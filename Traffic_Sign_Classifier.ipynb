# %% [markdown]
# # Self-Driving Car Engineer Nanodegree
#
# ## Deep Learning
#
# ## Project: Build a Traffic Sign Recognition Classifier
#
# In this notebook, a template is provided for you to implement your functionality in stages, which is required to successfully complete this project. If additional code is required that cannot be included in the notebook, be sure that the Python code is successfully imported and included in your submission if necessary.
#
# > **Note**: Once you have completed all of the code implementations, you need to finalize your work by exporting the iPython Notebook as an HTML document. Before exporting the notebook to html, all of the code cells need to have been run so that reviewers can see the final implementation and output. You can then export the notebook by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
#
# In addition to implementing code, there is a writeup to complete. The writeup should be completed in a separate file, which can be either a markdown file or a pdf document. There is a [write up template](https://github.com/udacity/CarND-Traffic-Sign-Classifier-Project/blob/master/writeup_template.md) that can be used to guide the writing process. Completing the code template and writeup template will cover all of the [rubric points](https://review.udacity.com/#!/rubrics/481/view) for this project.
#
# The [rubric](https://review.udacity.com/#!/rubrics/481/view) contains "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. The stand out suggestions are optional. If you decide to pursue the "stand out suggestions", you can include the code in this Ipython notebook and also discuss the results in the writeup file.
#
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut. In addition, Markdown cells can be edited by typically double-clicking the cell to enter edit mode.

# %% [markdown]
# ---
# ## Step 0: Load The Data

# %%
# Load pickled data
import pickle

# TODO: Fill this in based on where you saved the training and testing data

training_file = "./trafficSignData/train.p"
validation_file="./trafficSignData/valid.p"
testing_file ="./trafficSignData/test.p"

with open(training_file, mode='rb') as f:
    train = pickle.load(f)
with open(validation_file, mode='rb') as f:
    valid = pickle.load(f)
with open(testing_file, mode='rb') as f:
    test = pickle.load(f)
    
X_train, y_train = train['features'], train['labels']
X_valid, y_valid = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %% [markdown]
# ---
#
# ## Step 1: Dataset Summary & Exploration
#
# The pickled data is a dictionary with 4 key/value pairs:
#
# - `'features'` is a 4D array containing raw pixel data of the traffic sign images, (num examples, width, height, channels).
# - `'labels'` is a 1D array containing the label/class id of the traffic sign. The file `signnames.csv` contains id -> name mappings for each id.
# - `'sizes'` is a list containing tuples, (width, height) representing the original width and height the image.
# - `'coords'` is a list containing tuples, (x1, y1, x2, y2) representing coordinates of a bounding box around the sign in the image. **THESE COORDINATES ASSUME THE ORIGINAL IMAGE. THE PICKLED DATA CONTAINS RESIZED VERSIONS (32 by 32) OF THESE IMAGES**
#
# Complete the basic data summary below. Use python, numpy and/or pandas methods to calculate the data summary rather than hard coding the results. For example, the [pandas shape method](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.shape.html) might be useful for calculating some of the summary results.

# %% [markdown]
# ### Provide a Basic Summary of the Data Set Using Python, Numpy and/or Pandas

# %%
### Replace each question mark with the appropriate value. 
### Use python, pandas or numpy methods rather than hard coding the results
# TODO: Number of training examples
n_train = len(X_train)

# TODO: Number of testing examples.
n_test = len(X_test)

# TODO: What's the shape of an traffic sign image?
image_shape = X_train[0].shape

# TODO: How many unique classes/labels there are in the dataset.
#Go through all unique labels in the training set
unique_label=[]

for label in y_test:
    if label not in unique_label:
        unique_label.append(label)
        
n_classes = len(unique_label)

print("Number of training examples =", n_train)
print("Number of testing examples =", n_test)
print("Image data shape =", image_shape)
print("Number of classes =", n_classes)
# Out:
# Number of training examples = 34799
# Number of testing examples = 12630
# Image data shape = (32, 32, 3)
# Number of classes = 43

# %% [markdown]
# ### Include an exploratory visualization of the dataset

# %% [markdown]
# Visualize the German Traffic Signs Dataset using the pickled file(s). This is open ended, suggestions include: plotting traffic sign images, plotting the count of each sign, etc.
#
# The [Matplotlib](http://matplotlib.org/) [examples](http://matplotlib.org/examples/index.html) and [gallery](http://matplotlib.org/gallery.html) pages are a great resource for doing visualizations in Python.
#
# **NOTE:** It's recommended you start with something simple first. If you wish to do more, come back to it after you've completed the rest of the sections.

# %%
### Data exploration visualization code goes here.
### Feel free to use as many code cells as needed.
import matplotlib.pyplot as plt
# Visualizations will be shown in the notebook.
# %matplotlib inline

### Data exploration visualization code goes here.
### Feel free to use as many code cells as needed.
import matplotlib.pyplot as plt
# Visualizations will be shown in the notebook.
# %matplotlib inline
#img_id = 43
#image = X_train[img_id]
#image_label = y_train[img_id]
#img_plot = plt.imshow(image)
#print("imagenumber",img_id,"traffic label:",image_label)

num_of_samples=[]
plt.figure(figsize=(12, 16.5))
for i in range(0, n_classes):
    plt.subplot(11, 4, i+1)
    x_selected = X_train[y_train == i]
    plt.imshow(x_selected[0, :, :, :]) 
    plt.axis('off')
    num_of_samples.append(len(x_selected))
plt.show()

# %% [markdown]
# ----
#
# ## Step 2: Design and Test a Model Architecture
#
# Design and implement a deep learning model that learns to recognize traffic signs. Train and test your model on the [German Traffic Sign Dataset](http://benchmark.ini.rub.de/?section=gtsrb&subsection=dataset).
#
# The LeNet-5 implementation shown in the [classroom](https://classroom.udacity.com/nanodegrees/nd013/parts/fbf77062-5703-404e-b60c-95b78b2f3f9e/modules/6df7ae49-c61c-4bb2-a23e-6527e69209ec/lessons/601ae704-1035-4287-8b11-e2c2716217ad/concepts/d4aca031-508f-4e0b-b493-e7b706120f81) at the end of the CNN lesson is a solid starting point. You'll have to change the number of classes and possibly the preprocessing, but aside from that it's plug and play!
#
# With the LeNet-5 solution from the lecture, you should expect a validation set accuracy of about 0.89. To meet specifications, the validation set accuracy will need to be at least 0.93. It is possible to get an even higher accuracy, but 0.93 is the minimum for a successful project submission.
#
# There are various aspects to consider when thinking about this problem:
#
# - Neural network architecture (is the network over or underfitting?)
# - Play around preprocessing techniques (normalization, rgb to grayscale, etc)
# - Number of examples per label (some have more than others).
# - Generate fake data.
#
# Here is an example of a [published baseline model on this problem](http://yann.lecun.com/exdb/publis/pdf/sermanet-ijcnn-11.pdf). It's not required to be familiar with the approach used in the paper but, it's good practice to try to read papers like these.

# %% [markdown]
# ### Pre-process the Data Set (normalization, grayscale, etc.)

# %% [markdown]
# Use the code cell (or multiple code cells, if necessary) to implement the first step of your project.

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

#skimage.exposure.equalize_adapthist
### Preprocess the data here. Preprocessing steps could include normalization, converting to grayscale, etc.
### Feel free to use as many code cells as needed.


def convert_to_gray(image):
    return(cv2.cvtColor(image, cv2.COLOR_BGR2GRAY))
def equalize_histogram(image):
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(2,2))
    return(clahe.apply(image))

    
def reshape(image):
    return(np.reshape(image,(32,32,1)))
    

def process_image(image):
    gray = convert_to_gray(image)
    gray_eq_hist = equalize_histogram(gray)
    gray_eq_hist_reshaped = reshape(gray_eq_hist)
    gray_eq_hist_reshaped = (gray_eq_hist_reshaped-128.0)/255.0
    return gray_eq_hist_reshaped

# %%
inputimage=X_train[897]
processed_image = np.reshape(process_image(inputimage),(32,32))
plt.subplot(2,1,1)
plt.imshow(inputimage)
plt.subplot(2,1,2)
plt.imshow(processed_image,cmap='gray')

# %%
X_train_processed=[]
X_valid_processed = []

for img in X_train:
    X_train_processed.append(process_image(img))
    
for img in X_valid:
    X_valid_processed.append(process_image(img))

# %%
#Test data

test_images=[]
test_labels=[]
test_images_processed=[]

def load_image(path,label):
    img = cv2.imread(path)
    test_labels.append(label)
    pimg = process_image(img)
    imgshow = np.reshape(pimg,(32,32))
    test_images_processed.append(pimg)
    plt.imshow(imgshow,cmap='gray')
    
#GeneralCaution.jpg, 18
#SpeedLimit30.jpg    , 1  
#speedLimit30_1.jpg
#AheadOnly.jpg, 35
  
#roundAbout.jpg   40       
plt.subplot(1,5,1)
load_image("test/GeneralCaution.jpg",18)
plt.subplot(1,5,2)
load_image("test/SpeedLimit30.jpg",1)
plt.subplot(1,5,3)
load_image("test/speedLimit30_1.jpg",1)
plt.subplot(1,5,4)
load_image("test/roundAbout.jpg",40)
plt.subplot(1,5,5)
load_image("test/AheadOnly.jpg",35)

# %% [markdown]
# ### Model Architecture

# %%
#Visualize the processed data
import matplotlib.pyplot as plt
import random
# Visualizations will be shown in the notebook.
# %matplotlib inline

### Data exploration visualization code goes here.
### Feel free to use as many code cells as needed.
import matplotlib.pyplot as plt
# Visualizations will be shown in the notebook.
# %matplotlib inline


#img_id = 43
#image = X_train[img_id]
#image_label = y_train[img_id]
#img_plot = plt.imshow(image)
#print("imagenumber",img_id,"traffic label:",image_label)


plt.figure(figsize=(12, 16.5))

num_images_to_display=5

for i in range(0,num_images_to_display):
    index = random.randint(0,len(X_train))
    inputimage=X_train[index]
    processed_image = np.reshape(process_image(inputimage),(32,32))
    plt.subplot(num_images_to_display,4,1+2*i)
    plt.imshow(inputimage)
    plt.subplot(num_images_to_display,4,2+2*i)
    plt.imshow(processed_image,cmap='gray')


#X_train = rgb2gray_reshape(X_train)
#X_valid = rgb2gray_reshape(X_valid)
#X_train = X_train/255.0
#X_valid = X_valid/255.0
#channels = 1

# %%
print(len(X_train_processed))

print(X_train_processed[3443])
# Out:
# 34799
# [[[-0.00784314]
#   [-0.1372549 ]
#   [-0.04313725]
#   ...,
#   [ 0.09803922]
#   [-0.17647059]
#   [-0.27058824]]
#
#  [[ 0.02745098]
#   [-0.2       ]
#   [-0.1254902 ]
#   ...,
#   [-0.04313725]
#   [-0.21568627]
#   [-0.26666667]]
#
#  [[ 0.03529412]
#   [-0.01176471]
#   [-0.21568627]
#   ...,
#   [-0.10588235]
#   [-0.19215686]
#   [-0.23137255]]
#
#  ...,
#  [[ 0.        ]
#   [-0.14509804]
#   [-0.03529412]
#   ...,
#   [-0.14509804]
#   [-0.20392157]
#   [-0.23921569]]
#
#  [[-0.08235294]
#   [-0.21568627]
#   [-0.22745098]
#   ...,
#   [-0.0745098 ]
#   [-0.13333333]
#   [-0.18039216]]
#
#  [[-0.17647059]
#   [-0.27058824]
#   [-0.29019608]
#   ...,
#   [-0.14509804]
#   [-0.14509804]
#   [-0.25098039]]]

# %%
#All parameters in one place
channels=1


global_mu=0.0
global_sigma = 0.1
rate = 0.008
EPOCH=1000
BATCH_SIZE = 256
drop_prob=0.3

# %%
from tensorflow.contrib.layers import flatten
def LeNet(x):    
    # Hyperparameters
    mu = global_mu
    sigma = global_sigma

    # SOLUTION: Layer 1: Convolutional. Input = 32x32x3. Output = 28x28x6.
    conv1_W = tf.Variable(tf.truncated_normal(shape=(5, 5, channels, 6), mean = mu, stddev = sigma))
    conv1_b = tf.Variable(tf.zeros(6))
    conv1   = tf.nn.conv2d(x, conv1_W, strides=[1, 1, 1, 1], padding='VALID') + conv1_b

    # SOLUTION: Activation.
    conv1 = tf.nn.relu(conv1)

    # SOLUTION: Pooling. Input = 28x28x6. Output = 14x14x6.
    conv1 = tf.nn.max_pool(conv1, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='VALID')

    # SOLUTION: Layer 2: Convolutional. Output = 10x10x16.
    conv2_W = tf.Variable(tf.truncated_normal(shape=(5, 5, 6, 16), mean = mu, stddev = sigma))
    conv2_b = tf.Variable(tf.zeros(16))
    conv2   = tf.nn.conv2d(conv1, conv2_W, strides=[1, 1, 1, 1], padding='VALID') + conv2_b

    # SOLUTION: Activation.
    conv2 = tf.nn.relu(conv2)
    


    # SOLUTION: Pooling. Input = 10x10x16. Output = 5x5x16.
    conv2 = tf.nn.max_pool(conv2, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='VALID')

    # SOLUTION: Flatten. Input = 5x5x16. Output = 400.
    fc0   = flatten(conv2)
    
    #drop out
    fc0 = tf.nn.dropout(fc0, keep_prob)
    
    # SOLUTION: Layer 3: Fully Connected. Input = 400. Output = 120.
    fc1_W = tf.Variable(tf.truncated_normal(shape=(400, 120), mean = mu, stddev = sigma))
    fc1_b = tf.Variable(tf.zeros(120))
    fc1   = tf.matmul(fc0, fc1_W) + fc1_b

    # SOLUTION: Activation.
    fc1    = tf.nn.relu(fc1)

    #Drop out
   # fc1 = tf.nn.dropout(fc1, keep_prob)
    
    # SOLUTION: Layer 4: Fully Connected. Input = 120. Output = 84.
    fc2_W  = tf.Variable(tf.truncated_normal(shape=(120, 84), mean = mu, stddev = sigma))
    fc2_b  = tf.Variable(tf.zeros(84))
    fc2    = tf.matmul(fc1, fc2_W) + fc2_b

    # SOLUTION: Activation.
    fc2    = tf.nn.relu(fc2)

       #Drop out
   # fc2 = tf.nn.dropout(fc2, keep_prob)
    
    # SOLUTION: Layer 5: Fully Connected. Input = 84. Output = 10.
    fc3_W  = tf.Variable(tf.truncated_normal(shape=(84, n_classes), mean = mu, stddev = sigma))
    fc3_b  = tf.Variable(tf.zeros(n_classes))
    logits = tf.matmul(fc2, fc3_W) + fc3_b

    return logits

# %% [markdown]
# ### Train, Validate and Test the Model

# %% [markdown]
# A validation set can be used to assess how well the model is performing. A low accuracy on the training and validation
# sets imply underfitting. A high accuracy on the training set but low accuracy on the validation set implies overfitting.

# %%
### Train your model here.
### Calculate and report the accuracy on the training and validation set.
### Once a final model architecture is selected, 
### the accuracy on the test set should be calculated and reported as well.
### Feel free to use as many code cells as needed.
import tensorflow as tf


x = tf.placeholder(tf.float32,(None,32,32,channels))
y = tf.placeholder(tf.int32,(None))
keep_prob = tf.placeholder(tf.float32,(None))
onehot_y = tf.one_hot(y,n_classes)

# %%
## Call the high level  pipeline here

logits = LeNet(x)
cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits,onehot_y)
loss_operation = tf.reduce_mean(cross_entropy)
optimizer = tf.train.AdamOptimizer(learning_rate=rate)
training_operation = optimizer.minimize(loss_operation)

# %%
#Create evaluation pipeline
correct_prediction = tf.equal(tf.argmax(logits,1),tf.argmax(onehot_y,1))
accuracy_operation = tf.reduce_mean(tf.cast(correct_prediction,tf.float32))
def evaluate(X_data,Y_data):
    num_examples = len(X_data)
    
    total_accuracy=0.0
    sess = tf.get_default_session()
    for offset in range(0,num_examples,BATCH_SIZE):
        batch_x, batch_y = X_data[offset:offset+BATCH_SIZE],Y_data[offset:offset+BATCH_SIZE],
        accuracy = sess.run(accuracy_operation, feed_dict={x: batch_x, y: batch_y,keep_prob:1.0})
        #total_accuracy += (accuracy * batch_x.shape[0])
        total_accuracy += (accuracy * len(batch_x))
    return total_accuracy/num_examples

# %%
#Train the Network
from sklearn.utils import shuffle

accuracy_plot=[]
training_accuracy_plot=[]
with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        num_examples = len(X_train)
        
        print("Let the training commence ...")
        print()
        for i in range(EPOCH):
            X_train_processed, y_train = shuffle(X_train_processed,y_train)
            for offset in range(0,BATCH_SIZE,num_examples):
                end = offset + BATCH_SIZE
                batch_x,batch_y = X_train_processed[offset:end],y_train[offset:end]
                sess.run(training_operation,feed_dict={x:batch_x,y:batch_y,keep_prob:drop_prob})
        
            validation_accuracy = evaluate(X_valid_processed,y_valid)
           # test_labels=[]
            # test_images_processed=[]
            training_accuracy = evaluate(test_images_processed,test_labels)
            print("EPOCHS ...",format(i+1))
            print("Validation accuracy ...",format(validation_accuracy))
            print("Training accuracy ...",format(training_accuracy))
            accuracy_plot.append(validation_accuracy)
            training_accuracy_plot.append(training_accuracy)
            if(validation_accuracy > 0.93):
                break
            
            
        saver = tf.train.Saver()
        saver.save(sess,"lenet")
        print("Model saved")
# Out:
# Let the training commence ...
#
# EPOCHS ... 1
# Validation accuracy ... 0.05623582766439909
# Training accuracy ... 0.0
# EPOCHS ... 2
# Validation accuracy ... 0.07777777777777778
# Training accuracy ... 0.4000000059604645
# EPOCHS ... 3
# Validation accuracy ... 0.05419501133786848
# Training accuracy ... 0.4000000059604645
# EPOCHS ... 4
# Validation accuracy ... 0.09591836734693877
# Training accuracy ... 0.4000000059604645
# EPOCHS ... 5
# Validation accuracy ... 0.0709750566893424
# Training accuracy ... 0.0
# EPOCHS ... 6
# Validation accuracy ... 0.1018140589569161
# Training accuracy ... 0.0
# EPOCHS ... 7
# Validation accuracy ... 0.10839002267573696
# Training accuracy ... 0.0
# EPOCHS ... 8
# Validation accuracy ... 0.10476190476190476
# Training accuracy ... 0.0
# EPOCHS ... 9
# Validation accuracy ... 0.10272108843537416
# Training accuracy ... 0.0
# EPOCHS ... 10
# Validation accuracy ... 0.09954648526077098
# Training accuracy ... 0.4000000059604645
# EPOCHS ... 11
# Validation accuracy ... 0.09206349206349207
# Training accuracy ... 0.4000000059604645
# EPOCHS ... 12
# Validation accuracy ... 0.09546485260686502
# Training accuracy ... 0.4000000059604645
# EPOCHS ... 13
# Validation accuracy ... 0.09841269833160365
# Training accuracy ... 0.4000000059604645
# EPOCHS ... 14
# Validation accuracy ... 0.1201814057335021
# Training accuracy ... 0.4000000059604645
# EPOCHS ... 15
# Validation accuracy ... 0.10204081623192006
# Training accuracy ... 0.4000000059604645
# EPOCHS ... 16
# Validation accuracy ... 0.10770975044525129
# Training accuracy ... 0.4000000059604645
# EPOCHS ... 17
# Validation accuracy ... 0.13560090708354164
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 18
# Validation accuracy ... 0.16394557833941886
# Training accuracy ... 0.4000000059604645
# EPOCHS ... 19
# Validation accuracy ... 0.18390022672358014
# Training accuracy ... 0.0
# EPOCHS ... 20
# Validation accuracy ... 0.19229024929794866
# Training accuracy ... 0.20000000298023224
# EPOCHS ... 21
# Validation accuracy ... 0.20952380936162002
# Training accuracy ... 0.20000000298023224
# EPOCHS ... 22
# Validation accuracy ... 0.22743764168280864
# Training accuracy ... 0.4000000059604645
# EPOCHS ... 23
# Validation accuracy ... 0.2573696144178611
# Training accuracy ... 0.4000000059604645
# EPOCHS ... 24
# Validation accuracy ... 0.2791383222387491
# Training accuracy ... 0.4000000059604645
# EPOCHS ... 25
# Validation accuracy ... 0.3061224491688129
# Training accuracy ... 0.20000000298023224
# EPOCHS ... 26
# Validation accuracy ... 0.32335600898920003
# Training accuracy ... 0.20000000298023224
# EPOCHS ... 27
# Validation accuracy ... 0.3387755101229869
# Training accuracy ... 0.20000000298023224
# EPOCHS ... 28
# Validation accuracy ... 0.3548752836359331
# Training accuracy ... 0.4000000059604645
# EPOCHS ... 29
# Validation accuracy ... 0.35147392284843115
# Training accuracy ... 0.20000000298023224
# EPOCHS ... 30
# Validation accuracy ... 0.34965986367526236
# Training accuracy ... 0.4000000059604645
# EPOCHS ... 31
# Validation accuracy ... 0.3557823131684543
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 32
# Validation accuracy ... 0.3791383219684333
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 33
# Validation accuracy ... 0.3970521543842324
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 34
# Validation accuracy ... 0.3861678006427358
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 35
# Validation accuracy ... 0.37981859445571897
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 36
# Validation accuracy ... 0.3732426307098666
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 37
# Validation accuracy ... 0.4045351470138481
# Training accuracy ... 0.4000000059604645
# EPOCHS ... 38
# Validation accuracy ... 0.40929705210013184
# Training accuracy ... 0.4000000059604645
# EPOCHS ... 39
# Validation accuracy ... 0.3977324259524443
# Training accuracy ... 0.4000000059604645
# EPOCHS ... 40
# Validation accuracy ... 0.4013605443258134
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 41
# Validation accuracy ... 0.4253968252346359
# Training accuracy ... 0.800000011920929
# EPOCHS ... 42
# Validation accuracy ... 0.43356009105435844
# Training accuracy ... 0.800000011920929
# EPOCHS ... 43
# Validation accuracy ... 0.4528344674445604
# Training accuracy ... 0.800000011920929
# EPOCHS ... 44
# Validation accuracy ... 0.48548752810138696
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 45
# Validation accuracy ... 0.49047619023290623
# Training accuracy ... 0.4000000059604645
# EPOCHS ... 46
# Validation accuracy ... 0.49160997735129464
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 47
# Validation accuracy ... 0.4877551019056584
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 48
# Validation accuracy ... 0.5072562358817275
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 49
# Validation accuracy ... 0.496371882140231
# Training accuracy ... 0.800000011920929
# EPOCHS ... 50
# Validation accuracy ... 0.49705215381656914
# Training accuracy ... 0.800000011920929
# EPOCHS ... 51
# Validation accuracy ... 0.4870748298779096
# Training accuracy ... 0.800000011920929
# EPOCHS ... 52
# Validation accuracy ... 0.502947845723894
# Training accuracy ... 0.800000011920929
# EPOCHS ... 53
# Validation accuracy ... 0.5278911563003955
# Training accuracy ... 0.800000011920929
# EPOCHS ... 54
# Validation accuracy ... 0.5541950113649
# Training accuracy ... 0.800000011920929
# EPOCHS ... 55
# Validation accuracy ... 0.5641723356009071
# Training accuracy ... 0.800000011920929
# EPOCHS ... 56
# Validation accuracy ... 0.5766439909297052
# Training accuracy ... 0.800000011920929
# EPOCHS ... 57
# Validation accuracy ... 0.5873015875719032
# Training accuracy ... 0.800000011920929
# EPOCHS ... 58
# Validation accuracy ... 0.6004535147932922
# Training accuracy ... 0.800000011920929
# EPOCHS ... 59
# Validation accuracy ... 0.5777777778859041
# Training accuracy ... 0.800000011920929
# EPOCHS ... 60
# Validation accuracy ... 0.6011337867129146
# Training accuracy ... 0.800000011920929
# EPOCHS ... 61
# Validation accuracy ... 0.6292517004910511
# Training accuracy ... 0.800000011920929
# EPOCHS ... 62
# Validation accuracy ... 0.6442176871288932
# Training accuracy ... 0.800000011920929
# EPOCHS ... 63
# Validation accuracy ... 0.646258503698708
# Training accuracy ... 0.800000011920929
# EPOCHS ... 64
# Validation accuracy ... 0.6362811789220694
# Training accuracy ... 0.800000011920929
# EPOCHS ... 65
# Validation accuracy ... 0.6190476188043348
# Training accuracy ... 0.800000011920929
# EPOCHS ... 66
# Validation accuracy ... 0.6367346936342667
# Training accuracy ... 0.800000011920929
# EPOCHS ... 67
# Validation accuracy ... 0.6401360546920846
# Training accuracy ... 0.800000011920929
# EPOCHS ... 68
# Validation accuracy ... 0.6362811794086378
# Training accuracy ... 0.800000011920929
# EPOCHS ... 69
# Validation accuracy ... 0.6356009070565101
# Training accuracy ... 1.0
# EPOCHS ... 70
# Validation accuracy ... 0.6437641724166957
# Training accuracy ... 1.0
# EPOCHS ... 71
# Validation accuracy ... 0.6630385488339292
# Training accuracy ... 1.0
# EPOCHS ... 72
# Validation accuracy ... 0.6875283444549491
# Training accuracy ... 1.0
# EPOCHS ... 73
# Validation accuracy ... 0.7122448982565311
# Training accuracy ... 1.0
# EPOCHS ... 74
# Validation accuracy ... 0.6979591839708168
# Training accuracy ... 1.0
# EPOCHS ... 75
# Validation accuracy ... 0.6902494331336075
# Training accuracy ... 1.0
# EPOCHS ... 76
# Validation accuracy ... 0.6818594104578706
# Training accuracy ... 1.0
# EPOCHS ... 77
# Validation accuracy ... 0.6743764172605917
# Training accuracy ... 0.800000011920929
# EPOCHS ... 78
# Validation accuracy ... 0.6782312928143542
# Training accuracy ... 0.800000011920929
# EPOCHS ... 79
# Validation accuracy ... 0.6804988659968992
# Training accuracy ... 1.0
# EPOCHS ... 80
# Validation accuracy ... 0.6913832203060591
# Training accuracy ... 1.0
# EPOCHS ... 81
# Validation accuracy ... 0.701587301425112
# Training accuracy ... 1.0
# EPOCHS ... 82
# Validation accuracy ... 0.6918367347749723
# Training accuracy ... 0.800000011920929
# EPOCHS ... 83
# Validation accuracy ... 0.7043083898064231
# Training accuracy ... 0.800000011920929
# EPOCHS ... 84
# Validation accuracy ... 0.7154195014311343
# Training accuracy ... 1.0
# EPOCHS ... 85
# Validation accuracy ... 0.7163265309095923
# Training accuracy ... 1.0
# EPOCHS ... 86
# Validation accuracy ... 0.70113378714542
# Training accuracy ... 1.0
# EPOCHS ... 87
# Validation accuracy ... 0.7092970524515424
# Training accuracy ... 1.0
# EPOCHS ... 88
# Validation accuracy ... 0.711337868778073
# Training accuracy ... 1.0
# EPOCHS ... 89
# Validation accuracy ... 0.7165532877385752
# Training accuracy ... 0.800000011920929
# EPOCHS ... 90
# Validation accuracy ... 0.7233560093676422
# Training accuracy ... 0.800000011920929
# EPOCHS ... 91
# Validation accuracy ... 0.7172335601717977
# Training accuracy ... 0.800000011920929
# EPOCHS ... 92
# Validation accuracy ... 0.7188208620294151
# Training accuracy ... 0.800000011920929
# EPOCHS ... 93
# Validation accuracy ... 0.736507936345747
# Training accuracy ... 0.800000011920929
# EPOCHS ... 94
# Validation accuracy ... 0.7424036284422929
# Training accuracy ... 0.800000011920929
# EPOCHS ... 95
# Validation accuracy ... 0.7319727894400253
# Training accuracy ... 0.800000011920929
# EPOCHS ... 96
# Validation accuracy ... 0.7342403628658546
# Training accuracy ... 0.800000011920929
# EPOCHS ... 97
# Validation accuracy ... 0.7317460320433792
# Training accuracy ... 0.800000011920929
# EPOCHS ... 98
# Validation accuracy ... 0.7240362812332015
# Training accuracy ... 1.0
# EPOCHS ... 99
# Validation accuracy ... 0.7380952384466487
# Training accuracy ... 1.0
# EPOCHS ... 100
# Validation accuracy ... 0.7510204079740442
# Training accuracy ... 1.0
# EPOCHS ... 101
# Validation accuracy ... 0.746712018437937
# Training accuracy ... 1.0
# EPOCHS ... 102
# Validation accuracy ... 0.7390022673304119
# Training accuracy ... 1.0
# EPOCHS ... 103
# Validation accuracy ... 0.7458049889324474
# Training accuracy ... 1.0
# EPOCHS ... 104
# Validation accuracy ... 0.7646258506104519
# Training accuracy ... 1.0
# EPOCHS ... 105
# Validation accuracy ... 0.7394557823129252
# Training accuracy ... 1.0
# EPOCHS ... 106
# Validation accuracy ... 0.7301587301587301
# Training accuracy ... 1.0
# EPOCHS ... 107
# Validation accuracy ... 0.7562358276643991
# Training accuracy ... 1.0
# EPOCHS ... 108
# Validation accuracy ... 0.7782312925170068
# Training accuracy ... 1.0
# EPOCHS ... 109
# Validation accuracy ... 0.7607709748404367
# Training accuracy ... 1.0
# EPOCHS ... 110
# Validation accuracy ... 0.7560090703488478
# Training accuracy ... 1.0
# EPOCHS ... 111
# Validation accuracy ... 0.7569160995840215
# Training accuracy ... 1.0
# EPOCHS ... 112
# Validation accuracy ... 0.7371882089411591
# Training accuracy ... 0.800000011920929
# EPOCHS ... 113
# Validation accuracy ... 0.7362811789220693
# Training accuracy ... 0.800000011920929
# EPOCHS ... 114
# Validation accuracy ... 0.7521541947950852
# Training accuracy ... 0.800000011920929
# EPOCHS ... 115
# Validation accuracy ... 0.7630385488068976
# Training accuracy ... 0.800000011920929
# EPOCHS ... 116
# Validation accuracy ... 0.7578231295760797
# Training accuracy ... 0.4000000059604645
# EPOCHS ... 117
# Validation accuracy ... 0.7546485261581922
# Training accuracy ... 0.4000000059604645
# EPOCHS ... 118
# Validation accuracy ... 0.7662131517652482
# Training accuracy ... 0.800000011920929
# EPOCHS ... 119
# Validation accuracy ... 0.7739229026024574
# Training accuracy ... 1.0
# EPOCHS ... 120
# Validation accuracy ... 0.7807256236638612
# Training accuracy ... 1.0
# EPOCHS ... 121
# Validation accuracy ... 0.7793650796624269
# Training accuracy ... 1.0
# EPOCHS ... 122
# Validation accuracy ... 0.785034013362158
# Training accuracy ... 1.0
# EPOCHS ... 123
# Validation accuracy ... 0.7888888886456046
# Training accuracy ... 1.0
# EPOCHS ... 124
# Validation accuracy ... 0.792517007073037
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 125
# Validation accuracy ... 0.7993197281614723
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 126
# Validation accuracy ... 0.8031746032016348
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 127
# Validation accuracy ... 0.8004535147662606
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 128
# Validation accuracy ... 0.7941043084170543
# Training accuracy ... 0.800000011920929
# EPOCHS ... 129
# Validation accuracy ... 0.7879818597077782
# Training accuracy ... 0.800000011920929
# EPOCHS ... 130
# Validation accuracy ... 0.7770975054256499
# Training accuracy ... 1.0
# EPOCHS ... 131
# Validation accuracy ... 0.7705215422204292
# Training accuracy ... 1.0
# EPOCHS ... 132
# Validation accuracy ... 0.7804988664834678
# Training accuracy ... 1.0
# EPOCHS ... 133
# Validation accuracy ... 0.7993197281614723
# Training accuracy ... 1.0
# EPOCHS ... 134
# Validation accuracy ... 0.792517007073037
# Training accuracy ... 1.0
# EPOCHS ... 135
# Validation accuracy ... 0.7961451249868692
# Training accuracy ... 1.0
# EPOCHS ... 136
# Validation accuracy ... 0.8006802723791594
# Training accuracy ... 1.0
# EPOCHS ... 137
# Validation accuracy ... 0.8122448982294995
# Training accuracy ... 1.0
# EPOCHS ... 138
# Validation accuracy ... 0.8113378682374414
# Training accuracy ... 1.0
# EPOCHS ... 139
# Validation accuracy ... 0.8204081630220219
# Training accuracy ... 1.0
# EPOCHS ... 140
# Validation accuracy ... 0.81269841248216
# Training accuracy ... 1.0
# EPOCHS ... 141
# Validation accuracy ... 0.7977324263849497
# Training accuracy ... 1.0
# EPOCHS ... 142
# Validation accuracy ... 0.7827664397471076
# Training accuracy ... 0.800000011920929
# EPOCHS ... 143
# Validation accuracy ... 0.7770975057770606
# Training accuracy ... 0.800000011920929
# EPOCHS ... 144
# Validation accuracy ... 0.7766439912811158
# Training accuracy ... 0.800000011920929
# EPOCHS ... 145
# Validation accuracy ... 0.7911564624228445
# Training accuracy ... 0.800000011920929
# EPOCHS ... 146
# Validation accuracy ... 0.8086167803967621
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 147
# Validation accuracy ... 0.8083900224594843
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 148
# Validation accuracy ... 0.8022675734528608
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 149
# Validation accuracy ... 0.8117913832199547
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 150
# Validation accuracy ... 0.8206349206349206
# Training accuracy ... 0.800000011920929
# EPOCHS ... 151
# Validation accuracy ... 0.8204081632653061
# Training accuracy ... 0.800000011920929
# EPOCHS ... 152
# Validation accuracy ... 0.8197278914267785
# Training accuracy ... 0.800000011920929
# EPOCHS ... 153
# Validation accuracy ... 0.8104308392725834
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 154
# Validation accuracy ... 0.8113378682374414
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 155
# Validation accuracy ... 0.820181405679439
# Training accuracy ... 0.800000011920929
# EPOCHS ... 156
# Validation accuracy ... 0.8197278914808416
# Training accuracy ... 0.800000011920929
# EPOCHS ... 157
# Validation accuracy ... 0.8058956919613879
# Training accuracy ... 0.800000011920929
# EPOCHS ... 158
# Validation accuracy ... 0.8099773245874176
# Training accuracy ... 1.0
# EPOCHS ... 159
# Validation accuracy ... 0.8215419504107261
# Training accuracy ... 1.0
# EPOCHS ... 160
# Validation accuracy ... 0.8176870748569636
# Training accuracy ... 1.0
# EPOCHS ... 161
# Validation accuracy ... 0.8131519274646734
# Training accuracy ... 1.0
# EPOCHS ... 162
# Validation accuracy ... 0.8160997735129463
# Training accuracy ... 1.0
# EPOCHS ... 163
# Validation accuracy ... 0.8156462587737172
# Training accuracy ... 0.800000011920929
# EPOCHS ... 164
# Validation accuracy ... 0.8172335598474186
# Training accuracy ... 0.800000011920929
# EPOCHS ... 165
# Validation accuracy ... 0.8260770972623847
# Training accuracy ... 0.800000011920929
# EPOCHS ... 166
# Validation accuracy ... 0.8231292517277119
# Training accuracy ... 0.800000011920929
# EPOCHS ... 167
# Validation accuracy ... 0.8247165535853292
# Training accuracy ... 1.0
# EPOCHS ... 168
# Validation accuracy ... 0.83129251679055
# Training accuracy ... 1.0
# EPOCHS ... 169
# Validation accuracy ... 0.8383219952486
# Training accuracy ... 1.0
# EPOCHS ... 170
# Validation accuracy ... 0.8462585037257395
# Training accuracy ... 1.0
# EPOCHS ... 171
# Validation accuracy ... 0.8455782310762643
# Training accuracy ... 1.0
# EPOCHS ... 172
# Validation accuracy ... 0.8455782310762643
# Training accuracy ... 1.0
# EPOCHS ... 173
# Validation accuracy ... 0.8435374149930179
# Training accuracy ... 1.0
# EPOCHS ... 174
# Validation accuracy ... 0.8385487528614987
# Training accuracy ... 1.0
# EPOCHS ... 175
# Validation accuracy ... 0.8253968256671412
# Training accuracy ... 1.0
# EPOCHS ... 176
# Validation accuracy ... 0.8251700682975267
# Training accuracy ... 1.0
# EPOCHS ... 177
# Validation accuracy ... 0.8226757369884828
# Training accuracy ... 1.0
# EPOCHS ... 178
# Validation accuracy ... 0.8326530615218373
# Training accuracy ... 1.0
# EPOCHS ... 179
# Validation accuracy ... 0.8333333336577123
# Training accuracy ... 1.0
# EPOCHS ... 180
# Validation accuracy ... 0.8297052154735644
# Training accuracy ... 1.0
# EPOCHS ... 181
# Validation accuracy ... 0.8235827662506882
# Training accuracy ... 1.0
# EPOCHS ... 182
# Validation accuracy ... 0.8260770975867637
# Training accuracy ... 1.0
# EPOCHS ... 183
# Validation accuracy ... 0.8317460315568107
# Training accuracy ... 1.0
# EPOCHS ... 184
# Validation accuracy ... 0.8306122452223382
# Training accuracy ... 1.0
# EPOCHS ... 185
# Validation accuracy ... 0.8244897959724306
# Training accuracy ... 0.800000011920929
# EPOCHS ... 186
# Validation accuracy ... 0.8233560088540421
# Training accuracy ... 0.800000011920929
# EPOCHS ... 187
# Validation accuracy ... 0.8249433109549438
# Training accuracy ... 0.800000011920929
# EPOCHS ... 188
# Validation accuracy ... 0.8301587301857617
# Training accuracy ... 0.800000011920929
# EPOCHS ... 189
# Validation accuracy ... 0.8297052154195012
# Training accuracy ... 0.800000011920929
# EPOCHS ... 190
# Validation accuracy ... 0.8353741499301798
# Training accuracy ... 1.0
# EPOCHS ... 191
# Validation accuracy ... 0.8369614510038813
# Training accuracy ... 1.0
# EPOCHS ... 192
# Validation accuracy ... 0.8435374152633338
# Training accuracy ... 1.0
# EPOCHS ... 193
# Validation accuracy ... 0.8478458052860096
# Training accuracy ... 1.0
# EPOCHS ... 194
# Validation accuracy ... 0.8482993200252386
# Training accuracy ... 1.0
# EPOCHS ... 195
# Validation accuracy ... 0.8448979589403892
# Training accuracy ... 1.0
# EPOCHS ... 196
# Validation accuracy ... 0.8351473925605652
# Training accuracy ... 1.0
# EPOCHS ... 197
# Validation accuracy ... 0.8342403625685071
# Training accuracy ... 1.0
# EPOCHS ... 198
# Validation accuracy ... 0.8405895689177134
# Training accuracy ... 1.0
# EPOCHS ... 199
# Validation accuracy ... 0.8387755099607974
# Training accuracy ... 0.800000011920929
# EPOCHS ... 200
# Validation accuracy ... 0.8405895689177134
# Training accuracy ... 0.800000011920929
# EPOCHS ... 201
# Validation accuracy ... 0.841269841026557
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 202
# Validation accuracy ... 0.8376417231127248
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 203
# Validation accuracy ... 0.8387755099607974
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 204
# Validation accuracy ... 0.8437641720923167
# Training accuracy ... 0.800000011920929
# EPOCHS ... 205
# Validation accuracy ... 0.8367346936342668
# Training accuracy ... 0.800000011920929
# EPOCHS ... 206
# Validation accuracy ... 0.8331065757474662
# Training accuracy ... 0.800000011920929
# EPOCHS ... 207
# Validation accuracy ... 0.83560090705651
# Training accuracy ... 1.0
# EPOCHS ... 208
# Validation accuracy ... 0.8519274376687549
# Training accuracy ... 1.0
# EPOCHS ... 209
# Validation accuracy ... 0.8693877553993883
# Training accuracy ... 1.0
# EPOCHS ... 210
# Validation accuracy ... 0.868027210938417
# Training accuracy ... 1.0
# EPOCHS ... 211
# Validation accuracy ... 0.8643990927542688
# Training accuracy ... 1.0
# EPOCHS ... 212
# Validation accuracy ... 0.8562358279617466
# Training accuracy ... 1.0
# EPOCHS ... 213
# Validation accuracy ... 0.8469387752669199
# Training accuracy ... 1.0
# EPOCHS ... 214
# Validation accuracy ... 0.8453514741932183
# Training accuracy ... 0.800000011920929
# EPOCHS ... 215
# Validation accuracy ... 0.8496598642158941
# Training accuracy ... 1.0
# EPOCHS ... 216
# Validation accuracy ... 0.8512471658031957
# Training accuracy ... 1.0
# EPOCHS ... 217
# Validation accuracy ... 0.8544217689777989
# Training accuracy ... 0.800000011920929
# EPOCHS ... 218
# Validation accuracy ... 0.848752834737436
# Training accuracy ... 1.0
# EPOCHS ... 219
# Validation accuracy ... 0.8331065762340347
# Training accuracy ... 1.0
# EPOCHS ... 220
# Validation accuracy ... 0.819501134057164
# Training accuracy ... 1.0
# EPOCHS ... 221
# Validation accuracy ... 0.8140589571864156
# Training accuracy ... 1.0
# EPOCHS ... 222
# Validation accuracy ... 0.8337868483428782
# Training accuracy ... 1.0
# EPOCHS ... 223
# Validation accuracy ... 0.8517006805424246
# Training accuracy ... 1.0
# EPOCHS ... 224
# Validation accuracy ... 0.8467120184109054
# Training accuracy ... 1.0
# EPOCHS ... 225
# Validation accuracy ... 0.8462585036716764
# Training accuracy ... 1.0
# EPOCHS ... 226
# Validation accuracy ... 0.8455782313195486
# Training accuracy ... 1.0
# EPOCHS ... 227
# Validation accuracy ... 0.8498866213422244
# Training accuracy ... 1.0
# EPOCHS ... 228
# Validation accuracy ... 0.8560090703218162
# Training accuracy ... 1.0
# EPOCHS ... 229
# Validation accuracy ... 0.8673469388025418
# Training accuracy ... 1.0
# EPOCHS ... 230
# Validation accuracy ... 0.8646258506374835
# Training accuracy ... 1.0
# EPOCHS ... 231
# Validation accuracy ... 0.861904761958825
# Training accuracy ... 1.0
# EPOCHS ... 232
# Validation accuracy ... 0.8591836735234509
# Training accuracy ... 1.0
# EPOCHS ... 233
# Validation accuracy ... 0.8596371879923641
# Training accuracy ... 1.0
# EPOCHS ... 234
# Validation accuracy ... 0.8589569163971207
# Training accuracy ... 1.0
# EPOCHS ... 235
# Validation accuracy ... 0.8541950113649001
# Training accuracy ... 0.800000011920929
# EPOCHS ... 236
# Validation accuracy ... 0.8523809526512682
# Training accuracy ... 0.800000011920929
# EPOCHS ... 237
# Validation accuracy ... 0.8505668936943521
# Training accuracy ... 0.800000011920929
# EPOCHS ... 238
# Validation accuracy ... 0.8555555558258714
# Training accuracy ... 0.800000011920929
# EPOCHS ... 239
# Validation accuracy ... 0.8526077100208828
# Training accuracy ... 0.800000011920929
# EPOCHS ... 240
# Validation accuracy ... 0.85850340111726
# Training accuracy ... 0.800000011920929
# EPOCHS ... 241
# Validation accuracy ... 0.8664399090537679
# Training accuracy ... 1.0
# EPOCHS ... 242
# Validation accuracy ... 0.8653061224760111
# Training accuracy ... 1.0
# EPOCHS ... 243
# Validation accuracy ... 0.8594104311363497
# Training accuracy ... 1.0
# EPOCHS ... 244
# Validation accuracy ... 0.8571428574402046
# Training accuracy ... 1.0
# EPOCHS ... 245
# Validation accuracy ... 0.8551020411136739
# Training accuracy ... 1.0
# EPOCHS ... 246
# Validation accuracy ... 0.8641723356279386
# Training accuracy ... 1.0
# EPOCHS ... 247
# Validation accuracy ... 0.8689342403898433
# Training accuracy ... 1.0
# EPOCHS ... 248
# Validation accuracy ... 0.8707482990764436
# Training accuracy ... 1.0
# EPOCHS ... 249
# Validation accuracy ... 0.8653061227192954
# Training accuracy ... 1.0
# EPOCHS ... 250
# Validation accuracy ... 0.856235827934715
# Training accuracy ... 1.0
# EPOCHS ... 251
# Validation accuracy ... 0.8458049884188472
# Training accuracy ... 0.800000011920929
# EPOCHS ... 252
# Validation accuracy ... 0.8435374147227022
# Training accuracy ... 0.800000011920929
# EPOCHS ... 253
# Validation accuracy ... 0.8496598642429256
# Training accuracy ... 0.800000011920929
# EPOCHS ... 254
# Validation accuracy ... 0.8575963721794336
# Training accuracy ... 0.800000011920929
# EPOCHS ... 255
# Validation accuracy ... 0.8678004538391183
# Training accuracy ... 0.800000011920929
# EPOCHS ... 256
# Validation accuracy ... 0.8741496596747245
# Training accuracy ... 0.800000011920929
# EPOCHS ... 257
# Validation accuracy ... 0.8725623580874229
# Training accuracy ... 1.0
# EPOCHS ... 258
# Validation accuracy ... 0.8755102044060117
# Training accuracy ... 1.0
# EPOCHS ... 259
# Validation accuracy ... 0.8639455785556716
# Training accuracy ... 1.0
# EPOCHS ... 260
# Validation accuracy ... 0.8605442180114539
# Training accuracy ... 1.0
# EPOCHS ... 261
# Validation accuracy ... 0.8605442174708221
# Training accuracy ... 1.0
# EPOCHS ... 262
# Validation accuracy ... 0.8639455780150398
# Training accuracy ... 1.0
# EPOCHS ... 263
# Validation accuracy ... 0.8625850340676686
# Training accuracy ... 1.0
# EPOCHS ... 264
# Validation accuracy ... 0.8621315190581237
# Training accuracy ... 1.0
# EPOCHS ... 265
# Validation accuracy ... 0.8700680275082318
# Training accuracy ... 1.0
# EPOCHS ... 266
# Validation accuracy ... 0.8804988662401835
# Training accuracy ... 1.0
# EPOCHS ... 267
# Validation accuracy ... 0.8829931972789116
# Training accuracy ... 1.0
# EPOCHS ... 268
# Validation accuracy ... 0.8841269841269841
# Training accuracy ... 0.800000011920929
# EPOCHS ... 269
# Validation accuracy ... 0.8684807253802985
# Training accuracy ... 0.800000011920929
# EPOCHS ... 270
# Validation accuracy ... 0.8643990927272373
# Training accuracy ... 0.800000011920929
# EPOCHS ... 271
# Validation accuracy ... 0.8653061224760111
# Training accuracy ... 0.800000011920929
# EPOCHS ... 272
# Validation accuracy ... 0.8678004535417708
# Training accuracy ... 0.800000011920929
# EPOCHS ... 273
# Validation accuracy ... 0.8795918367617255
# Training accuracy ... 1.0
# EPOCHS ... 274
# Validation accuracy ... 0.8816326531152877
# Training accuracy ... 1.0
# EPOCHS ... 275
# Validation accuracy ... 0.8848072565602066
# Training accuracy ... 1.0
# EPOCHS ... 276
# Validation accuracy ... 0.8841269841810473
# Training accuracy ... 1.0
# EPOCHS ... 277
# Validation accuracy ... 0.8775510207055107
# Training accuracy ... 1.0
# EPOCHS ... 278
# Validation accuracy ... 0.873696145422064
# Training accuracy ... 1.0
# EPOCHS ... 279
# Validation accuracy ... 0.8730158730429046
# Training accuracy ... 1.0
# EPOCHS ... 280
# Validation accuracy ... 0.8818594107011548
# Training accuracy ... 1.0
# EPOCHS ... 281
# Validation accuracy ... 0.8945578233995676
# Training accuracy ... 1.0
# EPOCHS ... 282
# Validation accuracy ... 0.8879818596807467
# Training accuracy ... 1.0
# EPOCHS ... 283
# Validation accuracy ... 0.8750566896127194
# Training accuracy ... 1.0
# EPOCHS ... 284
# Validation accuracy ... 0.8643990932408374
# Training accuracy ... 1.0
# EPOCHS ... 285
# Validation accuracy ... 0.8696145124716553
# Training accuracy ... 1.0
# EPOCHS ... 286
# Validation accuracy ... 0.8732426303854876
# Training accuracy ... 1.0
# EPOCHS ... 287
# Validation accuracy ... 0.8759637190911775
# Training accuracy ... 1.0
# EPOCHS ... 288
# Validation accuracy ... 0.8702947848508147
# Training accuracy ... 1.0
# EPOCHS ... 289
# Validation accuracy ... 0.8637188206183938
# Training accuracy ... 1.0
# EPOCHS ... 290
# Validation accuracy ... 0.8603174600741761
# Training accuracy ... 1.0
# EPOCHS ... 291
# Validation accuracy ... 0.8603174600741761
# Training accuracy ... 1.0
# EPOCHS ... 292
# Validation accuracy ... 0.8587301584868745
# Training accuracy ... 1.0
# EPOCHS ... 293
# Validation accuracy ... 0.8621315190310922
# Training accuracy ... 1.0
# EPOCHS ... 294
# Validation accuracy ... 0.8632653058791647
# Training accuracy ... 1.0
# EPOCHS ... 295
# Validation accuracy ... 0.8671201814329272
# Training accuracy ... 1.0
# EPOCHS ... 296
# Validation accuracy ... 0.8750566890991194
# Training accuracy ... 1.0
# EPOCHS ... 297
# Validation accuracy ... 0.8825396822963982
# Training accuracy ... 1.0
# EPOCHS ... 298
# Validation accuracy ... 0.8882086165367611
# Training accuracy ... 1.0
# EPOCHS ... 299
# Validation accuracy ... 0.8891156460152191
# Training accuracy ... 1.0
# EPOCHS ... 300
# Validation accuracy ... 0.8850340133621579
# Training accuracy ... 1.0
# EPOCHS ... 301
# Validation accuracy ... 0.8786848072832674
# Training accuracy ... 1.0
# EPOCHS ... 302
# Validation accuracy ... 0.8757369612079628
# Training accuracy ... 1.0
# EPOCHS ... 303
# Validation accuracy ... 0.8791383217521805
# Training accuracy ... 1.0
# EPOCHS ... 304
# Validation accuracy ... 0.8734693877821337
# Training accuracy ... 1.0
# EPOCHS ... 305
# Validation accuracy ... 0.8664399093240838
# Training accuracy ... 0.800000011920929
# EPOCHS ... 306
# Validation accuracy ... 0.8689342403898433
# Training accuracy ... 0.800000011920929
# EPOCHS ... 307
# Validation accuracy ... 0.8732426304125191
# Training accuracy ... 0.800000011920929
# EPOCHS ... 308
# Validation accuracy ... 0.8770975056959658
# Training accuracy ... 0.800000011920929
# EPOCHS ... 309
# Validation accuracy ... 0.8734693877821337
# Training accuracy ... 1.0
# EPOCHS ... 310
# Validation accuracy ... 0.8773242627952645
# Training accuracy ... 1.0
# EPOCHS ... 311
# Validation accuracy ... 0.8752834464687339
# Training accuracy ... 1.0
# EPOCHS ... 312
# Validation accuracy ... 0.8746031746302062
# Training accuracy ... 1.0
# EPOCHS ... 313
# Validation accuracy ... 0.8752834470093656
# Training accuracy ... 1.0
# EPOCHS ... 314
# Validation accuracy ... 0.8789115644095976
# Training accuracy ... 1.0
# EPOCHS ... 315
# Validation accuracy ... 0.8911564626120656
# Training accuracy ... 1.0
# EPOCHS ... 316
# Validation accuracy ... 0.8934240365785265
# Training accuracy ... 1.0
# EPOCHS ... 317
# Validation accuracy ... 0.8927437644696831
# Training accuracy ... 1.0
# EPOCHS ... 318
# Validation accuracy ... 0.8861678004805463
# Training accuracy ... 1.0
# EPOCHS ... 319
# Validation accuracy ... 0.8802721088976005
# Training accuracy ... 1.0
# EPOCHS ... 320
# Validation accuracy ... 0.8770975059933133
# Training accuracy ... 1.0
# EPOCHS ... 321
# Validation accuracy ... 0.881859410755218
# Training accuracy ... 1.0
# EPOCHS ... 322
# Validation accuracy ... 0.8841269844513632
# Training accuracy ... 1.0
# EPOCHS ... 323
# Validation accuracy ... 0.8873015876259663
# Training accuracy ... 1.0
# EPOCHS ... 324
# Validation accuracy ... 0.8934240360649265
# Training accuracy ... 1.0
# EPOCHS ... 325
# Validation accuracy ... 0.894557822912999
# Training accuracy ... 1.0
# EPOCHS ... 326
# Validation accuracy ... 0.8950113376522281
# Training accuracy ... 1.0
# EPOCHS ... 327
# Validation accuracy ... 0.8870748302293202
# Training accuracy ... 1.0
# EPOCHS ... 328
# Validation accuracy ... 0.8748299319998207
# Training accuracy ... 0.800000011920929
# EPOCHS ... 329
# Validation accuracy ... 0.86122448982295
# Training accuracy ... 0.800000011920929
# EPOCHS ... 330
# Validation accuracy ... 0.8657596372152402
# Training accuracy ... 0.800000011920929
# EPOCHS ... 331
# Validation accuracy ... 0.8696145127690028
# Training accuracy ... 1.0
# EPOCHS ... 332
# Validation accuracy ... 0.8768707485696355
# Training accuracy ... 1.0
# EPOCHS ... 333
# Validation accuracy ... 0.8777777777777778
# Training accuracy ... 1.0
# EPOCHS ... 334
# Validation accuracy ... 0.8764172335600907
# Training accuracy ... 1.0
# EPOCHS ... 335
# Validation accuracy ... 0.8773242630385487
# Training accuracy ... 1.0
# EPOCHS ... 336
# Validation accuracy ... 0.8800453514739229
# Training accuracy ... 1.0
# EPOCHS ... 337
# Validation accuracy ... 0.8786848072562359
# Training accuracy ... 1.0
# EPOCHS ... 338
# Validation accuracy ... 0.8786848075265516
# Training accuracy ... 1.0
# EPOCHS ... 339
# Validation accuracy ... 0.8759637190911775
# Training accuracy ... 1.0
# EPOCHS ... 340
# Validation accuracy ... 0.8809523812226968
# Training accuracy ... 1.0
# EPOCHS ... 341
# Validation accuracy ... 0.8879818596807467
# Training accuracy ... 1.0
# EPOCHS ... 342
# Validation accuracy ... 0.8950113381387965
# Training accuracy ... 1.0
# EPOCHS ... 343
# Validation accuracy ... 0.8909297052154195
# Training accuracy ... 1.0
# EPOCHS ... 344
# Validation accuracy ... 0.891156462585034
# Training accuracy ... 1.0
# EPOCHS ... 345
# Validation accuracy ... 0.8884353739063756
# Training accuracy ... 1.0
# EPOCHS ... 346
# Validation accuracy ... 0.8798185938610241
# Training accuracy ... 0.800000011920929
# EPOCHS ... 347
# Validation accuracy ... 0.8827664396660128
# Training accuracy ... 1.0
# EPOCHS ... 348
# Validation accuracy ... 0.887755101797532
# Training accuracy ... 1.0
# EPOCHS ... 349
# Validation accuracy ... 0.8843537417939461
# Training accuracy ... 1.0
# EPOCHS ... 350
# Validation accuracy ... 0.8802721086002532
# Training accuracy ... 1.0
# EPOCHS ... 351
# Validation accuracy ... 0.8757369615053103
# Training accuracy ... 1.0
# EPOCHS ... 352
# Validation accuracy ... 0.8766439909837684
# Training accuracy ... 1.0
# EPOCHS ... 353
# Validation accuracy ... 0.8743764170173074
# Training accuracy ... 1.0
# EPOCHS ... 354
# Validation accuracy ... 0.885260770758804
# Training accuracy ... 1.0
# EPOCHS ... 355
# Validation accuracy ... 0.8938775510474397
# Training accuracy ... 1.0
# EPOCHS ... 356
# Validation accuracy ... 0.8943310655433845
# Training accuracy ... 1.0
# EPOCHS ... 357
# Validation accuracy ... 0.8900226755207088
# Training accuracy ... 1.0
# EPOCHS ... 358
# Validation accuracy ... 0.8857142857683489
# Training accuracy ... 1.0
# EPOCHS ... 359
# Validation accuracy ... 0.876417233343838
# Training accuracy ... 1.0
# EPOCHS ... 360
# Validation accuracy ... 0.8800453517712703
# Training accuracy ... 1.0
# EPOCHS ... 361
# Validation accuracy ... 0.8854875281284186
# Training accuracy ... 1.0
# EPOCHS ... 362
# Validation accuracy ... 0.8845804986499605
# Training accuracy ... 0.800000011920929
# EPOCHS ... 363
# Validation accuracy ... 0.8775510204622264
# Training accuracy ... 0.800000011920929
# EPOCHS ... 364
# Validation accuracy ... 0.8902494328903233
# Training accuracy ... 0.800000011920929
# EPOCHS ... 365
# Validation accuracy ... 0.9031746029313189
# Training accuracy ... 0.800000011920929
# EPOCHS ... 366
# Validation accuracy ... 0.8986394555390287
# Training accuracy ... 1.0
# EPOCHS ... 367
# Validation accuracy ... 0.8965986394557823
# Training accuracy ... 1.0
# EPOCHS ... 368
# Validation accuracy ... 0.8975056689342403
# Training accuracy ... 1.0
# EPOCHS ... 369
# Validation accuracy ... 0.8979591836734694
# Training accuracy ... 1.0
# EPOCHS ... 370
# Validation accuracy ... 0.8970521541950114
# Training accuracy ... 1.0
# EPOCHS ... 371
# Validation accuracy ... 0.8959183673469387
# Training accuracy ... 1.0
# EPOCHS ... 372
# Validation accuracy ... 0.8941043086603385
# Training accuracy ... 1.0
# EPOCHS ... 373
# Validation accuracy ... 0.8931972791818805
# Training accuracy ... 1.0
# EPOCHS ... 374
# Validation accuracy ... 0.8877551023111322
# Training accuracy ... 1.0
# EPOCHS ... 375
# Validation accuracy ... 0.8809523812226968
# Training accuracy ... 0.800000011920929
# EPOCHS ... 376
# Validation accuracy ... 0.8682539685242842
# Training accuracy ... 0.800000011920929
# EPOCHS ... 377
# Validation accuracy ... 0.8675736964154406
# Training accuracy ... 0.800000011920929
# EPOCHS ... 378
# Validation accuracy ... 0.8712018143292728
# Training accuracy ... 0.800000011920929
# EPOCHS ... 379
# Validation accuracy ... 0.8721088435374149
# Training accuracy ... 0.800000011920929
# EPOCHS ... 380
# Validation accuracy ... 0.8909297049721352
# Training accuracy ... 0.800000011920929
# EPOCHS ... 381
# Validation accuracy ... 0.9024943310927912
# Training accuracy ... 1.0
# EPOCHS ... 382
# Validation accuracy ... 0.9013605440014344
# Training accuracy ... 1.0
# EPOCHS ... 383
# Validation accuracy ... 0.8965986395098455
# Training accuracy ... 1.0
# EPOCHS ... 384
# Validation accuracy ... 0.8941043084440858
# Training accuracy ... 1.0
# EPOCHS ... 385
# Validation accuracy ... 0.8913832200087117
# Training accuracy ... 1.0
# EPOCHS ... 386
# Validation accuracy ... 0.894557822912999
# Training accuracy ... 1.0
# EPOCHS ... 387
# Validation accuracy ... 0.8950113376522281
# Training accuracy ... 1.0
# EPOCHS ... 388
# Validation accuracy ... 0.8963718823835153
# Training accuracy ... 1.0
# EPOCHS ... 389
# Validation accuracy ... 0.8943310660569846
# Training accuracy ... 1.0
# EPOCHS ... 390
# Validation accuracy ... 0.8888888891862363
# Training accuracy ... 1.0
# EPOCHS ... 391
# Validation accuracy ... 0.8868480728597057
# Training accuracy ... 0.800000011920929
# EPOCHS ... 392
# Validation accuracy ... 0.8888888889159204
# Training accuracy ... 1.0
# EPOCHS ... 393
# Validation accuracy ... 0.894557822912999
# Training accuracy ... 1.0
# EPOCHS ... 394
# Validation accuracy ... 0.9049886621855825
# Training accuracy ... 1.0
# EPOCHS ... 395
# Validation accuracy ... 0.9088435374690291
# Training accuracy ... 1.0
# EPOCHS ... 396
# Validation accuracy ... 0.9077097503776723
# Training accuracy ... 1.0
# EPOCHS ... 397
# Validation accuracy ... 0.9040816324638401
# Training accuracy ... 1.0
# EPOCHS ... 398
# Validation accuracy ... 0.8945578234536308
# Training accuracy ... 1.0
# EPOCHS ... 399
# Validation accuracy ... 0.8859410428946791
# Training accuracy ... 1.0
# EPOCHS ... 400
# Validation accuracy ... 0.8820861681248325
# Training accuracy ... 1.0
# EPOCHS ... 401
# Validation accuracy ... 0.8834467123425196
# Training accuracy ... 1.0
# EPOCHS ... 402
# Validation accuracy ... 0.8891156463125666
# Training accuracy ... 1.0
# EPOCHS ... 403
# Validation accuracy ... 0.8877551020948795
# Training accuracy ... 1.0
# EPOCHS ... 404
# Validation accuracy ... 0.8859410431109318
# Training accuracy ... 1.0
# EPOCHS ... 405
# Validation accuracy ... 0.8854875283717027
# Training accuracy ... 1.0
# EPOCHS ... 406
# Validation accuracy ... 0.890476190503222
# Training accuracy ... 1.0
# EPOCHS ... 407
# Validation accuracy ... 0.8968253971227442
# Training accuracy ... 1.0
# EPOCHS ... 408
# Validation accuracy ... 0.9013605440014344
# Training accuracy ... 1.0
# EPOCHS ... 409
# Validation accuracy ... 0.8981859408268312
# Training accuracy ... 1.0
# EPOCHS ... 410
# Validation accuracy ... 0.9006802718925908
# Training accuracy ... 1.0
# EPOCHS ... 411
# Validation accuracy ... 0.9038548753104783
# Training accuracy ... 1.0
# EPOCHS ... 412
# Validation accuracy ... 0.9054421768977798
# Training accuracy ... 1.0
# EPOCHS ... 413
# Validation accuracy ... 0.9031746032016348
# Training accuracy ... 1.0
# EPOCHS ... 414
# Validation accuracy ... 0.8997732429007014
# Training accuracy ... 1.0
# EPOCHS ... 415
# Validation accuracy ... 0.8965986397260982
# Training accuracy ... 1.0
# EPOCHS ... 416
# Validation accuracy ... 0.9004535150095448
# Training accuracy ... 1.0
# EPOCHS ... 417
# Validation accuracy ... 0.898866213178959
# Training accuracy ... 0.800000011920929
# EPOCHS ... 418
# Validation accuracy ... 0.89841269843973
# Training accuracy ... 0.800000011920929
# EPOCHS ... 419
# Validation accuracy ... 0.8988662134492749
# Training accuracy ... 0.800000011920929
# EPOCHS ... 420
# Validation accuracy ... 0.89954648558515
# Training accuracy ... 0.800000011920929
# EPOCHS ... 421
# Validation accuracy ... 0.9011337866318199
# Training accuracy ... 0.800000011920929
# EPOCHS ... 422
# Validation accuracy ... 0.8941043086873701
# Training accuracy ... 1.0
# EPOCHS ... 423
# Validation accuracy ... 0.8879818591671466
# Training accuracy ... 1.0
# EPOCHS ... 424
# Validation accuracy ... 0.8841269843973
# Training accuracy ... 1.0
# EPOCHS ... 425
# Validation accuracy ... 0.8829931972789116
# Training accuracy ... 1.0
# EPOCHS ... 426
# Validation accuracy ... 0.8850340136054422
# Training accuracy ... 1.0
# EPOCHS ... 427
# Validation accuracy ... 0.8875283449415177
# Training accuracy ... 1.0
# EPOCHS ... 428
# Validation accuracy ... 0.8941043086603385
# Training accuracy ... 1.0
# EPOCHS ... 429
# Validation accuracy ... 0.8975056689342403
# Training accuracy ... 1.0
# EPOCHS ... 430
# Validation accuracy ... 0.898639455782313
# Training accuracy ... 1.0
# EPOCHS ... 431
# Validation accuracy ... 0.899546485260771
# Training accuracy ... 1.0
# EPOCHS ... 432
# Validation accuracy ... 0.9022675736961451
# Training accuracy ... 1.0
# EPOCHS ... 433
# Validation accuracy ... 0.9086167800723831
# Training accuracy ... 1.0
# EPOCHS ... 434
# Validation accuracy ... 0.906802721115467
# Training accuracy ... 1.0
# EPOCHS ... 435
# Validation accuracy ... 0.9018140587136318
# Training accuracy ... 1.0
# EPOCHS ... 436
# Validation accuracy ... 0.8999999997567157
# Training accuracy ... 1.0
# EPOCHS ... 437
# Validation accuracy ... 0.9056689339970786
# Training accuracy ... 1.0
# EPOCHS ... 438
# Validation accuracy ... 0.9061224492499077
# Training accuracy ... 1.0
# EPOCHS ... 439
# Validation accuracy ... 0.9038548752834467
# Training accuracy ... 1.0
# EPOCHS ... 440
# Validation accuracy ... 0.9031746031746032
# Training accuracy ... 1.0
# EPOCHS ... 441
# Validation accuracy ... 0.9102040816326531
# Training accuracy ... 1.0
# EPOCHS ... 442
# Validation accuracy ... 0.9183673469387755
# Training accuracy ... 1.0
# EPOCHS ... 443
# Validation accuracy ... 0.9226757369614512
# Training accuracy ... 1.0
# EPOCHS ... 444
# Validation accuracy ... 0.9256235827664399
# Training accuracy ... 1.0
# EPOCHS ... 445
# Validation accuracy ... 0.9253968251535412
# Training accuracy ... 1.0
# EPOCHS ... 446
# Validation accuracy ... 0.9217687072397089
# Training accuracy ... 1.0
# EPOCHS ... 447
# Validation accuracy ... 0.9156462587737172
# Training accuracy ... 1.0
# EPOCHS ... 448
# Validation accuracy ... 0.9083900229460528
# Training accuracy ... 1.0
# EPOCHS ... 449
# Validation accuracy ... 0.908843537414966
# Training accuracy ... 1.0
# EPOCHS ... 450
# Validation accuracy ... 0.9086167803156673
# Training accuracy ... 1.0
# EPOCHS ... 451
# Validation accuracy ... 0.9077097508372093
# Training accuracy ... 1.0
# EPOCHS ... 452
# Validation accuracy ... 0.9081632655764383
# Training accuracy ... 1.0
# EPOCHS ... 453
# Validation accuracy ... 0.9122448982294995
# Training accuracy ... 1.0
# EPOCHS ... 454
# Validation accuracy ... 0.9165532882521753
# Training accuracy ... 1.0
# EPOCHS ... 455
# Validation accuracy ... 0.9149659866648737
# Training accuracy ... 1.0
# EPOCHS ... 456
# Validation accuracy ... 0.9081632653331541
# Training accuracy ... 1.0
# EPOCHS ... 457
# Validation accuracy ... 0.9047619050592522
# Training accuracy ... 1.0
# EPOCHS ... 458
# Validation accuracy ... 0.907029478512113
# Training accuracy ... 1.0
# EPOCHS ... 459
# Validation accuracy ... 0.9088435371987134
# Training accuracy ... 1.0
# EPOCHS ... 460
# Validation accuracy ... 0.9106575961556294
# Training accuracy ... 1.0
# EPOCHS ... 461
# Validation accuracy ... 0.9138321998438327
# Training accuracy ... 1.0
# EPOCHS ... 462
# Validation accuracy ... 0.9131519271943574
# Training accuracy ... 1.0
# EPOCHS ... 463
# Validation accuracy ... 0.9088435376852818
# Training accuracy ... 1.0
# EPOCHS ... 464
# Validation accuracy ... 0.9056689342403628
# Training accuracy ... 1.0
# EPOCHS ... 465
# Validation accuracy ... 0.9029478458049887
# Training accuracy ... 1.0
# EPOCHS ... 466
# Validation accuracy ... 0.9006802721088435
# Training accuracy ... 1.0
# EPOCHS ... 467
# Validation accuracy ... 0.9061224492499077
# Training accuracy ... 1.0
# EPOCHS ... 468
# Validation accuracy ... 0.9056689339970786
# Training accuracy ... 1.0
# EPOCHS ... 469
# Validation accuracy ... 0.9061224490066234
# Training accuracy ... 1.0
# EPOCHS ... 470
# Validation accuracy ... 0.9113378685077572
# Training accuracy ... 1.0
# EPOCHS ... 471
# Validation accuracy ... 0.9154195011608184
# Training accuracy ... 1.0
# EPOCHS ... 472
# Validation accuracy ... 0.9113378685077572
# Training accuracy ... 1.0
# EPOCHS ... 473
# Validation accuracy ... 0.9088435371716818
# Training accuracy ... 1.0
# EPOCHS ... 474
# Validation accuracy ... 0.9102040816326531
# Training accuracy ... 1.0
# EPOCHS ... 475
# Validation accuracy ... 0.8988662131519274
# Training accuracy ... 1.0
# EPOCHS ... 476
# Validation accuracy ... 0.8938775510204081
# Training accuracy ... 1.0
# EPOCHS ... 477
# Validation accuracy ... 0.8975056692045562
# Training accuracy ... 1.0
# EPOCHS ... 478
# Validation accuracy ... 0.9029478460753045
# Training accuracy ... 1.0
# EPOCHS ... 479
# Validation accuracy ... 0.9099773245603859
# Training accuracy ... 1.0
# EPOCHS ... 480
# Validation accuracy ... 0.9088435377123134
# Training accuracy ... 1.0
# EPOCHS ... 481
# Validation accuracy ... 0.904308389806423
# Training accuracy ... 1.0
# EPOCHS ... 482
# Validation accuracy ... 0.9090702945683278
# Training accuracy ... 1.0
# EPOCHS ... 483
# Validation accuracy ... 0.9104308387860149
# Training accuracy ... 1.0
# EPOCHS ... 484
# Validation accuracy ... 0.9115646261476875
# Training accuracy ... 1.0
# EPOCHS ... 485
# Validation accuracy ... 0.9138321998438327
# Training accuracy ... 1.0
# EPOCHS ... 486
# Validation accuracy ... 0.9133786848342879
# Training accuracy ... 1.0
# EPOCHS ... 487
# Validation accuracy ... 0.9117913832469863
# Training accuracy ... 1.0
# EPOCHS ... 488
# Validation accuracy ... 0.910884354038844
# Training accuracy ... 1.0
# EPOCHS ... 489
# Validation accuracy ... 0.9090702945683278
# Training accuracy ... 1.0
# EPOCHS ... 490
# Validation accuracy ... 0.8986394555660603
# Training accuracy ... 1.0
# EPOCHS ... 491
# Validation accuracy ... 0.891836734991225
# Training accuracy ... 0.800000011920929
# EPOCHS ... 492
# Validation accuracy ... 0.8879818597077783
# Training accuracy ... 0.800000011920929
# EPOCHS ... 493
# Validation accuracy ... 0.8916099771080104
# Training accuracy ... 0.800000011920929
# EPOCHS ... 494
# Validation accuracy ... 0.8943310658137004
# Training accuracy ... 0.800000011920929
# EPOCHS ... 495
# Validation accuracy ... 0.9006802721629067
# Training accuracy ... 1.0
# EPOCHS ... 496
# Validation accuracy ... 0.907936508260887
# Training accuracy ... 1.0
# EPOCHS ... 497
# Validation accuracy ... 0.9136054422309339
# Training accuracy ... 1.0
# EPOCHS ... 498
# Validation accuracy ... 0.911791383003702
# Training accuracy ... 1.0
# EPOCHS ... 499
# Validation accuracy ... 0.910884354038844
# Training accuracy ... 1.0
# EPOCHS ... 500
# Validation accuracy ... 0.9133786848342879
# Training accuracy ... 1.0
# EPOCHS ... 501
# Validation accuracy ... 0.9140589569431313
# Training accuracy ... 1.0
# EPOCHS ... 502
# Validation accuracy ... 0.9149659864215894
# Training accuracy ... 1.0
# EPOCHS ... 503
# Validation accuracy ... 0.9131519274646733
# Training accuracy ... 1.0
# EPOCHS ... 504
# Validation accuracy ... 0.9115646261476875
# Training accuracy ... 1.0
# EPOCHS ... 505
# Validation accuracy ... 0.911791383517302
# Training accuracy ... 1.0
# EPOCHS ... 506
# Validation accuracy ... 0.910884354038844
# Training accuracy ... 1.0
# EPOCHS ... 507
# Validation accuracy ... 0.9163265309095924
# Training accuracy ... 1.0
# EPOCHS ... 508
# Validation accuracy ... 0.9140589572134472
# Training accuracy ... 1.0
# EPOCHS ... 509
# Validation accuracy ... 0.907482993521658
# Training accuracy ... 1.0
# EPOCHS ... 510
# Validation accuracy ... 0.9058956913937246
# Training accuracy ... 1.0
# EPOCHS ... 511
# Validation accuracy ... 0.8961451247435849
# Training accuracy ... 0.800000011920929
# EPOCHS ... 512
# Validation accuracy ... 0.8913832199816801
# Training accuracy ... 0.800000011920929
# EPOCHS ... 513
# Validation accuracy ... 0.8959183673739703
# Training accuracy ... 0.800000011920929
# EPOCHS ... 514
# Validation accuracy ... 0.8975056689612719
# Training accuracy ... 0.800000011920929
# EPOCHS ... 515
# Validation accuracy ... 0.9070294784850814
# Training accuracy ... 1.0
# EPOCHS ... 516
# Validation accuracy ... 0.9138321998438327
# Training accuracy ... 1.0
# EPOCHS ... 517
# Validation accuracy ... 0.9133786848342879
# Training accuracy ... 1.0
# EPOCHS ... 518
# Validation accuracy ... 0.9117913834902704
# Training accuracy ... 1.0
# EPOCHS ... 519
# Validation accuracy ... 0.9054421768707483
# Training accuracy ... 1.0
# EPOCHS ... 520
# Validation accuracy ... 0.9002267573696145
# Training accuracy ... 1.0
# EPOCHS ... 521
# Validation accuracy ... 0.9043083900226757
# Training accuracy ... 1.0
# EPOCHS ... 522
# Validation accuracy ... 0.9063492063492063
# Training accuracy ... 1.0
# EPOCHS ... 523
# Validation accuracy ... 0.901360544488003
# Training accuracy ... 1.0
# EPOCHS ... 524
# Validation accuracy ... 0.8961451249868692
# Training accuracy ... 1.0
# EPOCHS ... 525
# Validation accuracy ... 0.8947845802555819
# Training accuracy ... 1.0
# EPOCHS ... 526
# Validation accuracy ... 0.8965986394828139
# Training accuracy ... 1.0
# EPOCHS ... 527
# Validation accuracy ... 0.9022675734798924
# Training accuracy ... 1.0
# EPOCHS ... 528
# Validation accuracy ... 0.9052154197984812
# Training accuracy ... 1.0
# EPOCHS ... 529
# Validation accuracy ... 0.9079365082338554
# Training accuracy ... 1.0
# EPOCHS ... 530
# Validation accuracy ... 0.9040816329504087
# Training accuracy ... 1.0
# EPOCHS ... 531
# Validation accuracy ... 0.9074829934946264
# Training accuracy ... 1.0
# EPOCHS ... 532
# Validation accuracy ... 0.9156462585574645
# Training accuracy ... 1.0
# EPOCHS ... 533
# Validation accuracy ... 0.9170068025318674
# Training accuracy ... 1.0
# EPOCHS ... 534
# Validation accuracy ... 0.9142857146100933
# Training accuracy ... 1.0
# EPOCHS ... 535
# Validation accuracy ... 0.9138321993302326
# Training accuracy ... 1.0
# EPOCHS ... 536
# Validation accuracy ... 0.9154195014311343
# Training accuracy ... 1.0
# EPOCHS ... 537
# Validation accuracy ... 0.9163265309095924
# Training accuracy ... 1.0
# EPOCHS ... 538
# Validation accuracy ... 0.9183673469658071
# Training accuracy ... 1.0
# EPOCHS ... 539
# Validation accuracy ... 0.9190476190746506
# Training accuracy ... 1.0
# EPOCHS ... 540
# Validation accuracy ... 0.9185941043354217
# Training accuracy ... 1.0
# EPOCHS ... 541
# Validation accuracy ... 0.9192743761739492
# Training accuracy ... 1.0
# EPOCHS ... 542
# Validation accuracy ... 0.9142857145560301
# Training accuracy ... 1.0
# EPOCHS ... 543
# Validation accuracy ... 0.9086167803156673
# Training accuracy ... 1.0
# EPOCHS ... 544
# Validation accuracy ... 0.9056689345106786
# Training accuracy ... 1.0
# EPOCHS ... 545
# Validation accuracy ... 0.9024943313360755
# Training accuracy ... 1.0
# EPOCHS ... 546
# Validation accuracy ... 0.9024943308224753
# Training accuracy ... 1.0
# EPOCHS ... 547
# Validation accuracy ... 0.9104308387589833
# Training accuracy ... 0.800000011920929
# EPOCHS ... 548
# Validation accuracy ... 0.9156462582601171
# Training accuracy ... 0.800000011920929
# EPOCHS ... 549
# Validation accuracy ... 0.9115646256070559
# Training accuracy ... 0.800000011920929
# EPOCHS ... 550
# Validation accuracy ... 0.9111111108678268
# Training accuracy ... 0.800000011920929
# EPOCHS ... 551
# Validation accuracy ... 0.9174603172170332
# Training accuracy ... 1.0
# EPOCHS ... 552
# Validation accuracy ... 0.9170068024778042
# Training accuracy ... 1.0
# EPOCHS ... 553
# Validation accuracy ... 0.9136054419335865
# Training accuracy ... 1.0
# EPOCHS ... 554
# Validation accuracy ... 0.904535147149006
# Training accuracy ... 1.0
# EPOCHS ... 555
# Validation accuracy ... 0.9056689345106786
# Training accuracy ... 1.0
# EPOCHS ... 556
# Validation accuracy ... 0.9077097508372093
# Training accuracy ... 1.0
# EPOCHS ... 557
# Validation accuracy ... 0.9092970524245109
# Training accuracy ... 1.0
# EPOCHS ... 558
# Validation accuracy ... 0.9099773242630386
# Training accuracy ... 1.0
# EPOCHS ... 559
# Validation accuracy ... 0.9081632656034699
# Training accuracy ... 1.0
# EPOCHS ... 560
# Validation accuracy ... 0.9079365077202552
# Training accuracy ... 1.0
# EPOCHS ... 561
# Validation accuracy ... 0.9040816324368085
# Training accuracy ... 1.0
# EPOCHS ... 562
# Validation accuracy ... 0.9013605439744028
# Training accuracy ... 1.0
# EPOCHS ... 563
# Validation accuracy ... 0.8952380952380953
# Training accuracy ... 1.0
# EPOCHS ... 564
# Validation accuracy ... 0.8963718820861678
# Training accuracy ... 1.0
# EPOCHS ... 565
# Validation accuracy ... 0.9040816326530612
# Training accuracy ... 1.0
# EPOCHS ... 566
# Validation accuracy ... 0.9154195011337869
# Training accuracy ... 1.0
# EPOCHS ... 567
# Validation accuracy ... 0.9126984126984127
# Training accuracy ... 1.0
# EPOCHS ... 568
# Validation accuracy ... 0.9074829931972789
# Training accuracy ... 1.0
# EPOCHS ... 569
# Validation accuracy ... 0.9058956916099773
# Training accuracy ... 1.0
# EPOCHS ... 570
# Validation accuracy ... 0.9154195011337869
# Training accuracy ... 1.0
# EPOCHS ... 571
# Validation accuracy ... 0.918140589569161
# Training accuracy ... 1.0
# EPOCHS ... 572
# Validation accuracy ... 0.9156462582601171
# Training accuracy ... 1.0
# EPOCHS ... 573
# Validation accuracy ... 0.913832199303201
# Training accuracy ... 1.0
# EPOCHS ... 574
# Validation accuracy ... 0.91428571404243
# Training accuracy ... 1.0
# EPOCHS ... 575
# Validation accuracy ... 0.9133786848342879
# Training accuracy ... 1.0
# EPOCHS ... 576
# Validation accuracy ... 0.916099773269662
# Training accuracy ... 1.0
# EPOCHS ... 577
# Validation accuracy ... 0.9126984127254443
# Training accuracy ... 1.0
# EPOCHS ... 578
# Validation accuracy ... 0.9145124716823604
# Training accuracy ... 1.0
# EPOCHS ... 579
# Validation accuracy ... 0.9181405895961926
# Training accuracy ... 1.0
# EPOCHS ... 580
# Validation accuracy ... 0.9183673466954912
# Training accuracy ... 1.0
# EPOCHS ... 581
# Validation accuracy ... 0.9131519271943574
# Training accuracy ... 1.0
# EPOCHS ... 582
# Validation accuracy ... 0.9117913829766704
# Training accuracy ... 1.0
# EPOCHS ... 583
# Validation accuracy ... 0.9129251698247429
# Training accuracy ... 1.0
# EPOCHS ... 584
# Validation accuracy ... 0.9120181403462849
# Training accuracy ... 1.0
# EPOCHS ... 585
# Validation accuracy ... 0.911111111381427
# Training accuracy ... 1.0
# EPOCHS ... 586
# Validation accuracy ... 0.909297052154195
# Training accuracy ... 1.0
# EPOCHS ... 587
# Validation accuracy ... 0.9092970524245109
# Training accuracy ... 1.0
# EPOCHS ... 588
# Validation accuracy ... 0.9156462587737172
# Training accuracy ... 1.0
# EPOCHS ... 589
# Validation accuracy ... 0.9176870751002478
# Training accuracy ... 1.0
# EPOCHS ... 590
# Validation accuracy ... 0.9192743766875494
# Training accuracy ... 1.0
# EPOCHS ... 591
# Validation accuracy ... 0.9185941045787058
# Training accuracy ... 1.0
# EPOCHS ... 592
# Validation accuracy ... 0.914739228781659
# Training accuracy ... 1.0
# EPOCHS ... 593
# Validation accuracy ... 0.9090702948116121
# Training accuracy ... 1.0
# EPOCHS ... 594
# Validation accuracy ... 0.904535147149006
# Training accuracy ... 1.0
# EPOCHS ... 595
# Validation accuracy ... 0.8975056689612719
# Training accuracy ... 1.0
# EPOCHS ... 596
# Validation accuracy ... 0.8972789118349417
# Training accuracy ... 1.0
# EPOCHS ... 597
# Validation accuracy ... 0.9047619045186205
# Training accuracy ... 1.0
# EPOCHS ... 598
# Validation accuracy ... 0.9126984124551284
# Training accuracy ... 1.0
# EPOCHS ... 599
# Validation accuracy ... 0.9185941040651058
# Training accuracy ... 1.0
# EPOCHS ... 600
# Validation accuracy ... 0.9204081630220219
# Training accuracy ... 1.0
# EPOCHS ... 601
# Validation accuracy ... 0.9199546482827928
# Training accuracy ... 1.0
# EPOCHS ... 602
# Validation accuracy ... 0.9188208614347203
# Training accuracy ... 1.0
# EPOCHS ... 603
# Validation accuracy ... 0.9195011335435638
# Training accuracy ... 1.0
# EPOCHS ... 604
# Validation accuracy ... 0.9208616780045351
# Training accuracy ... 1.0
# EPOCHS ... 605
# Validation accuracy ... 0.9206349206349206
# Training accuracy ... 1.0
# EPOCHS ... 606
# Validation accuracy ... 0.9204081632653062
# Training accuracy ... 1.0
# EPOCHS ... 607
# Validation accuracy ... 0.9167800456217897
# Training accuracy ... 1.0
# EPOCHS ... 608
# Validation accuracy ... 0.9142857145560301
# Training accuracy ... 1.0
# EPOCHS ... 609
# Validation accuracy ... 0.9165532882521753
# Training accuracy ... 1.0
# EPOCHS ... 610
# Validation accuracy ... 0.9210884356444655
# Training accuracy ... 1.0
# EPOCHS ... 611
# Validation accuracy ... 0.9231292519709962
# Training accuracy ... 1.0
# EPOCHS ... 612
# Validation accuracy ... 0.9258503404063703
# Training accuracy ... 1.0
# EPOCHS ... 613
# Validation accuracy ... 0.929705215689817
# Training accuracy ... 1.0
# EPOCHS ... 614
# Validation accuracy ... 0.9321995464852608
# Training accuracy ... 1.0
# Model saved

# %%
plt.subplot(2,1,1)
plt.plot(accuracy_plot)
plt.show()
plt.subplot(2,1,2)
plt.plot(training_accuracy_plot)
plt.show()

# %%
#print hyper parameters
print("EPOCHS",EPOCH)
print("rate",rate)
print("mu",global_mu)
print("sigma",global_sigma)
print("batch size",BATCH_SIZE)
print("Max validation accuracy achieved", max(accuracy_plot))
# Out:
# EPOCHS 1000
# rate 0.008
# mu 0.0
# sigma 0.1
# batch size 256
# Max validation accuracy achieved 0.932199546485

# %%
label_names=["Speed limit (20km/h)","Speed limit (30km/h)","Speed limit (50km/h)","Speed limit (60km/h)","Speed limit (70km/h)","Speed limit (80km/h)","End of speed limit (80km/h)","Speed limit (100km/h)","Speed limit (120km/h)","No passing","No passing for vehicles over 3.5 metric tons","Right-of-way at the next intersection","Priority road","Yield","Stop","No vehicles","Vehicles over 3.5 metric tons prohibited","No entry","General caution","Dangerous curve to the left","Dangerous curve to the right","Double curve","Bumpy road","Slippery road","Road narrows on the right","Road work","Traffic signals","Pedestrians","Children crossing","Bicycles crossing","Beware of ice/snow","Wild animals crossing","End of all speed and passing limits","Turn right ahead","Turn left ahead","Ahead only","Go straight or right","Go straight or left","Keep right","Keep left","Roundabout mandatory","End of no passing","End of no passing by vehicles over 3.5 metric tons",
]

# %% [markdown]
# ---
#
# ## Step 3: Test a Model on New Images
#
# To give yourself more insight into how your model is working, download at least five pictures of German traffic signs from the web and use your model to predict the traffic sign type.
#
# You may find `signnames.csv` useful as it contains mappings from the class id (integer) to the actual sign name.

# %% [markdown]
# ### Load and Output the Images

# %%
#Loaded before training

# %% [markdown]
# ### Predict the Sign Type for Each Image

# %%
def get_softmax_probs(X_data, sess): 
    prob = sess.run(tf.nn.softmax(logits), feed_dict={x: X_data, keep_prob: 1.0})    
    top_5 = tf.nn.top_k(prob, k=5)
    return sess.run(top_5)


with tf.Session() as sess:
    saver.restore(sess, './lenet')
    signs_top_5=get_softmax_probs(test_images_processed, sess)

plt.figure(figsize=(16, 21))
for i in range(5):
    plt.subplot(12, 2, 2*i+1)
    plt.imshow(np.reshape(test_images_processed[i],(32,32)),cmap='gray' )
    plt.title(i)
    plt.axis('off')
    plt.subplot(12, 2, 2*i+2)
    plt.barh(np.arange(1, 6, 1), signs_top_5.values[i, :])
    labs=[label_names[j] for j in signs_top_5.indices[i]]
    plt.yticks(np.arange(1, 6, 1), labs)
plt.show()

# %% [markdown]
# ### Analyze Performance

# %%
### Calculate the accuracy for these 5 new images. 
### For example, if the model predicted 1 out of 5 signs correctly, it's 20% accurate on these new images.
print (training_accuracy_plot[-1] * 100)
# Out:
# 100.0

# %% [markdown]
# ### Output Top 5 Softmax Probabilities For Each Image Found on the Web

# %% [markdown]
# For each of the new images, print out the model's softmax probabilities to show the **certainty** of the model's predictions (limit the output to the top 5 probabilities for each image). [`tf.nn.top_k`](https://www.tensorflow.org/versions/r0.12/api_docs/python/nn.html#top_k) could prove helpful here.
#
# The example below demonstrates how tf.nn.top_k can be used to find the top k predictions for each image.
#
# `tf.nn.top_k` will return the values and indices (class ids) of the top k predictions. So if k=3, for each sign, it'll return the 3 largest probabilities (out of a possible 43) and the correspoding class ids.
#
# Take this numpy array as an example. The values in the array represent predictions. The array contains softmax probabilities for five candidate images with six possible classes. `tk.nn.top_k` is used to choose the three classes with the highest probability:
#
# ```
# # (5, 6) array
# a = np.array([[ 0.24879643,  0.07032244,  0.12641572,  0.34763842,  0.07893497,
#          0.12789202],
#        [ 0.28086119,  0.27569815,  0.08594638,  0.0178669 ,  0.18063401,
#          0.15899337],
#        [ 0.26076848,  0.23664738,  0.08020603,  0.07001922,  0.1134371 ,
#          0.23892179],
#        [ 0.11943333,  0.29198961,  0.02605103,  0.26234032,  0.1351348 ,
#          0.16505091],
#        [ 0.09561176,  0.34396535,  0.0643941 ,  0.16240774,  0.24206137,
#          0.09155967]])
# ```
#
# Running it through `sess.run(tf.nn.top_k(tf.constant(a), k=3))` produces:
#
# ```
# TopKV2(values=array([[ 0.34763842,  0.24879643,  0.12789202],
#        [ 0.28086119,  0.27569815,  0.18063401],
#        [ 0.26076848,  0.23892179,  0.23664738],
#        [ 0.29198961,  0.26234032,  0.16505091],
#        [ 0.34396535,  0.24206137,  0.16240774]]), indices=array([[3, 0, 5],
#        [0, 1, 4],
#        [0, 5, 1],
#        [1, 3, 5],
#        [1, 4, 3]], dtype=int32))
# ```
#
# Looking just at the first row we get `[ 0.34763842,  0.24879643,  0.12789202]`, you can confirm these are the 3 largest probabilities in `a`. You'll also notice `[3, 0, 5]` are the corresponding indices.

# %%
### Print out the top five softmax probabilities for the predictions on the German traffic sign images found on the web. 
### Feel free to use as many code cells as needed.

# %% [markdown]
# ---
#
# ## Step 4: Visualize the Neural Network's State with Test Images
#
#  This Section is not required to complete but acts as an additional excersise for understaning the output of a neural network's weights. While neural networks can be a great learning device they are often referred to as a black box. We can understand what the weights of a neural network look like better by plotting their feature maps. After successfully training your neural network you can see what it's feature maps look like by plotting the output of the network's weight layers in response to a test stimuli image. From these plotted feature maps, it's possible to see what characteristics of an image the network finds interesting. For a sign, maybe the inner network feature maps react with high activation to the sign's boundary outline or to the contrast in the sign's painted symbol.
#
#  Provided for you below is the function code that allows you to get the visualization output of any tensorflow weight layer you want. The inputs to the function should be a stimuli image, one used during training or a new one you provided, and then the tensorflow variable name that represents the layer's state during the training process, for instance if you wanted to see what the [LeNet lab's](https://classroom.udacity.com/nanodegrees/nd013/parts/fbf77062-5703-404e-b60c-95b78b2f3f9e/modules/6df7ae49-c61c-4bb2-a23e-6527e69209ec/lessons/601ae704-1035-4287-8b11-e2c2716217ad/concepts/d4aca031-508f-4e0b-b493-e7b706120f81) feature maps looked like for it's second convolutional layer you could enter conv2 as the tf_activation variable.
#
# For an example of what feature map outputs look like, check out NVIDIA's results in their paper [End-to-End Deep Learning for Self-Driving Cars](https://devblogs.nvidia.com/parallelforall/deep-learning-self-driving-cars/) in the section Visualization of internal CNN State. NVIDIA was able to show that their network's inner weights had high activations to road boundary lines by comparing feature maps from an image with a clear path to one without. Try experimenting with a similar test to show that your trained network's weights are looking for interesting features, whether it's looking at differences in feature maps from images with or without a sign, or even what feature maps look like in a trained network vs a completely untrained one on the same sign image.
#
# <figure>
#  <img src="visualize_cnn.png" width="380" alt="Combined Image" />
#  <figcaption>
#  <p></p>
#  <p style="text-align: center;"> Your output should look something like this (above)</p>
#  </figcaption>
# </figure>
#  <p></p>

# %%
### Visualize your network's feature maps here.
### Feel free to use as many code cells as needed.

# image_input: the test image being fed into the network to produce the feature maps
# tf_activation: should be a tf variable name used during your training procedure that represents the calculated state of a specific weight layer
# activation_min/max: can be used to view the activation contrast in more detail, by default matplot sets min and max to the actual min and max values of the output
# plt_num: used to plot out multiple different weight feature map sets on the same block, just extend the plt number for each new feature map entry

def outputFeatureMap(image_input, tf_activation, activation_min=-1, activation_max=-1 ,plt_num=1):
    # Here make sure to preprocess your image_input in a way your network expects
    # with size, normalization, ect if needed
    # image_input =
    # Note: x should be the same name as your network's tensorflow data placeholder variable
    # If you get an error tf_activation is not defined it maybe having trouble accessing the variable from inside a function
    activation = tf_activation.eval(session=sess,feed_dict={x : image_input})
    featuremaps = activation.shape[3]
    plt.figure(plt_num, figsize=(15,15))
    for featuremap in range(featuremaps):
        plt.subplot(6,8, featuremap+1) # sets the number of feature maps to show on each row and column
        plt.title('FeatureMap ' + str(featuremap)) # displays the feature map number
        if activation_min != -1 & activation_max != -1:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", vmin =activation_min, vmax=activation_max, cmap="gray")
        elif activation_max != -1:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", vmax=activation_max, cmap="gray")
        elif activation_min !=-1:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", vmin=activation_min, cmap="gray")
        else:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", cmap="gray")

# %% [markdown]
# ### Question 9
#
# Discuss how you used the visual output of your trained network's feature maps to show that it had learned to look for interesting characteristics in traffic sign images

# %% [markdown]
# **Answer:**

# %% [markdown]
# > **Note**: Once you have completed all of the code implementations and successfully answered each question above, you may finalize your work by exporting the iPython Notebook as an HTML document. You can do this by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.

# %% [markdown]
# ### Project Writeup
#
# Once you have completed the code implementation, document your results in a project writeup using this [template](https://github.com/udacity/CarND-Traffic-Sign-Classifier-Project/blob/master/writeup_template.md) as a guide. The writeup can be in a markdown or pdf file.
