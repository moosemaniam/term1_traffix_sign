# %% [markdown]
# # Self-Driving Car Engineer Nanodegree
#
# ## Deep Learning
#
# ## Project: Build a Traffic Sign Recognition Classifier
#
# In this notebook, a template is provided for you to implement your functionality in stages, which is required to successfully complete this project. If additional code is required that cannot be included in the notebook, be sure that the Python code is successfully imported and included in your submission if necessary.
#
# > **Note**: Once you have completed all of the code implementations, you need to finalize your work by exporting the iPython Notebook as an HTML document. Before exporting the notebook to html, all of the code cells need to have been run so that reviewers can see the final implementation and output. You can then export the notebook by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
#
# In addition to implementing code, there is a writeup to complete. The writeup should be completed in a separate file, which can be either a markdown file or a pdf document. There is a [write up template](https://github.com/udacity/CarND-Traffic-Sign-Classifier-Project/blob/master/writeup_template.md) that can be used to guide the writing process. Completing the code template and writeup template will cover all of the [rubric points](https://review.udacity.com/#!/rubrics/481/view) for this project.
#
# The [rubric](https://review.udacity.com/#!/rubrics/481/view) contains "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. The stand out suggestions are optional. If you decide to pursue the "stand out suggestions", you can include the code in this Ipython notebook and also discuss the results in the writeup file.
#
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut. In addition, Markdown cells can be edited by typically double-clicking the cell to enter edit mode.

# %% [markdown]
# ---
# ## Step 0: Load The Data

# %%
# Load pickled data
import pickle

# TODO: Fill this in based on where you saved the training and testing data

training_file = "./trafficSignData/train.p"
validation_file="./trafficSignData/valid.p"
testing_file ="./trafficSignData/test.p"

with open(training_file, mode='rb') as f:
    train = pickle.load(f)
with open(validation_file, mode='rb') as f:
    valid = pickle.load(f)
with open(testing_file, mode='rb') as f:
    test = pickle.load(f)
    
X_train, y_train = train['features'], train['labels']
X_valid, y_valid = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %% [markdown]
# ---
#
# ## Step 1: Dataset Summary & Exploration
#
# The pickled data is a dictionary with 4 key/value pairs:
#
# - `'features'` is a 4D array containing raw pixel data of the traffic sign images, (num examples, width, height, channels).
# - `'labels'` is a 1D array containing the label/class id of the traffic sign. The file `signnames.csv` contains id -> name mappings for each id.
# - `'sizes'` is a list containing tuples, (width, height) representing the original width and height the image.
# - `'coords'` is a list containing tuples, (x1, y1, x2, y2) representing coordinates of a bounding box around the sign in the image. **THESE COORDINATES ASSUME THE ORIGINAL IMAGE. THE PICKLED DATA CONTAINS RESIZED VERSIONS (32 by 32) OF THESE IMAGES**
#
# Complete the basic data summary below. Use python, numpy and/or pandas methods to calculate the data summary rather than hard coding the results. For example, the [pandas shape method](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.shape.html) might be useful for calculating some of the summary results.

# %% [markdown]
# ### Provide a Basic Summary of the Data Set Using Python, Numpy and/or Pandas

# %%
### Replace each question mark with the appropriate value. 
### Use python, pandas or numpy methods rather than hard coding the results
# TODO: Number of training examples
n_train = len(X_train)

# TODO: Number of testing examples.
n_test = len(X_test)

# TODO: What's the shape of an traffic sign image?
image_shape = X_train[0].shape

# TODO: How many unique classes/labels there are in the dataset.
#Go through all unique labels in the training set
unique_label=[]

for label in y_test:
    if label not in unique_label:
        unique_label.append(label)
        
n_classes = len(unique_label)

print("Number of training examples =", n_train)
print("Number of testing examples =", n_test)
print("Image data shape =", image_shape)
print("Number of classes =", n_classes)
# Out:
# Number of training examples = 34799
# Number of testing examples = 12630
# Image data shape = (32, 32, 3)
# Number of classes = 43

# %% [markdown]
# ### Include an exploratory visualization of the dataset

# %% [markdown]
# Visualize the German Traffic Signs Dataset using the pickled file(s). This is open ended, suggestions include: plotting traffic sign images, plotting the count of each sign, etc.
#
# The [Matplotlib](http://matplotlib.org/) [examples](http://matplotlib.org/examples/index.html) and [gallery](http://matplotlib.org/gallery.html) pages are a great resource for doing visualizations in Python.
#
# **NOTE:** It's recommended you start with something simple first. If you wish to do more, come back to it after you've completed the rest of the sections.

# %%
### Data exploration visualization code goes here.
### Feel free to use as many code cells as needed.
import matplotlib.pyplot as plt
# Visualizations will be shown in the notebook.
# %matplotlib inline

### Data exploration visualization code goes here.
### Feel free to use as many code cells as needed.
import matplotlib.pyplot as plt
# Visualizations will be shown in the notebook.
# %matplotlib inline
#img_id = 43
#image = X_train[img_id]
#image_label = y_train[img_id]
#img_plot = plt.imshow(image)
#print("imagenumber",img_id,"traffic label:",image_label)

num_of_samples=[]
plt.figure(figsize=(12, 16.5))
for i in range(0, n_classes):
    plt.subplot(11, 4, i+1)
    x_selected = X_train[y_train == i]
    plt.imshow(x_selected[0, :, :, :]) 
    plt.axis('off')
    num_of_samples.append(len(x_selected))
plt.show()

# %% [markdown]
# ----
#
# ## Step 2: Design and Test a Model Architecture
#
# Design and implement a deep learning model that learns to recognize traffic signs. Train and test your model on the [German Traffic Sign Dataset](http://benchmark.ini.rub.de/?section=gtsrb&subsection=dataset).
#
# The LeNet-5 implementation shown in the [classroom](https://classroom.udacity.com/nanodegrees/nd013/parts/fbf77062-5703-404e-b60c-95b78b2f3f9e/modules/6df7ae49-c61c-4bb2-a23e-6527e69209ec/lessons/601ae704-1035-4287-8b11-e2c2716217ad/concepts/d4aca031-508f-4e0b-b493-e7b706120f81) at the end of the CNN lesson is a solid starting point. You'll have to change the number of classes and possibly the preprocessing, but aside from that it's plug and play!
#
# With the LeNet-5 solution from the lecture, you should expect a validation set accuracy of about 0.89. To meet specifications, the validation set accuracy will need to be at least 0.93. It is possible to get an even higher accuracy, but 0.93 is the minimum for a successful project submission.
#
# There are various aspects to consider when thinking about this problem:
#
# - Neural network architecture (is the network over or underfitting?)
# - Play around preprocessing techniques (normalization, rgb to grayscale, etc)
# - Number of examples per label (some have more than others).
# - Generate fake data.
#
# Here is an example of a [published baseline model on this problem](http://yann.lecun.com/exdb/publis/pdf/sermanet-ijcnn-11.pdf). It's not required to be familiar with the approach used in the paper but, it's good practice to try to read papers like these.

# %% [markdown]
# ### Pre-process the Data Set (normalization, grayscale, etc.)

# %% [markdown]
# Use the code cell (or multiple code cells, if necessary) to implement the first step of your project.

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

#skimage.exposure.equalize_adapthist
### Preprocess the data here. Preprocessing steps could include normalization, converting to grayscale, etc.
### Feel free to use as many code cells as needed.


def convert_to_gray(image):
    return(cv2.cvtColor(image, cv2.COLOR_BGR2GRAY))
def equalize_histogram(image):
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(2,2))
    return(clahe.apply(image))

    
def reshape(image):
    return(np.reshape(image,(32,32,1)))
    

def process_image(image):
    gray = convert_to_gray(image)
    gray_eq_hist = equalize_histogram(gray)
    gray_eq_hist_reshaped = reshape(gray_eq_hist)
    gray_eq_hist_reshaped = (gray_eq_hist_reshaped-128.0)/255.0
    return gray_eq_hist_reshaped

# %%
inputimage=X_train[897]
processed_image = np.reshape(process_image(inputimage),(32,32))
plt.subplot(2,1,1)
plt.imshow(inputimage)
plt.subplot(2,1,2)
plt.imshow(processed_image,cmap='gray')

# %%
X_train_processed=[]
X_valid_processed = []

for img in X_train:
    X_train_processed.append(process_image(img))
    
for img in X_valid:
    X_valid_processed.append(process_image(img))

# %%
#Test data

test_images=[]
test_labels=[]
test_images_processed=[]

def load_image(path,label):
    img = cv2.imread(path)
    test_labels.append(label)
    pimg = process_image(img)
    imgshow = np.reshape(pimg,(32,32))
    test_images_processed.append(pimg)
    plt.imshow(imgshow,cmap='gray')
    
#GeneralCaution.jpg, 18
#SpeedLimit30.jpg    , 1  
#speedLimit30_1.jpg
#AheadOnly.jpg, 35
  
#roundAbout.jpg   40       
plt.subplot(1,5,1)
load_image("test/GeneralCaution.jpg",18)
plt.subplot(1,5,2)
load_image("test/SpeedLimit30.jpg",1)
plt.subplot(1,5,3)
load_image("test/speedLimit30_1.jpg",1)
plt.subplot(1,5,4)
load_image("test/roundAbout.jpg",40)
plt.subplot(1,5,5)
load_image("test/AheadOnly.jpg",35)

# %% [markdown]
# ### Model Architecture

# %%
#Visualize the processed data
import matplotlib.pyplot as plt
import random
# Visualizations will be shown in the notebook.
# %matplotlib inline

### Data exploration visualization code goes here.
### Feel free to use as many code cells as needed.
import matplotlib.pyplot as plt
# Visualizations will be shown in the notebook.
# %matplotlib inline


#img_id = 43
#image = X_train[img_id]
#image_label = y_train[img_id]
#img_plot = plt.imshow(image)
#print("imagenumber",img_id,"traffic label:",image_label)


plt.figure(figsize=(12, 16.5))

num_images_to_display=5

for i in range(0,num_images_to_display):
    index = random.randint(0,len(X_train))
    inputimage=X_train[index]
    processed_image = np.reshape(process_image(inputimage),(32,32))
    plt.subplot(num_images_to_display,4,1+2*i)
    plt.imshow(inputimage)
    plt.subplot(num_images_to_display,4,2+2*i)
    plt.imshow(processed_image,cmap='gray')


#X_train = rgb2gray_reshape(X_train)
#X_valid = rgb2gray_reshape(X_valid)
#X_train = X_train/255.0
#X_valid = X_valid/255.0
#channels = 1

# %%
print(len(X_train_processed))

print(X_train_processed[3443])
# Out:
# 34799
# [[[-0.00784314]
#   [-0.1372549 ]
#   [-0.04313725]
#   ...,
#   [ 0.09803922]
#   [-0.17647059]
#   [-0.27058824]]
#
#  [[ 0.02745098]
#   [-0.2       ]
#   [-0.1254902 ]
#   ...,
#   [-0.04313725]
#   [-0.21568627]
#   [-0.26666667]]
#
#  [[ 0.03529412]
#   [-0.01176471]
#   [-0.21568627]
#   ...,
#   [-0.10588235]
#   [-0.19215686]
#   [-0.23137255]]
#
#  ...,
#  [[ 0.        ]
#   [-0.14509804]
#   [-0.03529412]
#   ...,
#   [-0.14509804]
#   [-0.20392157]
#   [-0.23921569]]
#
#  [[-0.08235294]
#   [-0.21568627]
#   [-0.22745098]
#   ...,
#   [-0.0745098 ]
#   [-0.13333333]
#   [-0.18039216]]
#
#  [[-0.17647059]
#   [-0.27058824]
#   [-0.29019608]
#   ...,
#   [-0.14509804]
#   [-0.14509804]
#   [-0.25098039]]]

# %%
#All parameters in one place
channels=1


global_mu=0.0
global_sigma = 0.1
rate = 0.008
EPOCH=1000
BATCH_SIZE = 256
drop_prob=0.3

# %%
from tensorflow.contrib.layers import flatten
def LeNet(x):    
    # Hyperparameters
    mu = global_mu
    sigma = global_sigma

    # SOLUTION: Layer 1: Convolutional. Input = 32x32x3. Output = 28x28x6.
    conv1_W = tf.Variable(tf.truncated_normal(shape=(5, 5, channels, 6), mean = mu, stddev = sigma))
    conv1_b = tf.Variable(tf.zeros(6))
    conv1   = tf.nn.conv2d(x, conv1_W, strides=[1, 1, 1, 1], padding='VALID') + conv1_b

    # SOLUTION: Activation.
    conv1 = tf.nn.relu(conv1)

    # SOLUTION: Pooling. Input = 28x28x6. Output = 14x14x6.
    conv1 = tf.nn.max_pool(conv1, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='VALID')

    # SOLUTION: Layer 2: Convolutional. Output = 10x10x16.
    conv2_W = tf.Variable(tf.truncated_normal(shape=(5, 5, 6, 16), mean = mu, stddev = sigma))
    conv2_b = tf.Variable(tf.zeros(16))
    conv2   = tf.nn.conv2d(conv1, conv2_W, strides=[1, 1, 1, 1], padding='VALID') + conv2_b

    # SOLUTION: Activation.
    conv2 = tf.nn.relu(conv2)
    


    # SOLUTION: Pooling. Input = 10x10x16. Output = 5x5x16.
    conv2 = tf.nn.max_pool(conv2, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='VALID')

    # SOLUTION: Flatten. Input = 5x5x16. Output = 400.
    fc0   = flatten(conv2)
    
    #drop out
    fc0 = tf.nn.dropout(fc0, keep_prob)
    
    # SOLUTION: Layer 3: Fully Connected. Input = 400. Output = 120.
    fc1_W = tf.Variable(tf.truncated_normal(shape=(400, 120), mean = mu, stddev = sigma))
    fc1_b = tf.Variable(tf.zeros(120))
    fc1   = tf.matmul(fc0, fc1_W) + fc1_b

    # SOLUTION: Activation.
    fc1    = tf.nn.relu(fc1)

    #Drop out
   # fc1 = tf.nn.dropout(fc1, keep_prob)
    
    # SOLUTION: Layer 4: Fully Connected. Input = 120. Output = 84.
    fc2_W  = tf.Variable(tf.truncated_normal(shape=(120, 84), mean = mu, stddev = sigma))
    fc2_b  = tf.Variable(tf.zeros(84))
    fc2    = tf.matmul(fc1, fc2_W) + fc2_b

    # SOLUTION: Activation.
    fc2    = tf.nn.relu(fc2)

       #Drop out
   # fc2 = tf.nn.dropout(fc2, keep_prob)
    
    # SOLUTION: Layer 5: Fully Connected. Input = 84. Output = 10.
    fc3_W  = tf.Variable(tf.truncated_normal(shape=(84, n_classes), mean = mu, stddev = sigma))
    fc3_b  = tf.Variable(tf.zeros(n_classes))
    logits = tf.matmul(fc2, fc3_W) + fc3_b

    return logits

# %% [markdown]
# ### Train, Validate and Test the Model

# %% [markdown]
# A validation set can be used to assess how well the model is performing. A low accuracy on the training and validation
# sets imply underfitting. A high accuracy on the training set but low accuracy on the validation set implies overfitting.

# %%
### Train your model here.
### Calculate and report the accuracy on the training and validation set.
### Once a final model architecture is selected, 
### the accuracy on the test set should be calculated and reported as well.
### Feel free to use as many code cells as needed.
import tensorflow as tf


x = tf.placeholder(tf.float32,(None,32,32,channels))
y = tf.placeholder(tf.int32,(None))
keep_prob = tf.placeholder(tf.float32,(None))
onehot_y = tf.one_hot(y,n_classes)

# %%
## Call the high level  pipeline here

logits = LeNet(x)
cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits,onehot_y)
loss_operation = tf.reduce_mean(cross_entropy)
optimizer = tf.train.AdamOptimizer(learning_rate=rate)
training_operation = optimizer.minimize(loss_operation)

# %%
#Create evaluation pipeline
correct_prediction = tf.equal(tf.argmax(logits,1),tf.argmax(onehot_y,1))
accuracy_operation = tf.reduce_mean(tf.cast(correct_prediction,tf.float32))
def evaluate(X_data,Y_data):
    num_examples = len(X_data)
    
    total_accuracy=0.0
    sess = tf.get_default_session()
    for offset in range(0,num_examples,BATCH_SIZE):
        batch_x, batch_y = X_data[offset:offset+BATCH_SIZE],Y_data[offset:offset+BATCH_SIZE],
        accuracy = sess.run(accuracy_operation, feed_dict={x: batch_x, y: batch_y,keep_prob:1.0})
        #total_accuracy += (accuracy * batch_x.shape[0])
        total_accuracy += (accuracy * len(batch_x))
    return total_accuracy/num_examples

# %%
#Train the Network
from sklearn.utils import shuffle

accuracy_plot=[]
training_accuracy_plot=[]
with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        num_examples = len(X_train)
        
        print("Let the training commence ...")
        print()
        for i in range(EPOCH):
            X_train_processed, y_train = shuffle(X_train_processed,y_train)
            for offset in range(0,BATCH_SIZE,num_examples):
                end = offset + BATCH_SIZE
                batch_x,batch_y = X_train_processed[offset:end],y_train[offset:end]
                sess.run(training_operation,feed_dict={x:batch_x,y:batch_y,keep_prob:drop_prob})
        
            validation_accuracy = evaluate(X_valid_processed,y_valid)
           # test_labels=[]
            # test_images_processed=[]
            training_accuracy = evaluate(test_images_processed,test_labels)  
            print("EPOCHS ...",format(i+1))
            print("Validation accuracy ...",format(validation_accuracy))
            print("Training accuracy ...",format(training_accuracy))
            accuracy_plot.append(validation_accuracy)
            training_accuracy_plot.append(training_accuracy)
            
            
        saver = tf.train.Saver()
        saver.save(sess,"lenet")
        print("Model saved")
# Out:
# Let the training commence ...
#
# EPOCHS ... 1
# Validation accuracy ... 0.05464852607625277
# Training accuracy ... 0.4000000059604645
# EPOCHS ... 2
# Validation accuracy ... 0.06349206322174765
# Training accuracy ... 0.20000000298023224
# EPOCHS ... 3
# Validation accuracy ... 0.05442176870748299
# Training accuracy ... 0.4000000059604645
# EPOCHS ... 4
# Validation accuracy ... 0.05442176870748299
# Training accuracy ... 0.4000000059604645
# EPOCHS ... 5
# Validation accuracy ... 0.047619047619047616
# Training accuracy ... 0.0
# EPOCHS ... 6
# Validation accuracy ... 0.047619047619047616
# Training accuracy ... 0.0
# EPOCHS ... 7
# Validation accuracy ... 0.047619047619047616
# Training accuracy ... 0.0
# EPOCHS ... 8
# Validation accuracy ... 0.047165532879818596
# Training accuracy ... 0.0
# EPOCHS ... 9
# Validation accuracy ... 0.07800453514739229
# Training accuracy ... 0.4000000059604645
# EPOCHS ... 10
# Validation accuracy ... 0.07981859410430839
# Training accuracy ... 0.4000000059604645
# EPOCHS ... 11
# Validation accuracy ... 0.05941043083900227
# Training accuracy ... 0.4000000059604645
# EPOCHS ... 12
# Validation accuracy ... 0.06666666666666667
# Training accuracy ... 0.4000000059604645
# EPOCHS ... 13
# Validation accuracy ... 0.06893424036281179
# Training accuracy ... 0.4000000059604645
# EPOCHS ... 14
# Validation accuracy ... 0.06598639455782312
# Training accuracy ... 0.4000000059604645
# EPOCHS ... 15
# Validation accuracy ... 0.06689342403628118
# Training accuracy ... 0.4000000059604645
# EPOCHS ... 16
# Validation accuracy ... 0.0673469387755102
# Training accuracy ... 0.4000000059604645
# EPOCHS ... 17
# Validation accuracy ... 0.06712018140589569
# Training accuracy ... 0.4000000059604645
# EPOCHS ... 18
# Validation accuracy ... 0.07551020408163266
# Training accuracy ... 0.4000000059604645
# EPOCHS ... 19
# Validation accuracy ... 0.07709750566893424
# Training accuracy ... 0.4000000059604645
# EPOCHS ... 20
# Validation accuracy ... 0.07596371882086168
# Training accuracy ... 0.4000000059604645
# EPOCHS ... 21
# Validation accuracy ... 0.09659863947774548
# Training accuracy ... 0.4000000059604645
# EPOCHS ... 22
# Validation accuracy ... 0.1308390022608158
# Training accuracy ... 0.4000000059604645
# EPOCHS ... 23
# Validation accuracy ... 0.12766439908621263
# Training accuracy ... 0.0
# EPOCHS ... 24
# Validation accuracy ... 0.12086167794371408
# Training accuracy ... 0.0
# EPOCHS ... 25
# Validation accuracy ... 0.12653061225841375
# Training accuracy ... 0.0
# EPOCHS ... 26
# Validation accuracy ... 0.15170068029914044
# Training accuracy ... 0.20000000298023224
# EPOCHS ... 27
# Validation accuracy ... 0.1875283445495597
# Training accuracy ... 0.20000000298023224
# EPOCHS ... 28
# Validation accuracy ... 0.21292516997341665
# Training accuracy ... 0.20000000298023224
# EPOCHS ... 29
# Validation accuracy ... 0.21609977323925145
# Training accuracy ... 0.20000000298023224
# EPOCHS ... 30
# Validation accuracy ... 0.2235827664399093
# Training accuracy ... 0.4000000059604645
# EPOCHS ... 31
# Validation accuracy ... 0.23786848042827616
# Training accuracy ... 0.4000000059604645
# EPOCHS ... 32
# Validation accuracy ... 0.23469387728070457
# Training accuracy ... 0.4000000059604645
# EPOCHS ... 33
# Validation accuracy ... 0.23514739246595473
# Training accuracy ... 0.4000000059604645
# EPOCHS ... 34
# Validation accuracy ... 0.25578231296571746
# Training accuracy ... 0.4000000059604645
# EPOCHS ... 35
# Validation accuracy ... 0.26258503401191596
# Training accuracy ... 0.0
# EPOCHS ... 36
# Validation accuracy ... 0.2748299319727891
# Training accuracy ... 0.20000000298023224
# EPOCHS ... 37
# Validation accuracy ... 0.2972789115637811
# Training accuracy ... 0.20000000298023224
# EPOCHS ... 38
# Validation accuracy ... 0.3088435373338712
# Training accuracy ... 0.20000000298023224
# EPOCHS ... 39
# Validation accuracy ... 0.3335600908786531
# Training accuracy ... 0.20000000298023224
# EPOCHS ... 40
# Validation accuracy ... 0.3444444446336655
# Training accuracy ... 0.4000000059604645
# EPOCHS ... 41
# Validation accuracy ... 0.34829931956570165
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 42
# Validation accuracy ... 0.36031746012823923
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 43
# Validation accuracy ... 0.37233560093406104
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 44
# Validation accuracy ... 0.37551020370319044
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 45
# Validation accuracy ... 0.38412698426214203
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 46
# Validation accuracy ... 0.38253968291812473
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 47
# Validation accuracy ... 0.36394557817722933
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 48
# Validation accuracy ... 0.3594104307714233
# Training accuracy ... 0.20000000298023224
# EPOCHS ... 49
# Validation accuracy ... 0.38412698430268943
# Training accuracy ... 0.20000000298023224
# EPOCHS ... 50
# Validation accuracy ... 0.4185941043354216
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 51
# Validation accuracy ... 0.45396825364387494
# Training accuracy ... 0.800000011920929
# EPOCHS ... 52
# Validation accuracy ... 0.47256235862805457
# Training accuracy ... 0.800000011920929
# EPOCHS ... 53
# Validation accuracy ... 0.4637188209157412
# Training accuracy ... 0.800000011920929
# EPOCHS ... 54
# Validation accuracy ... 0.4689342406601592
# Training accuracy ... 0.800000011920929
# EPOCHS ... 55
# Validation accuracy ... 0.4965986394828139
# Training accuracy ... 0.800000011920929
# EPOCHS ... 56
# Validation accuracy ... 0.5213151925275115
# Training accuracy ... 0.800000011920929
# EPOCHS ... 57
# Validation accuracy ... 0.4843537412533144
# Training accuracy ... 0.800000011920929
# EPOCHS ... 58
# Validation accuracy ... 0.4850340139568528
# Training accuracy ... 0.800000011920929
# EPOCHS ... 59
# Validation accuracy ... 0.4798185939421189
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 60
# Validation accuracy ... 0.4802721088976006
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 61
# Validation accuracy ... 0.4759637191182091
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 62
# Validation accuracy ... 0.4886621313030217
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 63
# Validation accuracy ... 0.49909297084592097
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 64
# Validation accuracy ... 0.49319727923594364
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 65
# Validation accuracy ... 0.5167800454055371
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 66
# Validation accuracy ... 0.5541950113649
# Training accuracy ... 0.800000011920929
# EPOCHS ... 67
# Validation accuracy ... 0.5623582764007067
# Training accuracy ... 0.800000011920929
# EPOCHS ... 68
# Validation accuracy ... 0.5546485258338132
# Training accuracy ... 0.800000011920929
# EPOCHS ... 69
# Validation accuracy ... 0.5532879816161261
# Training accuracy ... 0.800000011920929
# EPOCHS ... 70
# Validation accuracy ... 0.5469387752669198
# Training accuracy ... 0.800000011920929
# EPOCHS ... 71
# Validation accuracy ... 0.5480725621690555
# Training accuracy ... 0.800000011920929
# EPOCHS ... 72
# Validation accuracy ... 0.5467120179784001
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 73
# Validation accuracy ... 0.5818594104849022
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 74
# Validation accuracy ... 0.5911564623417498
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 75
# Validation accuracy ... 0.586848072319074
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 76
# Validation accuracy ... 0.6009070292351738
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 77
# Validation accuracy ... 0.5972789118890048
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 78
# Validation accuracy ... 0.5730158732321257
# Training accuracy ... 0.800000011920929
# EPOCHS ... 79
# Validation accuracy ... 0.5730158728942308
# Training accuracy ... 0.800000011920929
# EPOCHS ... 80
# Validation accuracy ... 0.5780045348230133
# Training accuracy ... 0.800000011920929
# EPOCHS ... 81
# Validation accuracy ... 0.5786848068777937
# Training accuracy ... 0.800000011920929
# EPOCHS ... 82
# Validation accuracy ... 0.5816326531693509
# Training accuracy ... 0.800000011920929
# EPOCHS ... 83
# Validation accuracy ... 0.5741496599720719
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 84
# Validation accuracy ... 0.5984126982505089
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 85
# Validation accuracy ... 0.6321995462960397
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 86
# Validation accuracy ... 0.6528344674445604
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 87
# Validation accuracy ... 0.6603174601012076
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 88
# Validation accuracy ... 0.6621315195717239
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 89
# Validation accuracy ... 0.6507936511180298
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 90
# Validation accuracy ... 0.6453514737336814
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 91
# Validation accuracy ... 0.6428571432085535
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 92
# Validation accuracy ... 0.631519274457512
# Training accuracy ... 0.6000000238418579
# EPOCHS ... 93
# Validation accuracy ... 0.6172335604421135
# Training accuracy ... 0.800000011920929
# EPOCHS ... 94
# Validation accuracy ... 0.6263038546860623
# Training accuracy ... 0.800000011920929
# EPOCHS ... 95
# Validation accuracy ... 0.6464852610412909
# Training accuracy ... 0.800000011920929
# EPOCHS ... 96
# Validation accuracy ... 0.645578231292517
# Training accuracy ... 0.800000011920929
# EPOCHS ... 97
# Validation accuracy ... 0.6659863945578232
# Training accuracy ... 0.800000011920929
# EPOCHS ... 98
# Validation accuracy ... 0.6839002267844012
# Training accuracy ... 0.800000011920929
# EPOCHS ... 99
# Validation accuracy ... 0.678004535228487
# Training accuracy ... 0.800000011920929
# EPOCHS ... 100
# Validation accuracy ... 0.6655328797374993
# Training accuracy ... 0.800000011920929
# EPOCHS ... 101
# Validation accuracy ... 0.6764172337493118
# Training accuracy ... 0.800000011920929
# EPOCHS ... 102
# Validation accuracy ... 0.6814058958808311
# Training accuracy ... 0.800000011920929
# EPOCHS ... 103
# Validation accuracy ... 0.6807256237719875
# Training accuracy ... 0.800000011920929
# EPOCHS ... 104
# Validation accuracy ... 0.6791383219414017
# Training accuracy ... 1.0
# EPOCHS ... 105
# Validation accuracy ... 0.686848072454232
# Training accuracy ... 1.0
# EPOCHS ... 106
# Validation accuracy ... 0.7038548751212572
# Training accuracy ... 1.0
# EPOCHS ... 107
# Validation accuracy ... 0.7140589572404787
# Training accuracy ... 1.0
# EPOCHS ... 108
# Validation accuracy ... 0.6993197279452197
# Training accuracy ... 1.0
# EPOCHS ... 109
# Validation accuracy ... 0.6913832200087117
# Training accuracy ... 1.0
# EPOCHS ... 110
# Validation accuracy ... 0.6571428568995729
# Training accuracy ... 1.0
# EPOCHS ... 111
# Validation accuracy ... 0.6580498866483467
# Training accuracy ... 1.0
# EPOCHS ... 112
# Validation accuracy ... 0.6956916102746717
# Training accuracy ... 0.800000011920929
# EPOCHS ... 113
# Validation accuracy ... 0.7020408164076254
# Training accuracy ... 1.0
# EPOCHS ... 114
# Validation accuracy ... 0.6639455785827031
# Training accuracy ... 0.800000011920929
# EPOCHS ... 115
# Validation accuracy ... 0.6433106577044982
# Training accuracy ... 0.800000011920929
# EPOCHS ... 116
# Validation accuracy ... 0.6376417234641354
# Training accuracy ... 0.800000011920929
# EPOCHS ... 117
# Validation accuracy ... 0.6390022678980751
# Training accuracy ... 0.800000011920929
# EPOCHS ... 118
# Validation accuracy ... 0.6603174601012076
# Training accuracy ... 0.800000011920929
# EPOCHS ... 119
# Validation accuracy ... 0.6975056692315877
# Training accuracy ... 0.800000011920929
# EPOCHS ... 120
# Validation accuracy ... 0.7140589569431314
# Training accuracy ... 1.0
# EPOCHS ... 121
# Validation accuracy ... 0.7120181403462849
# Training accuracy ... 1.0
# EPOCHS ... 122
# Validation accuracy ... 0.703174602931319
# Training accuracy ... 1.0
# EPOCHS ... 123
# Validation accuracy ... 0.6986394558363761
# Training accuracy ... 1.0
# EPOCHS ... 124
# Validation accuracy ... 0.6809523813037915
# Training accuracy ... 1.0
# EPOCHS ... 125
# Validation accuracy ... 0.6823129255485102
# Training accuracy ... 1.0
# EPOCHS ... 126
# Validation accuracy ... 0.6977324266552655
# Training accuracy ... 1.0
# EPOCHS ... 127
# Validation accuracy ... 0.7104308393536781
# Training accuracy ... 1.0
# EPOCHS ... 128
# Validation accuracy ... 0.719047618858398
# Training accuracy ... 1.0
# EPOCHS ... 129
# Validation accuracy ... 0.7122448982835627
# Training accuracy ... 1.0
# EPOCHS ... 130
# Validation accuracy ... 0.7206349206889838
# Training accuracy ... 1.0
# EPOCHS ... 131
# Validation accuracy ... 0.7229024946284132
# Training accuracy ... 0.800000011920929
# EPOCHS ... 132
# Validation accuracy ... 0.7249433109279122
# Training accuracy ... 1.0
# EPOCHS ... 133
# Validation accuracy ... 0.7163265308825607
# Training accuracy ... 1.0
# EPOCHS ... 134
# Validation accuracy ... 0.7335600909732637
# Training accuracy ... 1.0
# EPOCHS ... 135
# Validation accuracy ... 0.7353741499301798
# Training accuracy ... 1.0
# EPOCHS ... 136
# Validation accuracy ... 0.7342403630821073
# Training accuracy ... 1.0
# EPOCHS ... 137
# Validation accuracy ... 0.7335600909732637
# Training accuracy ... 1.0
# EPOCHS ... 138
# Validation accuracy ... 0.7374149657431103
# Training accuracy ... 1.0
# EPOCHS ... 139
# Validation accuracy ... 0.7260770975327006
# Training accuracy ... 1.0
# EPOCHS ... 140
# Validation accuracy ... 0.7215419501404102
# Training accuracy ... 1.0
# EPOCHS ... 141
# Validation accuracy ... 0.7260770972623847
# Training accuracy ... 1.0
# EPOCHS ... 142
# Validation accuracy ... 0.7362811794356694
# Training accuracy ... 1.0
# EPOCHS ... 143
# Validation accuracy ... 0.7476190474298265
# Training accuracy ... 1.0
# EPOCHS ... 144
# Validation accuracy ... 0.7571428572239519
# Training accuracy ... 1.0
# EPOCHS ... 145
# Validation accuracy ... 0.7680272109654485
# Training accuracy ... 1.0
# EPOCHS ... 146
# Validation accuracy ... 0.7741496596476929
# Training accuracy ... 0.800000011920929
# EPOCHS ... 147
# Validation accuracy ... 0.7575963719091178
# Training accuracy ... 0.800000011920929
# EPOCHS ... 148
# Validation accuracy ... 0.7489795918637663
# Training accuracy ... 0.800000011920929
# EPOCHS ... 149
# Validation accuracy ... 0.742176870505015
# Training accuracy ... 0.800000011920929
# EPOCHS ... 150
# Validation accuracy ... 0.7512471652895956
# Training accuracy ... 0.800000011920929
# EPOCHS ... 151
# Validation accuracy ... 0.7551020405730423
# Training accuracy ... 0.800000011920929
# EPOCHS ... 152
# Validation accuracy ... 0.7530612242465117
# Training accuracy ... 0.800000011920929
# EPOCHS ... 153
# Validation accuracy ... 0.7648526074664663
# Training accuracy ... 0.800000011920929
# EPOCHS ... 154
# Validation accuracy ... 0.7643990927272373
# Training accuracy ... 0.800000011920929
# EPOCHS ... 155
# Validation accuracy ... 0.7689342401195275
# Training accuracy ... 0.800000011920929
# EPOCHS ... 156
# Validation accuracy ... 0.7621315190310921
# Training accuracy ... 0.800000011920929
# EPOCHS ... 157
# Validation accuracy ... 0.7619047621750777
# Training accuracy ... 0.800000011920929
# EPOCHS ... 158
# Validation accuracy ... 0.7498866213151928
# Training accuracy ... 1.0
# EPOCHS ... 159
# Validation accuracy ... 0.7356009070294784
# Training accuracy ... 1.0
# EPOCHS ... 160
# Validation accuracy ... 0.7399092970521542
# Training accuracy ... 1.0
# EPOCHS ... 161
# Validation accuracy ... 0.7428571431274587
# Training accuracy ... 1.0
# EPOCHS ... 162
# Validation accuracy ... 0.7464852610412909
# Training accuracy ... 1.0
# EPOCHS ... 163
# Validation accuracy ... 0.7702947843372147
# Training accuracy ... 1.0
# EPOCHS ... 164
# Validation accuracy ... 0.7759637188478933
# Training accuracy ... 1.0
# EPOCHS ... 165
# Validation accuracy ... 0.7616780045621789
# Training accuracy ... 1.0
# EPOCHS ... 166
# Validation accuracy ... 0.7575963716658335
# Training accuracy ... 1.0
# EPOCHS ... 167
# Validation accuracy ... 0.7664399096214312
# Training accuracy ... 1.0
# EPOCHS ... 168
# Validation accuracy ... 0.7675736961721563
# Training accuracy ... 1.0
# EPOCHS ... 169
# Validation accuracy ... 0.776643990686421
# Training accuracy ... 1.0
# EPOCHS ... 170
# Validation accuracy ... 0.7827664401796129
# Training accuracy ... 1.0
# EPOCHS ... 171
# Validation accuracy ... 0.7664399092970522
# Training accuracy ... 1.0
# EPOCHS ... 172
# Validation accuracy ... 0.7562358276643991
# Training accuracy ... 1.0
# EPOCHS ... 173
# Validation accuracy ... 0.7444444444444445
# Training accuracy ... 1.0
# EPOCHS ... 174
# Validation accuracy ... 0.7439909297052154
# Training accuracy ... 1.0
# EPOCHS ... 175
# Validation accuracy ... 0.7448979591836735
# Training accuracy ... 1.0
# EPOCHS ... 176
# Validation accuracy ... 0.7585034013605442
# Training accuracy ... 1.0
# EPOCHS ... 177
# Validation accuracy ... 0.7687074829931972
# Training accuracy ... 0.800000011920929
# EPOCHS ... 178
# Validation accuracy ... 0.7709750566893424
# Training accuracy ... 0.800000011920929
# EPOCHS ... 179
# Validation accuracy ... 0.7775510204081633
# Training accuracy ... 0.800000011920929
# EPOCHS ... 180
# Validation accuracy ... 0.7816326528179403
# Training accuracy ... 0.800000011920929
# EPOCHS ... 181
# Validation accuracy ... 0.7786848070670147
# Training accuracy ... 0.800000011920929
# EPOCHS ... 182
# Validation accuracy ... 0.780272109194948
# Training accuracy ... 0.800000011920929
# EPOCHS ... 183
# Validation accuracy ... 0.7839002268114328
# Training accuracy ... 0.800000011920929
# EPOCHS ... 184
# Validation accuracy ... 0.7954648529050572
# Training accuracy ... 0.800000011920929
# EPOCHS ... 185
# Validation accuracy ... 0.7990929702782577
# Training accuracy ... 1.0
# EPOCHS ... 186
# Validation accuracy ... 0.7884353744199757
# Training accuracy ... 1.0
# EPOCHS ... 187
# Validation accuracy ... 0.7977324263038549
# Training accuracy ... 1.0
# EPOCHS ... 188
# Validation accuracy ... 0.8006802723791594
# Training accuracy ... 1.0
# EPOCHS ... 189
# Validation accuracy ... 0.7900226757369615
# Training accuracy ... 1.0
# EPOCHS ... 190
# Validation accuracy ... 0.781859410430839
# Training accuracy ... 1.0
# EPOCHS ... 191
# Validation accuracy ... 0.7850340136054422
# Training accuracy ... 1.0
# EPOCHS ... 192
# Validation accuracy ... 0.8049886621315193
# Training accuracy ... 1.0
# EPOCHS ... 193
# Validation accuracy ... 0.810204081632653
# Training accuracy ... 1.0
# EPOCHS ... 194
# Validation accuracy ... 0.8111111111111111
# Training accuracy ... 1.0
# EPOCHS ... 195
# Validation accuracy ... 0.8034013605442177
# Training accuracy ... 1.0
# EPOCHS ... 196
# Validation accuracy ... 0.7981859410430839
# Training accuracy ... 1.0
# EPOCHS ... 197
# Validation accuracy ... 0.8047619047619048
# Training accuracy ... 1.0
# EPOCHS ... 198
# Validation accuracy ... 0.8163265306122449
# Training accuracy ... 1.0
# EPOCHS ... 199
# Validation accuracy ... 0.820861678274851
# Training accuracy ... 1.0
# EPOCHS ... 200
# Validation accuracy ... 0.8102040819029689
# Training accuracy ... 1.0
# EPOCHS ... 201
# Validation accuracy ... 0.7959183676172547
# Training accuracy ... 1.0
# EPOCHS ... 202
# Validation accuracy ... 0.8090702950548964
# Training accuracy ... 1.0
# EPOCHS ... 203
# Validation accuracy ... 0.812018140859885
# Training accuracy ... 1.0
# EPOCHS ... 204
# Validation accuracy ... 0.8129251703383431
# Training accuracy ... 1.0
# EPOCHS ... 205
# Validation accuracy ... 0.8090702950548964
# Training accuracy ... 1.0
# EPOCHS ... 206
# Validation accuracy ... 0.8054421771410641
# Training accuracy ... 1.0
# EPOCHS ... 207
# Validation accuracy ... 0.8063492061059221
# Training accuracy ... 1.0
# EPOCHS ... 208
# Validation accuracy ... 0.8022675734528608
# Training accuracy ... 1.0
# EPOCHS ... 209
# Validation accuracy ... 0.8083900224324527
# Training accuracy ... 1.0
# EPOCHS ... 210
# Validation accuracy ... 0.8081632655764383
# Training accuracy ... 1.0
# EPOCHS ... 211
# Validation accuracy ... 0.8136054421768707
# Training accuracy ... 1.0
# EPOCHS ... 212
# Validation accuracy ... 0.8208616780045351
# Training accuracy ... 1.0
# EPOCHS ... 213
# Validation accuracy ... 0.8160997735129463
# Training accuracy ... 1.0
# EPOCHS ... 214
# Validation accuracy ... 0.7965986397260981
# Training accuracy ... 1.0
# EPOCHS ... 215
# Validation accuracy ... 0.7882086167800454
# Training accuracy ... 1.0
# EPOCHS ... 216
# Validation accuracy ... 0.7938775510204081
# Training accuracy ... 1.0
# EPOCHS ... 217
# Validation accuracy ... 0.8070294784580498
# Training accuracy ... 1.0
# EPOCHS ... 218
# Validation accuracy ... 0.8229024943310658
# Training accuracy ... 1.0
# EPOCHS ... 219
# Validation accuracy ... 0.8319727891156462
# Training accuracy ... 1.0
# EPOCHS ... 220
# Validation accuracy ... 0.8192743764172336
# Training accuracy ... 1.0
# EPOCHS ... 221
# Validation accuracy ... 0.8122448982294995
# Training accuracy ... 1.0
# EPOCHS ... 222
# Validation accuracy ... 0.8099773245333544
# Training accuracy ... 1.0
# EPOCHS ... 223
# Validation accuracy ... 0.8176870745866477
# Training accuracy ... 0.800000011920929
# EPOCHS ... 224
# Validation accuracy ... 0.8328798188644202
# Training accuracy ... 1.0
# EPOCHS ... 225
# Validation accuracy ... 0.8365079365079365
# Training accuracy ... 1.0
# EPOCHS ... 226
# Validation accuracy ... 0.8204081632653061
# Training accuracy ... 1.0
# EPOCHS ... 227
# Validation accuracy ... 0.8061224489795918
# Training accuracy ... 1.0
# EPOCHS ... 228
# Validation accuracy ... 0.8052154195011337
# Training accuracy ... 1.0
# EPOCHS ... 229
# Validation accuracy ... 0.808390022675737
# Training accuracy ... 1.0
# EPOCHS ... 230
# Validation accuracy ... 0.81859410430839
# Training accuracy ... 1.0
# EPOCHS ... 231
# Validation accuracy ... 0.834920634920635
# Training accuracy ... 1.0
# EPOCHS ... 232
# Validation accuracy ... 0.8421768707482993
# Training accuracy ... 1.0
# EPOCHS ... 233
# Validation accuracy ... 0.8365079365079365
# Training accuracy ... 1.0
# EPOCHS ... 234
# Validation accuracy ... 0.83718820861678
# Training accuracy ... 0.800000011920929
# EPOCHS ... 235
# Validation accuracy ... 0.8385487528344672
# Training accuracy ... 0.800000011920929
# EPOCHS ... 236
# Validation accuracy ... 0.8378684807256236
# Training accuracy ... 1.0
# EPOCHS ... 237
# Validation accuracy ... 0.8238095240798397
# Training accuracy ... 1.0
# EPOCHS ... 238
# Validation accuracy ... 0.8179138319562622
# Training accuracy ... 1.0
# EPOCHS ... 239
# Validation accuracy ... 0.8204081630220219
# Training accuracy ... 1.0
# EPOCHS ... 240
# Validation accuracy ... 0.821768707239709
# Training accuracy ... 1.0
# EPOCHS ... 241
# Validation accuracy ... 0.8179138319562622
# Training accuracy ... 1.0
# EPOCHS ... 242
# Validation accuracy ... 0.8099773240197543
# Training accuracy ... 1.0
# EPOCHS ... 243
# Validation accuracy ... 0.8102040813893688
# Training accuracy ... 1.0
# EPOCHS ... 244
# Validation accuracy ... 0.8244897961886832
# Training accuracy ... 1.0
# EPOCHS ... 245
# Validation accuracy ... 0.8183673466954913
# Training accuracy ... 1.0
# EPOCHS ... 246
# Validation accuracy ... 0.8154195008905026
# Training accuracy ... 1.0
# EPOCHS ... 247
# Validation accuracy ... 0.8158730156567632
# Training accuracy ... 1.0
# EPOCHS ... 248
# Validation accuracy ... 0.8269841267678743
# Training accuracy ... 1.0
# EPOCHS ... 249
# Validation accuracy ... 0.8303854878256921
# Training accuracy ... 0.800000011920929
# EPOCHS ... 250
# Validation accuracy ... 0.8249433104143121
# Training accuracy ... 0.800000011920929
# EPOCHS ... 251
# Validation accuracy ... 0.8265306120016137
# Training accuracy ... 0.800000011920929
# EPOCHS ... 252
# Validation accuracy ... 0.8242630388190687
# Training accuracy ... 0.800000011920929
# EPOCHS ... 253
# Validation accuracy ... 0.8083900229460528
# Training accuracy ... 1.0
# EPOCHS ... 254
# Validation accuracy ... 0.812018140859885
# Training accuracy ... 1.0
# EPOCHS ... 255
# Validation accuracy ... 0.8167800456217897
# Training accuracy ... 1.0
# EPOCHS ... 256
# Validation accuracy ... 0.8199546485260771
# Training accuracy ... 1.0
# EPOCHS ... 257
# Validation accuracy ... 0.8247165535582978
# Training accuracy ... 1.0
# EPOCHS ... 258
# Validation accuracy ... 0.8247165530446976
# Training accuracy ... 1.0
# EPOCHS ... 259
# Validation accuracy ... 0.8267573693712282
# Training accuracy ... 0.800000011920929
# EPOCHS ... 260
# Validation accuracy ... 0.8251700680542424
# Training accuracy ... 1.0
# EPOCHS ... 261
# Validation accuracy ... 0.8219954648796393
# Training accuracy ... 1.0
# EPOCHS ... 262
# Validation accuracy ... 0.8238095238365554
# Training accuracy ... 1.0
# EPOCHS ... 263
# Validation accuracy ... 0.8176870748569636
# Training accuracy ... 1.0
# EPOCHS ... 264
# Validation accuracy ... 0.8283446712288457
# Training accuracy ... 1.0
# EPOCHS ... 265
# Validation accuracy ... 0.8408163268009281
# Training accuracy ... 1.0
# EPOCHS ... 266
# Validation accuracy ... 0.8380952380952381
# Training accuracy ... 1.0
# EPOCHS ... 267
# Validation accuracy ... 0.8403628117913832
# Training accuracy ... 1.0
# EPOCHS ... 268
# Validation accuracy ... 0.8473922902494331
# Training accuracy ... 1.0
# EPOCHS ... 269
# Validation accuracy ... 0.8419501133786849
# Training accuracy ... 1.0
# EPOCHS ... 270
# Validation accuracy ... 0.8414965986394558
# Training accuracy ... 0.800000011920929
# EPOCHS ... 271
# Validation accuracy ... 0.827891156462585
# Training accuracy ... 0.800000011920929
# EPOCHS ... 272
# Validation accuracy ... 0.844671201814059
# Training accuracy ... 0.800000011920929
# EPOCHS ... 273
# Validation accuracy ... 0.8469387755102041
# Training accuracy ... 0.800000011920929
# EPOCHS ... 274
# Validation accuracy ... 0.8467120181405896
# Training accuracy ... 1.0
# EPOCHS ... 275
# Validation accuracy ... 0.8448979591836735
# Training accuracy ... 1.0
# EPOCHS ... 276
# Validation accuracy ... 0.8292517004369878
# Training accuracy ... 1.0
# EPOCHS ... 277
# Validation accuracy ... 0.8238095238365554
# Training accuracy ... 1.0
# EPOCHS ... 278
# Validation accuracy ... 0.8222222222492538
# Training accuracy ... 1.0
# EPOCHS ... 279
# Validation accuracy ... 0.8276643991200021
# Training accuracy ... 1.0
# EPOCHS ... 280
# Validation accuracy ... 0.8247165530446976
# Training accuracy ... 1.0
# EPOCHS ... 281
# Validation accuracy ... 0.8333333330900491
# Training accuracy ... 1.0
# EPOCHS ... 282
# Validation accuracy ... 0.8383219954918842
# Training accuracy ... 1.0
# EPOCHS ... 283
# Validation accuracy ... 0.8394557823399568
# Training accuracy ... 1.0
# EPOCHS ... 284
# Validation accuracy ... 0.8310657596642198
# Training accuracy ... 1.0
# EPOCHS ... 285
# Validation accuracy ... 0.8213151927707958
# Training accuracy ... 1.0
# EPOCHS ... 286
# Validation accuracy ... 0.8165532877385752
# Training accuracy ... 1.0
# EPOCHS ... 287
# Validation accuracy ... 0.8222222219789379
# Training accuracy ... 1.0
# EPOCHS ... 288
# Validation accuracy ... 0.8394557823399568
# Training accuracy ... 1.0
# EPOCHS ... 289
# Validation accuracy ... 0.8582766437476455
# Training accuracy ... 1.0
# EPOCHS ... 290
# Validation accuracy ... 0.8678004537850551
# Training accuracy ... 1.0
# EPOCHS ... 291
# Validation accuracy ... 0.8691609980027422
# Training accuracy ... 1.0
# EPOCHS ... 292
# Validation accuracy ... 0.8603174605877761
# Training accuracy ... 1.0
# EPOCHS ... 293
# Validation accuracy ... 0.8478458047453779
# Training accuracy ... 1.0
# EPOCHS ... 294
# Validation accuracy ... 0.8374149657431103
# Training accuracy ... 1.0
# EPOCHS ... 295
# Validation accuracy ... 0.8360544215254232
# Training accuracy ... 1.0
# EPOCHS ... 296
# Validation accuracy ... 0.847392290519749
# Training accuracy ... 1.0
# EPOCHS ... 297
# Validation accuracy ... 0.857142857413173
# Training accuracy ... 1.0
# EPOCHS ... 298
# Validation accuracy ... 0.8551020410866423
# Training accuracy ... 1.0
# EPOCHS ... 299
# Validation accuracy ... 0.8503401363247376
# Training accuracy ... 1.0
# EPOCHS ... 300
# Validation accuracy ... 0.8442176873451458
# Training accuracy ... 1.0
# EPOCHS ... 301
# Validation accuracy ... 0.8442176873451458
# Training accuracy ... 1.0
# EPOCHS ... 302
# Validation accuracy ... 0.8503401363247376
# Training accuracy ... 1.0
# EPOCHS ... 303
# Validation accuracy ... 0.8564625853043295
# Training accuracy ... 1.0
# EPOCHS ... 304
# Validation accuracy ... 0.8523809526512682
# Training accuracy ... 1.0
# EPOCHS ... 305
# Validation accuracy ... 0.8498866213422244
# Training accuracy ... 1.0
# EPOCHS ... 306
# Validation accuracy ... 0.8514739231728102
# Training accuracy ... 1.0
# EPOCHS ... 307
# Validation accuracy ... 0.85578231292517
# Training accuracy ... 1.0
# EPOCHS ... 308
# Validation accuracy ... 0.8537414965986394
# Training accuracy ... 1.0
# EPOCHS ... 309
# Validation accuracy ... 0.8562358276643991
# Training accuracy ... 1.0
# EPOCHS ... 310
# Validation accuracy ... 0.854875283446712
# Training accuracy ... 1.0
# EPOCHS ... 311
# Validation accuracy ... 0.8473922902494331
# Training accuracy ... 1.0
# EPOCHS ... 312
# Validation accuracy ... 0.8405895691609977
# Training accuracy ... 1.0
# EPOCHS ... 313
# Validation accuracy ... 0.8344671201814059
# Training accuracy ... 1.0
# EPOCHS ... 314
# Validation accuracy ... 0.8319727891156462
# Training accuracy ... 1.0
# EPOCHS ... 315
# Validation accuracy ... 0.8297052154195012
# Training accuracy ... 1.0
# EPOCHS ... 316
# Validation accuracy ... 0.8408163265306122
# Training accuracy ... 1.0
# EPOCHS ... 317
# Validation accuracy ... 0.8489795921070505
# Training accuracy ... 1.0
# EPOCHS ... 318
# Validation accuracy ... 0.8607709753270052
# Training accuracy ... 1.0
# EPOCHS ... 319
# Validation accuracy ... 0.8689342406331276
# Training accuracy ... 1.0
# EPOCHS ... 320
# Validation accuracy ... 0.8632653063927648
# Training accuracy ... 1.0
# EPOCHS ... 321
# Validation accuracy ... 0.8528344673904973
# Training accuracy ... 1.0
# EPOCHS ... 322
# Validation accuracy ... 0.8551020410866423
# Training accuracy ... 1.0
# EPOCHS ... 323
# Validation accuracy ... 0.8460317463020619
# Training accuracy ... 1.0
# EPOCHS ... 324
# Validation accuracy ... 0.8448979591836735
# Training accuracy ... 1.0
# EPOCHS ... 325
# Validation accuracy ... 0.8392290249433106
# Training accuracy ... 1.0
# EPOCHS ... 326
# Validation accuracy ... 0.8321995464852607
# Training accuracy ... 1.0
# EPOCHS ... 327
# Validation accuracy ... 0.8333333333333334
# Training accuracy ... 1.0
# EPOCHS ... 328
# Validation accuracy ... 0.8369614512471655
# Training accuracy ... 1.0
# EPOCHS ... 329
# Validation accuracy ... 0.8433106575963719
# Training accuracy ... 1.0
# EPOCHS ... 330
# Validation accuracy ... 0.8437641723356009
# Training accuracy ... 1.0
# EPOCHS ... 331
# Validation accuracy ... 0.8480725623582767
# Training accuracy ... 1.0
# EPOCHS ... 332
# Validation accuracy ... 0.8471655328798186
# Training accuracy ... 1.0
# EPOCHS ... 333
# Validation accuracy ... 0.854421768707483
# Training accuracy ... 1.0
# EPOCHS ... 334
# Validation accuracy ... 0.8519274373984391
# Training accuracy ... 1.0
# EPOCHS ... 335
# Validation accuracy ... 0.8476190473757633
# Training accuracy ... 1.0
# EPOCHS ... 336
# Validation accuracy ... 0.8428571426138586
# Training accuracy ... 1.0
# EPOCHS ... 337
# Validation accuracy ... 0.8374149657431103
# Training accuracy ... 1.0
# EPOCHS ... 338
# Validation accuracy ... 0.842630385244244
# Training accuracy ... 1.0
# EPOCHS ... 339
# Validation accuracy ... 0.8614512471655329
# Training accuracy ... 1.0
# EPOCHS ... 340
# Validation accuracy ... 0.8750566893424037
# Training accuracy ... 1.0
# EPOCHS ... 341
# Validation accuracy ... 0.8784580498866214
# Training accuracy ... 1.0
# EPOCHS ... 342
# Validation accuracy ... 0.8764172335600907
# Training accuracy ... 1.0
# EPOCHS ... 343
# Validation accuracy ... 0.8750566893424037
# Training accuracy ... 1.0
# EPOCHS ... 344
# Validation accuracy ... 0.8811791383219955
# Training accuracy ... 1.0
# EPOCHS ... 345
# Validation accuracy ... 0.8793650793650793
# Training accuracy ... 1.0
# EPOCHS ... 346
# Validation accuracy ... 0.8752834467120182
# Training accuracy ... 1.0
# EPOCHS ... 347
# Validation accuracy ... 0.873015873015873
# Training accuracy ... 1.0
# EPOCHS ... 348
# Validation accuracy ... 0.8700680272108844
# Training accuracy ... 1.0
# EPOCHS ... 349
# Validation accuracy ... 0.8643990929705215
# Training accuracy ... 1.0
# EPOCHS ... 350
# Validation accuracy ... 0.8605442174437906
# Training accuracy ... 1.0
# EPOCHS ... 351
# Validation accuracy ... 0.8553287979426568
# Training accuracy ... 1.0
# EPOCHS ... 352
# Validation accuracy ... 0.8546485261041291
# Training accuracy ... 1.0
# EPOCHS ... 353
# Validation accuracy ... 0.852834467147213
# Training accuracy ... 1.0
# EPOCHS ... 354
# Validation accuracy ... 0.8512471655599114
# Training accuracy ... 1.0
# EPOCHS ... 355
# Validation accuracy ... 0.848752834737436
# Training accuracy ... 1.0
# EPOCHS ... 356
# Validation accuracy ... 0.845578231292517
# Training accuracy ... 1.0
# EPOCHS ... 357
# Validation accuracy ... 0.8442176870748299
# Training accuracy ... 1.0
# EPOCHS ... 358
# Validation accuracy ... 0.8408163265306122
# Training accuracy ... 1.0
# EPOCHS ... 359
# Validation accuracy ... 0.8480725623582767
# Training accuracy ... 1.0
# EPOCHS ... 360
# Validation accuracy ... 0.861904761904762
# Training accuracy ... 1.0
# EPOCHS ... 361
# Validation accuracy ... 0.8775510204081632
# Training accuracy ... 1.0
# EPOCHS ... 362
# Validation accuracy ... 0.8825396825396825
# Training accuracy ... 1.0
# EPOCHS ... 363
# Validation accuracy ... 0.8775510204081632
# Training accuracy ... 1.0
# EPOCHS ... 364
# Validation accuracy ... 0.873922902494331
# Training accuracy ... 1.0
# EPOCHS ... 365
# Validation accuracy ... 0.8716553290685017
# Training accuracy ... 1.0
# EPOCHS ... 366
# Validation accuracy ... 0.8548752837440594
# Training accuracy ... 1.0
# EPOCHS ... 367
# Validation accuracy ... 0.8451247166073511
# Training accuracy ... 1.0
# EPOCHS ... 368
# Validation accuracy ... 0.8401360544758318
# Training accuracy ... 1.0
# EPOCHS ... 369
# Validation accuracy ... 0.8412698415671888
# Training accuracy ... 1.0
# EPOCHS ... 370
# Validation accuracy ... 0.8562358274211148
# Training accuracy ... 1.0
# EPOCHS ... 371
# Validation accuracy ... 0.8578231292517007
# Training accuracy ... 1.0
# EPOCHS ... 372
# Validation accuracy ... 0.8582766439909297
# Training accuracy ... 1.0
# EPOCHS ... 373
# Validation accuracy ... 0.8587301587301587
# Training accuracy ... 1.0
# EPOCHS ... 374
# Validation accuracy ... 0.8564625853043295
# Training accuracy ... 0.800000011920929
# EPOCHS ... 375
# Validation accuracy ... 0.8517006800288246
# Training accuracy ... 0.800000011920929
# EPOCHS ... 376
# Validation accuracy ... 0.8555555553122713
# Training accuracy ... 0.800000011920929
# EPOCHS ... 377
# Validation accuracy ... 0.8535147389857407
# Training accuracy ... 0.800000011920929
# EPOCHS ... 378
# Validation accuracy ... 0.8503401358111375
# Training accuracy ... 0.800000011920929
# EPOCHS ... 379
# Validation accuracy ... 0.8462585034013606
# Training accuracy ... 0.800000011920929
# EPOCHS ... 380
# Validation accuracy ... 0.8462585036716764
# Training accuracy ... 0.800000011920929
# EPOCHS ... 381
# Validation accuracy ... 0.8557823131954859
# Training accuracy ... 0.800000011920929
# EPOCHS ... 382
# Validation accuracy ... 0.856235827934715
# Training accuracy ... 0.800000011920929
# EPOCHS ... 383
# Validation accuracy ... 0.8564625853043295
# Training accuracy ... 1.0
# EPOCHS ... 384
# Validation accuracy ... 0.856235827934715
# Training accuracy ... 1.0
# EPOCHS ... 385
# Validation accuracy ... 0.8528344671201814
# Training accuracy ... 1.0
# EPOCHS ... 386
# Validation accuracy ... 0.8519274376417234
# Training accuracy ... 1.0
# EPOCHS ... 387
# Validation accuracy ... 0.85578231292517
# Training accuracy ... 1.0
# EPOCHS ... 388
# Validation accuracy ... 0.8480725626285925
# Training accuracy ... 1.0
# EPOCHS ... 389
# Validation accuracy ... 0.8458049886891631
# Training accuracy ... 1.0
# EPOCHS ... 390
# Validation accuracy ... 0.8521541953086853
# Training accuracy ... 1.0
# EPOCHS ... 391
# Validation accuracy ... 0.8587301590275062
# Training accuracy ... 0.800000011920929
# EPOCHS ... 392
# Validation accuracy ... 0.8596371879923641
# Training accuracy ... 1.0
# EPOCHS ... 393
# Validation accuracy ... 0.8532879816431578
# Training accuracy ... 1.0
# EPOCHS ... 394
# Validation accuracy ... 0.8505668932077836
# Training accuracy ... 1.0
# EPOCHS ... 395
# Validation accuracy ... 0.8485260771245372
# Training accuracy ... 1.0
# EPOCHS ... 396
# Validation accuracy ... 0.8473922900061488
# Training accuracy ... 1.0
# EPOCHS ... 397
# Validation accuracy ... 0.8523809526512682
# Training accuracy ... 1.0
# EPOCHS ... 398
# Validation accuracy ... 0.8575963718820862
# Training accuracy ... 1.0
# EPOCHS ... 399
# Validation accuracy ... 0.8727891159165744
# Training accuracy ... 1.0
# EPOCHS ... 400
# Validation accuracy ... 0.8750566896127194
# Training accuracy ... 1.0
# EPOCHS ... 401
# Validation accuracy ... 0.8668934240362812
# Training accuracy ... 1.0
# EPOCHS ... 402
# Validation accuracy ... 0.8621315190310922
# Training accuracy ... 1.0
# EPOCHS ... 403
# Validation accuracy ... 0.8537414963553552
# Training accuracy ... 1.0
# EPOCHS ... 404
# Validation accuracy ... 0.8535147389857407
# Training accuracy ... 1.0
# EPOCHS ... 405
# Validation accuracy ... 0.8614512469222486
# Training accuracy ... 1.0
# EPOCHS ... 406
# Validation accuracy ... 0.8725623580333597
# Training accuracy ... 1.0
# EPOCHS ... 407
# Validation accuracy ... 0.8814058954483257
# Training accuracy ... 1.0
# EPOCHS ... 408
# Validation accuracy ... 0.8825396825667141
# Training accuracy ... 1.0
# EPOCHS ... 409
# Validation accuracy ... 0.8791383220224964
# Training accuracy ... 1.0
# EPOCHS ... 410
# Validation accuracy ... 0.8816326528179402
# Training accuracy ... 0.800000011920929
# EPOCHS ... 411
# Validation accuracy ... 0.882766439909297
# Training accuracy ... 0.800000011920929
# EPOCHS ... 412
# Validation accuracy ... 0.8782312925170068
# Training accuracy ... 0.800000011920929
# EPOCHS ... 413
# Validation accuracy ... 0.8712018140589569
# Training accuracy ... 0.800000011920929
# EPOCHS ... 414
# Validation accuracy ... 0.873015873015873
# Training accuracy ... 0.800000011920929
# EPOCHS ... 415
# Validation accuracy ... 0.8750566893424037
# Training accuracy ... 1.0
# EPOCHS ... 416
# Validation accuracy ... 0.8804988662131519
# Training accuracy ... 1.0
# EPOCHS ... 417
# Validation accuracy ... 0.8782312927873227
# Training accuracy ... 1.0
# EPOCHS ... 418
# Validation accuracy ... 0.8755102043519485
# Training accuracy ... 1.0
# EPOCHS ... 419
# Validation accuracy ... 0.871882086194832
# Training accuracy ... 1.0
# EPOCHS ... 420
# Validation accuracy ... 0.8712018140589569
# Training accuracy ... 1.0
# EPOCHS ... 421
# Validation accuracy ... 0.8750566893424037
# Training accuracy ... 1.0
# EPOCHS ... 422
# Validation accuracy ... 0.873015873015873
# Training accuracy ... 1.0
# EPOCHS ... 423
# Validation accuracy ... 0.8646258503401361
# Training accuracy ... 1.0
# EPOCHS ... 424
# Validation accuracy ... 0.8650793650793651
# Training accuracy ... 1.0
# EPOCHS ... 425
# Validation accuracy ... 0.863265306122449
# Training accuracy ... 1.0
# EPOCHS ... 426
# Validation accuracy ... 0.8671201814058956
# Training accuracy ... 1.0
# EPOCHS ... 427
# Validation accuracy ... 0.8659863945578231
# Training accuracy ... 0.800000011920929
# EPOCHS ... 428
# Validation accuracy ... 0.873922902494331
# Training accuracy ... 0.800000011920929
# EPOCHS ... 429
# Validation accuracy ... 0.8800453514739229
# Training accuracy ... 0.800000011920929
# EPOCHS ... 430
# Validation accuracy ... 0.8786848072562359
# Training accuracy ... 0.800000011920929
# EPOCHS ... 431
# Validation accuracy ... 0.8829931972789116
# Training accuracy ... 0.800000011920929
# EPOCHS ... 432
# Validation accuracy ... 0.8852607709750567
# Training accuracy ... 0.800000011920929
# EPOCHS ... 433
# Validation accuracy ... 0.8825396825396825
# Training accuracy ... 1.0
# EPOCHS ... 434
# Validation accuracy ... 0.8721088435374149
# Training accuracy ... 1.0
# EPOCHS ... 435
# Validation accuracy ... 0.857596372152402
# Training accuracy ... 1.0
# EPOCHS ... 436
# Validation accuracy ... 0.8569161000435584
# Training accuracy ... 1.0
# EPOCHS ... 437
# Validation accuracy ... 0.8662131519274376
# Training accuracy ... 1.0
# EPOCHS ... 438
# Validation accuracy ... 0.8709750566893424
# Training accuracy ... 1.0
# EPOCHS ... 439
# Validation accuracy ... 0.8666666666666667
# Training accuracy ... 1.0
# EPOCHS ... 440
# Validation accuracy ... 0.8680272108843538
# Training accuracy ... 1.0
# EPOCHS ... 441
# Validation accuracy ... 0.8723356009070294
# Training accuracy ... 1.0
# EPOCHS ... 442
# Validation accuracy ... 0.8782312925170068
# Training accuracy ... 1.0
# EPOCHS ... 443
# Validation accuracy ... 0.881859410430839
# Training accuracy ... 1.0
# EPOCHS ... 444
# Validation accuracy ... 0.8820861680707693
# Training accuracy ... 1.0
# EPOCHS ... 445
# Validation accuracy ... 0.8845804988662131
# Training accuracy ... 1.0
# EPOCHS ... 446
# Validation accuracy ... 0.891156462585034
# Training accuracy ... 1.0
# EPOCHS ... 447
# Validation accuracy ... 0.8952380952380953
# Training accuracy ... 1.0
# EPOCHS ... 448
# Validation accuracy ... 0.8947845804988662
# Training accuracy ... 1.0
# EPOCHS ... 449
# Validation accuracy ... 0.8934240362811792
# Training accuracy ... 1.0
# EPOCHS ... 450
# Validation accuracy ... 0.8852607709750567
# Training accuracy ... 1.0
# EPOCHS ... 451
# Validation accuracy ... 0.8732426303854876
# Training accuracy ... 1.0
# EPOCHS ... 452
# Validation accuracy ... 0.8705215419501133
# Training accuracy ... 1.0
# EPOCHS ... 453
# Validation accuracy ... 0.8707482993197279
# Training accuracy ... 1.0
# EPOCHS ... 454
# Validation accuracy ... 0.8782312925170068
# Training accuracy ... 1.0
# EPOCHS ... 455
# Validation accuracy ... 0.8882086167800454
# Training accuracy ... 1.0
# EPOCHS ... 456
# Validation accuracy ... 0.8895691609977324
# Training accuracy ... 1.0
# EPOCHS ... 457
# Validation accuracy ... 0.8841269841269841
# Training accuracy ... 1.0
# EPOCHS ... 458
# Validation accuracy ... 0.881859410430839
# Training accuracy ... 1.0
# EPOCHS ... 459
# Validation accuracy ... 0.8780045351473923
# Training accuracy ... 1.0
# EPOCHS ... 460
# Validation accuracy ... 0.8702947845804989
# Training accuracy ... 1.0
# EPOCHS ... 461
# Validation accuracy ... 0.8682539682539683
# Training accuracy ... 0.800000011920929
# EPOCHS ... 462
# Validation accuracy ... 0.8759637188208617
# Training accuracy ... 1.0
# EPOCHS ... 463
# Validation accuracy ... 0.8836734693877552
# Training accuracy ... 1.0
# EPOCHS ... 464
# Validation accuracy ... 0.890702947845805
# Training accuracy ... 1.0
# EPOCHS ... 465
# Validation accuracy ... 0.8875283446712018
# Training accuracy ... 1.0
# EPOCHS ... 466
# Validation accuracy ... 0.8870748299319728
# Training accuracy ... 1.0
# EPOCHS ... 467
# Validation accuracy ... 0.8886621315192744
# Training accuracy ... 1.0
# EPOCHS ... 468
# Validation accuracy ... 0.8841269841269841
# Training accuracy ... 1.0
# EPOCHS ... 469
# Validation accuracy ... 0.8789115646258503
# Training accuracy ... 1.0
# EPOCHS ... 470
# Validation accuracy ... 0.8707482993197279
# Training accuracy ... 1.0
# EPOCHS ... 471
# Validation accuracy ... 0.8755102040816326
# Training accuracy ... 1.0
# EPOCHS ... 472
# Validation accuracy ... 0.8687074829931973
# Training accuracy ... 1.0
# EPOCHS ... 473
# Validation accuracy ... 0.8591836734693877
# Training accuracy ... 1.0
# EPOCHS ... 474
# Validation accuracy ... 0.861904761904762
# Training accuracy ... 1.0
# EPOCHS ... 475
# Validation accuracy ... 0.8671201814058956
# Training accuracy ... 1.0
# EPOCHS ... 476
# Validation accuracy ... 0.8766439909297052
# Training accuracy ... 1.0
# EPOCHS ... 477
# Validation accuracy ... 0.8791383219954648
# Training accuracy ... 1.0
# EPOCHS ... 478
# Validation accuracy ... 0.8825396825396825
# Training accuracy ... 1.0
# EPOCHS ... 479
# Validation accuracy ... 0.8809523809523809
# Training accuracy ... 1.0
# EPOCHS ... 480
# Validation accuracy ... 0.890249433106576
# Training accuracy ... 1.0
# EPOCHS ... 481
# Validation accuracy ... 0.8916099773242631
# Training accuracy ... 1.0
# EPOCHS ... 482
# Validation accuracy ... 0.8857142857142857
# Training accuracy ... 1.0
# EPOCHS ... 483
# Validation accuracy ... 0.8773242630385487
# Training accuracy ... 1.0
# EPOCHS ... 484
# Validation accuracy ... 0.8666666666666667
# Training accuracy ... 1.0
# EPOCHS ... 485
# Validation accuracy ... 0.8623582766439909
# Training accuracy ... 1.0
# EPOCHS ... 486
# Validation accuracy ... 0.8689342403628117
# Training accuracy ... 1.0
# EPOCHS ... 487
# Validation accuracy ... 0.8793650793650793
# Training accuracy ... 1.0
# EPOCHS ... 488
# Validation accuracy ... 0.8854875283446711
# Training accuracy ... 1.0
# EPOCHS ... 489
# Validation accuracy ... 0.8770975056689342
# Training accuracy ... 1.0
# EPOCHS ... 490
# Validation accuracy ... 0.8770975056689342
# Training accuracy ... 1.0
# EPOCHS ... 491
# Validation accuracy ... 0.8777777777777778
# Training accuracy ... 1.0
# EPOCHS ... 492
# Validation accuracy ... 0.8777777777777778
# Training accuracy ... 1.0
# EPOCHS ... 493
# Validation accuracy ... 0.8750566896127194
# Training accuracy ... 1.0
# EPOCHS ... 494
# Validation accuracy ... 0.8702947848508147
# Training accuracy ... 1.0
# EPOCHS ... 495
# Validation accuracy ... 0.8673469387755102
# Training accuracy ... 1.0
# EPOCHS ... 496
# Validation accuracy ... 0.8755102040816326
# Training accuracy ... 1.0
# EPOCHS ... 497
# Validation accuracy ... 0.8802721088435375
# Training accuracy ... 1.0
# EPOCHS ... 498
# Validation accuracy ... 0.8839002267573696
# Training accuracy ... 1.0
# EPOCHS ... 499
# Validation accuracy ... 0.8804988662131519
# Training accuracy ... 1.0
# EPOCHS ... 500
# Validation accuracy ... 0.8802721088435375
# Training accuracy ... 1.0
# EPOCHS ... 501
# Validation accuracy ... 0.8859410430839002
# Training accuracy ... 1.0
# EPOCHS ... 502
# Validation accuracy ... 0.8882086167800454
# Training accuracy ... 1.0
# EPOCHS ... 503
# Validation accuracy ... 0.8863945578231293
# Training accuracy ... 1.0
# EPOCHS ... 504
# Validation accuracy ... 0.8863945578231293
# Training accuracy ... 1.0
# EPOCHS ... 505
# Validation accuracy ... 0.8884353741496599
# Training accuracy ... 1.0
# EPOCHS ... 506
# Validation accuracy ... 0.8922902494331065
# Training accuracy ... 1.0
# EPOCHS ... 507
# Validation accuracy ... 0.8938775510204081
# Training accuracy ... 1.0
# EPOCHS ... 508
# Validation accuracy ... 0.8952380952380953
# Training accuracy ... 1.0
# EPOCHS ... 509
# Validation accuracy ... 0.8963718820861678
# Training accuracy ... 1.0
# EPOCHS ... 510
# Validation accuracy ... 0.8927437641723356
# Training accuracy ... 1.0
# EPOCHS ... 511
# Validation accuracy ... 0.8832199546485261
# Training accuracy ... 1.0
# EPOCHS ... 512
# Validation accuracy ... 0.8811791383219955
# Training accuracy ... 1.0
# EPOCHS ... 513
# Validation accuracy ... 0.8761904761904762
# Training accuracy ... 1.0
# EPOCHS ... 514
# Validation accuracy ... 0.8709750566893424
# Training accuracy ... 1.0
# EPOCHS ... 515
# Validation accuracy ... 0.8702947845804989
# Training accuracy ... 1.0
# EPOCHS ... 516
# Validation accuracy ... 0.8705215419501133
# Training accuracy ... 1.0
# EPOCHS ... 517
# Validation accuracy ... 0.882766439909297
# Training accuracy ... 1.0
# EPOCHS ... 518
# Validation accuracy ... 0.8875283446712018
# Training accuracy ... 1.0
# EPOCHS ... 519
# Validation accuracy ... 0.8916099773242631
# Training accuracy ... 1.0
# EPOCHS ... 520
# Validation accuracy ... 0.8938775510204081
# Training accuracy ... 1.0
# EPOCHS ... 521
# Validation accuracy ... 0.8922902494331065
# Training accuracy ... 1.0
# EPOCHS ... 522
# Validation accuracy ... 0.8891156462585034
# Training accuracy ... 1.0
# EPOCHS ... 523
# Validation accuracy ... 0.8879818594104308
# Training accuracy ... 1.0
# EPOCHS ... 524
# Validation accuracy ... 0.8809523809523809
# Training accuracy ... 1.0
# EPOCHS ... 525
# Validation accuracy ... 0.8789115646258503
# Training accuracy ... 1.0
# EPOCHS ... 526
# Validation accuracy ... 0.8777777777777778
# Training accuracy ... 1.0
# EPOCHS ... 527
# Validation accuracy ... 0.8798185941043084
# Training accuracy ... 1.0
# EPOCHS ... 528
# Validation accuracy ... 0.8861678004535147
# Training accuracy ... 1.0
# EPOCHS ... 529
# Validation accuracy ... 0.8936507936507937
# Training accuracy ... 1.0
# EPOCHS ... 530
# Validation accuracy ... 0.8943310657596372
# Training accuracy ... 1.0
# EPOCHS ... 531
# Validation accuracy ... 0.8938775510204081
# Training accuracy ... 1.0
# EPOCHS ... 532
# Validation accuracy ... 0.8936507936507937
# Training accuracy ... 1.0
# EPOCHS ... 533
# Validation accuracy ... 0.8956916099773242
# Training accuracy ... 1.0
# EPOCHS ... 534
# Validation accuracy ... 0.8959183673469387
# Training accuracy ... 1.0
# EPOCHS ... 535
# Validation accuracy ... 0.8943310657596372
# Training accuracy ... 1.0
# EPOCHS ... 536
# Validation accuracy ... 0.8843537414965986
# Training accuracy ... 1.0
# EPOCHS ... 537
# Validation accuracy ... 0.8773242630385487
# Training accuracy ... 1.0
# EPOCHS ... 538
# Validation accuracy ... 0.8668934240362812
# Training accuracy ... 1.0
# EPOCHS ... 539
# Validation accuracy ... 0.872562358276644
# Training accuracy ... 1.0
# EPOCHS ... 540
# Validation accuracy ... 0.8780045351473923
# Training accuracy ... 1.0
# EPOCHS ... 541
# Validation accuracy ... 0.8854875283446711
# Training accuracy ... 1.0
# EPOCHS ... 542
# Validation accuracy ... 0.8886621315192744
# Training accuracy ... 1.0
# EPOCHS ... 543
# Validation accuracy ... 0.8936507936507937
# Training accuracy ... 0.800000011920929
# EPOCHS ... 544
# Validation accuracy ... 0.8927437641723356
# Training accuracy ... 1.0
# EPOCHS ... 545
# Validation accuracy ... 0.890249433106576
# Training accuracy ... 1.0
# EPOCHS ... 546
# ...
# Training accuracy ... 1.0
# EPOCHS ... 814
# Validation accuracy ... 0.9077097505668934
# Training accuracy ... 1.0
# EPOCHS ... 815
# Validation accuracy ... 0.9058956916099773
# Training accuracy ... 1.0
# EPOCHS ... 816
# Validation accuracy ... 0.9045351476626061
# Training accuracy ... 1.0
# EPOCHS ... 817
# Validation accuracy ... 0.9079365082068238
# Training accuracy ... 1.0
# EPOCHS ... 818
# Validation accuracy ... 0.909297052154195
# Training accuracy ... 1.0
# EPOCHS ... 819
# Validation accuracy ... 0.9027210884353741
# Training accuracy ... 1.0
# EPOCHS ... 820
# Validation accuracy ... 0.8984126984126984
# Training accuracy ... 1.0
# EPOCHS ... 821
# Validation accuracy ... 0.8965986397260982
# Training accuracy ... 1.0
# EPOCHS ... 822
# Validation accuracy ... 0.9009070297487739
# Training accuracy ... 1.0
# EPOCHS ... 823
# Validation accuracy ... 0.9029478460753045
# Training accuracy ... 1.0
# EPOCHS ... 824
# Validation accuracy ... 0.8979591839437853
# Training accuracy ... 1.0
# EPOCHS ... 825
# Validation accuracy ... 0.8965986397260982
# Training accuracy ... 1.0
# EPOCHS ... 826
# Validation accuracy ... 0.8936507936507937
# Training accuracy ... 1.0
# EPOCHS ... 827
# Validation accuracy ... 0.8941043083900226
# Training accuracy ... 1.0
# EPOCHS ... 828
# Validation accuracy ... 0.8968253968253969
# Training accuracy ... 1.0
# EPOCHS ... 829
# Validation accuracy ... 0.9036281179138322
# Training accuracy ... 1.0
# EPOCHS ... 830
# Validation accuracy ... 0.9077097505668934
# Training accuracy ... 1.0
# EPOCHS ... 831
# Validation accuracy ... 0.910657596371882
# Training accuracy ... 1.0
# EPOCHS ... 832
# Validation accuracy ... 0.9104308390022676
# Training accuracy ... 1.0
# EPOCHS ... 833
# Validation accuracy ... 0.9113378684807256
# Training accuracy ... 1.0
# EPOCHS ... 834
# Validation accuracy ... 0.9099773242630386
# Training accuracy ... 1.0
# EPOCHS ... 835
# Validation accuracy ... 0.9077097505668934
# Training accuracy ... 1.0
# EPOCHS ... 836
# Validation accuracy ... 0.9049886621315193
# Training accuracy ... 1.0
# EPOCHS ... 837
# Validation accuracy ... 0.9020408163265307
# Training accuracy ... 1.0
# EPOCHS ... 838
# Validation accuracy ... 0.899546485260771
# Training accuracy ... 1.0
# EPOCHS ... 839
# Validation accuracy ... 0.8977324263038549
# Training accuracy ... 1.0
# EPOCHS ... 840
# Validation accuracy ... 0.8975056689342403
# Training accuracy ... 1.0
# EPOCHS ... 841
# Validation accuracy ... 0.9038548752834467
# Training accuracy ... 1.0
# EPOCHS ... 842
# Validation accuracy ... 0.9054421768707483
# Training accuracy ... 1.0
# EPOCHS ... 843
# Validation accuracy ... 0.9086167800453515
# Training accuracy ... 1.0
# EPOCHS ... 844
# Validation accuracy ... 0.9122448979591836
# Training accuracy ... 1.0
# EPOCHS ... 845
# Validation accuracy ... 0.9156462585034013
# Training accuracy ... 1.0
# EPOCHS ... 846
# Validation accuracy ... 0.9120181405895692
# Training accuracy ... 1.0
# EPOCHS ... 847
# Validation accuracy ... 0.9049886621315193
# Training accuracy ... 1.0
# EPOCHS ... 848
# Validation accuracy ... 0.9090702947845805
# Training accuracy ... 1.0
# EPOCHS ... 849
# Validation accuracy ... 0.9138321995464853
# Training accuracy ... 1.0
# EPOCHS ... 850
# Validation accuracy ... 0.909297052154195
# Training accuracy ... 1.0
# EPOCHS ... 851
# Validation accuracy ... 0.9027210884353741
# Training accuracy ... 1.0
# EPOCHS ... 852
# Validation accuracy ... 0.900907029478458
# Training accuracy ... 1.0
# EPOCHS ... 853
# Validation accuracy ... 0.9002267573696145
# Training accuracy ... 1.0
# EPOCHS ... 854
# Validation accuracy ... 0.8936507939211095
# Training accuracy ... 1.0
# EPOCHS ... 855
# Validation accuracy ... 0.8897959186376628
# Training accuracy ... 1.0
# EPOCHS ... 856
# Validation accuracy ... 0.8904761907465063
# Training accuracy ... 1.0
# EPOCHS ... 857
# Validation accuracy ... 0.8950113381387965
# Training accuracy ... 1.0
# EPOCHS ... 858
# Validation accuracy ... 0.8950113381387965
# Training accuracy ... 1.0
# EPOCHS ... 859
# Validation accuracy ... 0.8925170070730369
# Training accuracy ... 1.0
# EPOCHS ... 860
# Validation accuracy ... 0.8947845807691821
# Training accuracy ... 1.0
# EPOCHS ... 861
# Validation accuracy ... 0.9011337871183884
# Training accuracy ... 1.0
# EPOCHS ... 862
# Validation accuracy ... 0.9038548755537625
# Training accuracy ... 1.0
# EPOCHS ... 863
# Validation accuracy ... 0.8993197281614723
# Training accuracy ... 1.0
# EPOCHS ... 864
# Validation accuracy ... 0.8965986397260982
# Training accuracy ... 1.0
# EPOCHS ... 865
# Validation accuracy ... 0.9024943313360755
# Training accuracy ... 1.0
# EPOCHS ... 866
# Validation accuracy ... 0.8995464855310868
# Training accuracy ... 1.0
# EPOCHS ... 867
# Validation accuracy ... 0.901360544488003
# Training accuracy ... 1.0
# EPOCHS ... 868
# Validation accuracy ... 0.9029478460753045
# Training accuracy ... 1.0
# EPOCHS ... 869
# Validation accuracy ... 0.9031746034449191
# Training accuracy ... 1.0
# EPOCHS ... 870
# Validation accuracy ... 0.9056689345106786
# Training accuracy ... 1.0
# EPOCHS ... 871
# Validation accuracy ... 0.9015873018576175
# Training accuracy ... 1.0
# EPOCHS ... 872
# Validation accuracy ... 0.9004535150095448
# Training accuracy ... 1.0
# EPOCHS ... 873
# Validation accuracy ... 0.9029478460753045
# Training accuracy ... 1.0
# EPOCHS ... 874
# Validation accuracy ... 0.9063492066195222
# Training accuracy ... 1.0
# EPOCHS ... 875
# Validation accuracy ... 0.9065759639891368
# Training accuracy ... 1.0
# EPOCHS ... 876
# Validation accuracy ... 0.9074829934675948
# Training accuracy ... 1.0
# EPOCHS ... 877
# Validation accuracy ... 0.9115646256070559
# Training accuracy ... 1.0
# EPOCHS ... 878
# Validation accuracy ... 0.9086167798020672
# Training accuracy ... 1.0
# EPOCHS ... 879
# Validation accuracy ... 0.905895691366693
# Training accuracy ... 1.0
# EPOCHS ... 880
# Validation accuracy ... 0.9056689342673944
# Training accuracy ... 1.0
# EPOCHS ... 881
# Validation accuracy ... 0.8963718821131994
# Training accuracy ... 1.0
# EPOCHS ... 882
# Validation accuracy ... 0.9004535147662606
# Training accuracy ... 1.0
# EPOCHS ... 883
# Validation accuracy ... 0.9024943308224753
# Training accuracy ... 1.0
# EPOCHS ... 884
# Validation accuracy ... 0.903628117670548
# Training accuracy ... 1.0
# EPOCHS ... 885
# Validation accuracy ... 0.904988661888235
# Training accuracy ... 1.0
# EPOCHS ... 886
# Validation accuracy ... 0.9058956916099773
# Training accuracy ... 1.0
# EPOCHS ... 887
# Validation accuracy ... 0.908390022675737
# Training accuracy ... 1.0
# EPOCHS ... 888
# Validation accuracy ... 0.9077097505668934
# Training accuracy ... 1.0
# EPOCHS ... 889
# Validation accuracy ... 0.9086167800453515
# Training accuracy ... 1.0
# EPOCHS ... 890
# Validation accuracy ... 0.9072562358276643
# Training accuracy ... 1.0
# EPOCHS ... 891
# Validation accuracy ... 0.9047619047619048
# Training accuracy ... 1.0
# EPOCHS ... 892
# Validation accuracy ... 0.9061224489795918
# Training accuracy ... 1.0
# EPOCHS ... 893
# Validation accuracy ... 0.9099773242630386
# Training accuracy ... 1.0
# EPOCHS ... 894
# Validation accuracy ... 0.9086167800453515
# Training accuracy ... 1.0
# EPOCHS ... 895
# Validation accuracy ... 0.908390022675737
# Training accuracy ... 1.0
# EPOCHS ... 896
# Validation accuracy ... 0.9113378684807256
# Training accuracy ... 1.0
# EPOCHS ... 897
# Validation accuracy ... 0.9122448979591836
# Training accuracy ... 1.0
# EPOCHS ... 898
# Validation accuracy ... 0.9120181405895692
# Training accuracy ... 1.0
# EPOCHS ... 899
# Validation accuracy ... 0.9074829931972789
# Training accuracy ... 1.0
# EPOCHS ... 900
# Validation accuracy ... 0.9038548752834467
# Training accuracy ... 1.0
# EPOCHS ... 901
# Validation accuracy ... 0.9031746031746032
# Training accuracy ... 1.0
# EPOCHS ... 902
# Validation accuracy ... 0.9131519274376417
# Training accuracy ... 1.0
# EPOCHS ... 903
# Validation accuracy ... 0.9170068027210885
# Training accuracy ... 1.0
# EPOCHS ... 904
# Validation accuracy ... 0.9208616780045351
# Training accuracy ... 1.0
# EPOCHS ... 905
# Validation accuracy ... 0.9199546485260771
# Training accuracy ... 1.0
# EPOCHS ... 906
# Validation accuracy ... 0.9179138321995465
# Training accuracy ... 1.0
# EPOCHS ... 907
# Validation accuracy ... 0.9145124716553288
# Training accuracy ... 1.0
# EPOCHS ... 908
# Validation accuracy ... 0.9149659863945578
# Training accuracy ... 1.0
# EPOCHS ... 909
# Validation accuracy ... 0.9117913832199547
# Training accuracy ... 1.0
# EPOCHS ... 910
# Validation accuracy ... 0.9120181405895692
# Training accuracy ... 1.0
# EPOCHS ... 911
# Validation accuracy ... 0.9122448979591836
# Training accuracy ... 1.0
# EPOCHS ... 912
# Validation accuracy ... 0.9081632653061225
# Training accuracy ... 1.0
# EPOCHS ... 913
# Validation accuracy ... 0.9049886621315193
# Training accuracy ... 1.0
# EPOCHS ... 914
# Validation accuracy ... 0.8997732426303855
# Training accuracy ... 1.0
# EPOCHS ... 915
# Validation accuracy ... 0.8988662131519274
# Training accuracy ... 1.0
# EPOCHS ... 916
# Validation accuracy ... 0.9
# Training accuracy ... 1.0
# EPOCHS ... 917
# Validation accuracy ... 0.9034013605442177
# Training accuracy ... 1.0
# EPOCHS ... 918
# Validation accuracy ... 0.9031746031746032
# Training accuracy ... 1.0
# EPOCHS ... 919
# Validation accuracy ... 0.9040816326530612
# Training accuracy ... 1.0
# EPOCHS ... 920
# Validation accuracy ... 0.9002267573696145
# Training accuracy ... 1.0
# EPOCHS ... 921
# Validation accuracy ... 0.8975056689342403
# Training accuracy ... 1.0
# EPOCHS ... 922
# Validation accuracy ... 0.8972789115646258
# Training accuracy ... 1.0
# EPOCHS ... 923
# Validation accuracy ... 0.900907029478458
# Training accuracy ... 1.0
# EPOCHS ... 924
# Validation accuracy ... 0.9052154195011338
# Training accuracy ... 1.0
# EPOCHS ... 925
# Validation accuracy ... 0.9058956916099773
# Training accuracy ... 1.0
# EPOCHS ... 926
# Validation accuracy ... 0.9029478458049887
# Training accuracy ... 1.0
# EPOCHS ... 927
# Validation accuracy ... 0.9036281179138322
# Training accuracy ... 1.0
# EPOCHS ... 928
# Validation accuracy ... 0.9070294784580499
# Training accuracy ... 1.0
# EPOCHS ... 929
# Validation accuracy ... 0.9047619050322206
# Training accuracy ... 1.0
# EPOCHS ... 930
# Validation accuracy ... 0.8975056692045562
# Training accuracy ... 1.0
# EPOCHS ... 931
# Validation accuracy ... 0.8956916102476401
# Training accuracy ... 1.0
# EPOCHS ... 932
# Validation accuracy ... 0.8993197281614723
# Training accuracy ... 1.0
# EPOCHS ... 933
# Validation accuracy ... 0.9056689342403628
# Training accuracy ... 1.0
# EPOCHS ... 934
# Validation accuracy ... 0.9090702947845805
# Training accuracy ... 1.0
# EPOCHS ... 935
# Validation accuracy ... 0.8927437641723356
# Training accuracy ... 1.0
# EPOCHS ... 936
# Validation accuracy ... 0.9122448979591836
# Training accuracy ... 1.0
# EPOCHS ... 937
# Validation accuracy ... 0.9129251700680272
# Training accuracy ... 1.0
# EPOCHS ... 938
# Validation accuracy ... 0.8981859410430839
# Training accuracy ... 1.0
# EPOCHS ... 939
# Validation accuracy ... 0.8854875283446711
# Training accuracy ... 0.800000011920929
# EPOCHS ... 940
# Validation accuracy ... 0.891156462585034
# Training accuracy ... 0.800000011920929
# EPOCHS ... 941
# Validation accuracy ... 0.8975056689342403
# Training accuracy ... 1.0
# EPOCHS ... 942
# Validation accuracy ... 0.8947845804988662
# Training accuracy ... 1.0
# EPOCHS ... 943
# Validation accuracy ... 0.8884353741496599
# Training accuracy ... 1.0
# EPOCHS ... 944
# Validation accuracy ... 0.8950113378684807
# Training accuracy ... 1.0
# EPOCHS ... 945
# Validation accuracy ... 0.9022675736961451
# Training accuracy ... 1.0
# EPOCHS ... 946
# Validation accuracy ... 0.9018140589569161
# Training accuracy ... 1.0
# EPOCHS ... 947
# Validation accuracy ... 0.8938775510204081
# Training accuracy ... 1.0
# EPOCHS ... 948
# Validation accuracy ... 0.8888888888888888
# Training accuracy ... 1.0
# EPOCHS ... 949
# Validation accuracy ... 0.898639455782313
# Training accuracy ... 1.0
# EPOCHS ... 950
# Validation accuracy ... 0.9054421768707483
# Training accuracy ... 1.0
# EPOCHS ... 951
# Validation accuracy ... 0.9013605442176871
# Training accuracy ... 0.800000011920929
# EPOCHS ... 952
# Validation accuracy ... 0.8965986397260982
# Training accuracy ... 0.800000011920929
# EPOCHS ... 953
# Validation accuracy ... 0.894331066029953
# Training accuracy ... 0.800000011920929
# EPOCHS ... 954
# Validation accuracy ... 0.894331066029953
# Training accuracy ... 0.800000011920929
# EPOCHS ... 955
# Validation accuracy ... 0.8931972791818805
# Training accuracy ... 0.800000011920929
# EPOCHS ... 956
# Validation accuracy ... 0.8954648528780256
# Training accuracy ... 0.800000011920929
# EPOCHS ... 957
# Validation accuracy ... 0.901360544488003
# Training accuracy ... 0.800000011920929
# EPOCHS ... 958
# Validation accuracy ... 0.903628118184148
# Training accuracy ... 1.0
# EPOCHS ... 959
# Validation accuracy ... 0.9047619047619048
# Training accuracy ... 1.0
# EPOCHS ... 960
# Validation accuracy ... 0.8997732426303855
# Training accuracy ... 1.0
# EPOCHS ... 961
# Validation accuracy ... 0.9015873015873016
# Training accuracy ... 1.0
# EPOCHS ... 962
# Validation accuracy ... 0.9020408163265307
# Training accuracy ... 1.0
# EPOCHS ... 963
# Validation accuracy ... 0.9022675736961451
# Training accuracy ... 0.800000011920929
# EPOCHS ... 964
# Validation accuracy ... 0.9011337868480725
# Training accuracy ... 0.800000011920929
# EPOCHS ... 965
# Validation accuracy ... 0.8954648526077098
# Training accuracy ... 0.800000011920929
# EPOCHS ... 966
# Validation accuracy ... 0.8943310657596372
# Training accuracy ... 0.800000011920929
# EPOCHS ... 967
# Validation accuracy ... 0.8952380952380953
# Training accuracy ... 0.800000011920929
# EPOCHS ... 968
# Validation accuracy ... 0.9015873015873016
# Training accuracy ... 1.0
# EPOCHS ... 969
# Validation accuracy ... 0.9065759637188209
# Training accuracy ... 1.0
# EPOCHS ... 970
# Validation accuracy ... 0.9149659863945578
# Training accuracy ... 1.0
# EPOCHS ... 971
# Validation accuracy ... 0.9192743764172335
# Training accuracy ... 1.0
# EPOCHS ... 972
# Validation accuracy ... 0.9179138321995465
# Training accuracy ... 1.0
# EPOCHS ... 973
# Validation accuracy ... 0.9147392290249433
# Training accuracy ... 1.0
# EPOCHS ... 974
# Validation accuracy ... 0.9156462585034013
# Training accuracy ... 1.0
# EPOCHS ... 975
# Validation accuracy ... 0.9138321995464853
# Training accuracy ... 1.0
# EPOCHS ... 976
# Validation accuracy ... 0.9126984126984127
# Training accuracy ... 1.0
# EPOCHS ... 977
# Validation accuracy ... 0.9122448979591836
# Training accuracy ... 1.0
# EPOCHS ... 978
# Validation accuracy ... 0.9072562360979802
# Training accuracy ... 1.0
# EPOCHS ... 979
# Validation accuracy ... 0.9015873015873016
# Training accuracy ... 1.0
# EPOCHS ... 980
# Validation accuracy ... 0.8936507936507937
# Training accuracy ... 0.800000011920929
# EPOCHS ... 981
# Validation accuracy ... 0.8895691609977324
# Training accuracy ... 0.800000011920929
# EPOCHS ... 982
# Validation accuracy ... 0.8891156462585034
# Training accuracy ... 0.800000011920929
# EPOCHS ... 983
# Validation accuracy ... 0.8952380952380953
# Training accuracy ... 0.800000011920929
# EPOCHS ... 984
# Validation accuracy ... 0.8975056689342403
# Training accuracy ... 0.800000011920929
# EPOCHS ... 985
# Validation accuracy ... 0.898639455782313
# Training accuracy ... 1.0
# EPOCHS ... 986
# Validation accuracy ... 0.8956916099773242
# Training accuracy ... 1.0
# EPOCHS ... 987
# Validation accuracy ... 0.8943310657596372
# Training accuracy ... 1.0
# EPOCHS ... 988
# Validation accuracy ... 0.8941043083900226
# Training accuracy ... 1.0
# EPOCHS ... 989
# Validation accuracy ... 0.8952380952380953
# Training accuracy ... 1.0
# EPOCHS ... 990
# Validation accuracy ... 0.899546485260771
# Training accuracy ... 1.0
# EPOCHS ... 991
# Validation accuracy ... 0.9031746031746032
# Training accuracy ... 1.0
# EPOCHS ... 992
# Validation accuracy ... 0.9052154195011338
# Training accuracy ... 1.0
# EPOCHS ... 993
# Validation accuracy ... 0.9079365079365079
# Training accuracy ... 1.0
# EPOCHS ... 994
# Validation accuracy ... 0.9070294784580499
# Training accuracy ... 1.0
# EPOCHS ... 995
# Validation accuracy ... 0.9043083900226757
# Training accuracy ... 1.0
# EPOCHS ... 996
# Validation accuracy ... 0.9018140589569161
# Training accuracy ... 1.0
# EPOCHS ... 997
# Validation accuracy ... 0.9018140589569161
# Training accuracy ... 1.0
# EPOCHS ... 998
# Validation accuracy ... 0.8988662131519274
# Training accuracy ... 1.0
# EPOCHS ... 999
# Validation accuracy ... 0.8975056689342403
# Training accuracy ... 1.0
# EPOCHS ... 1000
# Validation accuracy ... 0.9049886624018352
# Training accuracy ... 1.0
# Model saved

# %%
plt.subplot(2,1,1)
plt.plot(accuracy_plot)
plt.show()
plt.subplot(2,1,2)
plt.plot(training_accuracy_plot)
plt.show()

# %%
#print hyper parameters
print("EPOCHS",EPOCH)
print("rate",rate)
print("mu",global_mu)
print("sigma",global_sigma)
print("batch size",BATCH_SIZE)
print("Max validation accuracy achieved", max(accuracy_plot))
# Out:
# EPOCHS 1000
# rate 0.01
# mu 0.0
# sigma 0.1
# batch size 256
# Max validation accuracy achieved 0.920861678005

# %%
label_names=["Speed limit (20km/h)","Speed limit (30km/h)","Speed limit (50km/h)","Speed limit (60km/h)","Speed limit (70km/h)","Speed limit (80km/h)","End of speed limit (80km/h)","Speed limit (100km/h)","Speed limit (120km/h)","No passing","No passing for vehicles over 3.5 metric tons","Right-of-way at the next intersection","Priority road","Yield","Stop","No vehicles","Vehicles over 3.5 metric tons prohibited","No entry","General caution","Dangerous curve to the left","Dangerous curve to the right","Double curve","Bumpy road","Slippery road","Road narrows on the right","Road work","Traffic signals","Pedestrians","Children crossing","Bicycles crossing","Beware of ice/snow","Wild animals crossing","End of all speed and passing limits","Turn right ahead","Turn left ahead","Ahead only","Go straight or right","Go straight or left","Keep right","Keep left","Roundabout mandatory","End of no passing","End of no passing by vehicles over 3.5 metric tons",
]

# %% [markdown]
# ---
#
# ## Step 3: Test a Model on New Images
#
# To give yourself more insight into how your model is working, download at least five pictures of German traffic signs from the web and use your model to predict the traffic sign type.
#
# You may find `signnames.csv` useful as it contains mappings from the class id (integer) to the actual sign name.

# %% [markdown]
# ### Load and Output the Images

# %%
#Loaded before training

# %% [markdown]
# ### Predict the Sign Type for Each Image

# %%
def get_softmax_probs(X_data, sess): 
    prob = sess.run(tf.nn.softmax(logits), feed_dict={x: X_data, keep_prob: 1.0})    
    top_5 = tf.nn.top_k(prob, k=5)
    return sess.run(top_5)


with tf.Session() as sess:
    saver.restore(sess, './lenet')
    signs_top_5=get_softmax_probs(test_images_processed, sess)

plt.figure(figsize=(16, 21))
for i in range(5):
    plt.subplot(12, 2, 2*i+1)
    plt.imshow(np.reshape(test_images_processed[i],(32,32)),cmap='gray' )
    plt.title(i)
    plt.axis('off')
    plt.subplot(12, 2, 2*i+2)
    plt.barh(np.arange(1, 6, 1), signs_top_5.values[i, :])
    labs=[label_names[j] for j in signs_top_5.indices[i]]
    plt.yticks(np.arange(1, 6, 1), labs)
plt.show()

# %% [markdown]
# ### Analyze Performance

# %%
### Calculate the accuracy for these 5 new images. 
### For example, if the model predicted 1 out of 5 signs correctly, it's 20% accurate on these new images.
print (training_accuracy_plot[-1] * 100)
# Out:
# 100.0

# %% [markdown]
# ### Output Top 5 Softmax Probabilities For Each Image Found on the Web

# %% [markdown]
# For each of the new images, print out the model's softmax probabilities to show the **certainty** of the model's predictions (limit the output to the top 5 probabilities for each image). [`tf.nn.top_k`](https://www.tensorflow.org/versions/r0.12/api_docs/python/nn.html#top_k) could prove helpful here.
#
# The example below demonstrates how tf.nn.top_k can be used to find the top k predictions for each image.
#
# `tf.nn.top_k` will return the values and indices (class ids) of the top k predictions. So if k=3, for each sign, it'll return the 3 largest probabilities (out of a possible 43) and the correspoding class ids.
#
# Take this numpy array as an example. The values in the array represent predictions. The array contains softmax probabilities for five candidate images with six possible classes. `tk.nn.top_k` is used to choose the three classes with the highest probability:
#
# ```
# # (5, 6) array
# a = np.array([[ 0.24879643,  0.07032244,  0.12641572,  0.34763842,  0.07893497,
#          0.12789202],
#        [ 0.28086119,  0.27569815,  0.08594638,  0.0178669 ,  0.18063401,
#          0.15899337],
#        [ 0.26076848,  0.23664738,  0.08020603,  0.07001922,  0.1134371 ,
#          0.23892179],
#        [ 0.11943333,  0.29198961,  0.02605103,  0.26234032,  0.1351348 ,
#          0.16505091],
#        [ 0.09561176,  0.34396535,  0.0643941 ,  0.16240774,  0.24206137,
#          0.09155967]])
# ```
#
# Running it through `sess.run(tf.nn.top_k(tf.constant(a), k=3))` produces:
#
# ```
# TopKV2(values=array([[ 0.34763842,  0.24879643,  0.12789202],
#        [ 0.28086119,  0.27569815,  0.18063401],
#        [ 0.26076848,  0.23892179,  0.23664738],
#        [ 0.29198961,  0.26234032,  0.16505091],
#        [ 0.34396535,  0.24206137,  0.16240774]]), indices=array([[3, 0, 5],
#        [0, 1, 4],
#        [0, 5, 1],
#        [1, 3, 5],
#        [1, 4, 3]], dtype=int32))
# ```
#
# Looking just at the first row we get `[ 0.34763842,  0.24879643,  0.12789202]`, you can confirm these are the 3 largest probabilities in `a`. You'll also notice `[3, 0, 5]` are the corresponding indices.

# %%
### Print out the top five softmax probabilities for the predictions on the German traffic sign images found on the web. 
### Feel free to use as many code cells as needed.

# %% [markdown]
# ---
#
# ## Step 4: Visualize the Neural Network's State with Test Images
#
#  This Section is not required to complete but acts as an additional excersise for understaning the output of a neural network's weights. While neural networks can be a great learning device they are often referred to as a black box. We can understand what the weights of a neural network look like better by plotting their feature maps. After successfully training your neural network you can see what it's feature maps look like by plotting the output of the network's weight layers in response to a test stimuli image. From these plotted feature maps, it's possible to see what characteristics of an image the network finds interesting. For a sign, maybe the inner network feature maps react with high activation to the sign's boundary outline or to the contrast in the sign's painted symbol.
#
#  Provided for you below is the function code that allows you to get the visualization output of any tensorflow weight layer you want. The inputs to the function should be a stimuli image, one used during training or a new one you provided, and then the tensorflow variable name that represents the layer's state during the training process, for instance if you wanted to see what the [LeNet lab's](https://classroom.udacity.com/nanodegrees/nd013/parts/fbf77062-5703-404e-b60c-95b78b2f3f9e/modules/6df7ae49-c61c-4bb2-a23e-6527e69209ec/lessons/601ae704-1035-4287-8b11-e2c2716217ad/concepts/d4aca031-508f-4e0b-b493-e7b706120f81) feature maps looked like for it's second convolutional layer you could enter conv2 as the tf_activation variable.
#
# For an example of what feature map outputs look like, check out NVIDIA's results in their paper [End-to-End Deep Learning for Self-Driving Cars](https://devblogs.nvidia.com/parallelforall/deep-learning-self-driving-cars/) in the section Visualization of internal CNN State. NVIDIA was able to show that their network's inner weights had high activations to road boundary lines by comparing feature maps from an image with a clear path to one without. Try experimenting with a similar test to show that your trained network's weights are looking for interesting features, whether it's looking at differences in feature maps from images with or without a sign, or even what feature maps look like in a trained network vs a completely untrained one on the same sign image.
#
# <figure>
#  <img src="visualize_cnn.png" width="380" alt="Combined Image" />
#  <figcaption>
#  <p></p>
#  <p style="text-align: center;"> Your output should look something like this (above)</p>
#  </figcaption>
# </figure>
#  <p></p>

# %%
### Visualize your network's feature maps here.
### Feel free to use as many code cells as needed.

# image_input: the test image being fed into the network to produce the feature maps
# tf_activation: should be a tf variable name used during your training procedure that represents the calculated state of a specific weight layer
# activation_min/max: can be used to view the activation contrast in more detail, by default matplot sets min and max to the actual min and max values of the output
# plt_num: used to plot out multiple different weight feature map sets on the same block, just extend the plt number for each new feature map entry

def outputFeatureMap(image_input, tf_activation, activation_min=-1, activation_max=-1 ,plt_num=1):
    # Here make sure to preprocess your image_input in a way your network expects
    # with size, normalization, ect if needed
    # image_input =
    # Note: x should be the same name as your network's tensorflow data placeholder variable
    # If you get an error tf_activation is not defined it maybe having trouble accessing the variable from inside a function
    activation = tf_activation.eval(session=sess,feed_dict={x : image_input})
    featuremaps = activation.shape[3]
    plt.figure(plt_num, figsize=(15,15))
    for featuremap in range(featuremaps):
        plt.subplot(6,8, featuremap+1) # sets the number of feature maps to show on each row and column
        plt.title('FeatureMap ' + str(featuremap)) # displays the feature map number
        if activation_min != -1 & activation_max != -1:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", vmin =activation_min, vmax=activation_max, cmap="gray")
        elif activation_max != -1:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", vmax=activation_max, cmap="gray")
        elif activation_min !=-1:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", vmin=activation_min, cmap="gray")
        else:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", cmap="gray")

# %% [markdown]
# ### Question 9
#
# Discuss how you used the visual output of your trained network's feature maps to show that it had learned to look for interesting characteristics in traffic sign images

# %% [markdown]
# **Answer:**

# %% [markdown]
# > **Note**: Once you have completed all of the code implementations and successfully answered each question above, you may finalize your work by exporting the iPython Notebook as an HTML document. You can do this by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.

# %% [markdown]
# ### Project Writeup
#
# Once you have completed the code implementation, document your results in a project writeup using this [template](https://github.com/udacity/CarND-Traffic-Sign-Classifier-Project/blob/master/writeup_template.md) as a guide. The writeup can be in a markdown or pdf file.
